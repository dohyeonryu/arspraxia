# %% [markdown]
# <a href="https://colab.research.google.com/github/dohyeonryu/arspraxia/blob/main/Pororo_200.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file_youtube=pd.read_csv("Youtube_Ko_Raw_05.csv")
file_news=pd.read_csv("news_keyword_05.csv")
file_twitter=pd.read_csv("twitter_cleaning_05.csv")

# %%
body_youtube=list(file_youtube['body'])
body_news=list(file_news['body'])
body_twitter=list(file_twitter['body'])

# %%
from pororo import Pororo
ner=Pororo(task="ner",lang="ko")
review=Pororo(task="review_scoring",lang="ko")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
body_youtube=list(file_youtube['body'].head(200))
body_news=list(file_news['body'].head(200))
body_twitter=list(file_twitter['body'].head(200))

# %%
from tqdm import tqdm_notebook
ner_results=[]
for i in tqdm_notebook(body_youtube):
  result = ner(i)
  ner_results.append(result)
ner_results
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
#   0%|          | 0/200 [00:00<?, ?it/s]
# [Korean Sentence Splitter]: Initializing Pynori...
# [[('보고싶어', 'O'),
#   (' ', 'O'),
#   ('보고싶어', 'O'),
#   (' ', 'O'),
#   ('보고싶어', 'O'),
#   (' ', 'O'),
#   ('백현아', 'PERSON')],
#  [('따스하고', 'O'),
#   (' ', 'O'),
#   ('다정한', 'O'),
#   (' ', 'O'),
#   ('너의', 'O'),
#   (' ', 'O'),
#   ('목소리는', 'O'),
#   (' ', 'O'),
#   ('12월', 'DATE'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('기적', 'O'),
#   (' ', 'O'),
#   ('같아♥', 'O'),
#   (' ', 'O'),
#   ('그는', 'O'),
#   (' ', 'O'),
#   ('이제', 'O'),
#   (' ', 'O'),
#   ('내가', 'O'),
#   (' ', 'O'),
#   ('그리워하는', 'O'),
#   (' ', 'O'),
#   ('안도감을', 'O'),
#   (' ', 'O'),
#   ('느끼게', 'O'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('모든', 'O'),
#   (' ', 'O'),
#   ('따뜻함으로', 'O'),
#   (' ', 'O'),
#   ('내', 'O'),
#   (' ', 'O'),
#   ('영혼과', 'O'),
#   (' ', 'O'),
#   ('마음을', 'O'),
#   (' ', 'O'),
#   ('안아줍니다', 'O')],
#  [('따스하고', 'O'),
#   (' ', 'O'),
#   ('다정한', 'O'),
#   (' ', 'O'),
#   ('너의', 'O'),
#   (' ', 'O'),
#   ('목소리는', 'O'),
#   (' ', 'O'),
#   ('12월', 'DATE'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('기적', 'O'),
#   (' ', 'O'),
#   ('같아♥', 'O'),
#   (' ', 'O'),
#   ('그는', 'O'),
#   (' ', 'O'),
#   ('이제', 'O'),
#   (' ', 'O'),
#   ('내가', 'O'),
#   (' ', 'O'),
#   ('그리워하는', 'O'),
#   (' ', 'O'),
#   ('안도감을', 'O'),
#   (' ', 'O'),
#   ('느끼게', 'O'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('모든', 'O'),
#   (' ', 'O'),
#   ('따뜻함으로', 'O'),
#   (' ', 'O'),
#   ('내', 'O'),
#   (' ', 'O'),
#   ('영혼과', 'O'),
#   (' ', 'O'),
#   ('마음을', 'O'),
#   (' ', 'O'),
#   ('안아줍니다', 'O')],
#  [('아', 'O'), (' ', 'O'), ('드디어어어어어어ㅓㅠㅠㅠㅠ', 'O')],
#  [('백현', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('목소리', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('로맨틱이에요,', 'O'),
#   (' ', 'O'),
#   ("I'm", 'O'),
#   (' ', 'O'),
#   ('so', 'O'),
#   (' ', 'O'),
#   ('happy', 'O'),
#   (' ', 'O'),
#   ('that', 'O'),
#   (' ', 'O'),
#   ('kyoongtube', 'O'),
#   (' ', 'O'),
#   ('is', 'O'),
#   (' ', 'O'),
#   ('back', 'O'),
#   (' ', 'O'),
#   ('ㅠㅠ', 'O')],
#  [('눈물', 'O'),
#   (' ', 'O'),
#   ('왜', 'O'),
#   (' ', 'O'),
#   ('이렇게', 'O'),
#   (' ', 'O'),
#   ('흘리지', 'O'),
#   (' ', 'O'),
#   ('ㅠㅠ', 'O')],
#  [('Vote', 'O'), (' ', 'O'), ('for', 'O'), (' ', 'O'), ('ℤ✨있지', 'O')],
#  [('역시', 'O'),
#   (' ', 'O'),
#   ('sorry', 'O'),
#   (' ', 'O'),
#   ('not', 'O'),
#   (' ', 'O'),
#   ('sorry', 'O'),
#   (' ', 'O'),
#   ('1위', 'QUANTITY'),
#   ('구나', 'O'),
#   (' ', 'O'),
#   ('너무좋아', 'O')],
#  [('너희들은', 'O'),
#   (' ', 'O'),
#   ('그', 'O'),
#   (' ', 'O'),
#   ('옷이', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('멋져', 'O'),
#   (' ', 'O'),
#   ('보인다', 'O')],
#  [('And', 'O'),
#   (' ', 'O'),
#   ("don't", 'O'),
#   (' ', 'O'),
#   ('forget', 'O'),
#   (' ', 'O'),
#   ('to', 'O'),
#   (' ', 'O'),
#   ('vote', 'O'),
#   (' ', 'O'),
#   ('SMA', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('for', 'O'),
#   (' ', 'O'),
#   ('ITZY', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('!!!!', 'O'),
#   (' ', 'O'),
#   ('Thank', 'O'),
#   (' ', 'O'),
#   ('you', 'O'),
#   (' ', 'O'),
#   ('#ITZY', 'O'),
#   (' ', 'O'),
#   ('#있지', 'O')],
#  [('아', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('정우영', 'PERSON'),
#   ('ㅋㅋㅋㅋㅋㅋ냅다', 'O'),
#   (' ', 'O'),
#   ('고음지르고', 'O'),
#   (' ', 'O'),
#   ('옆에서', 'O'),
#   (' ', 'O'),
#   ('홍중', 'PERSON'),
#   ('이랑', 'O'),
#   (' ', 'O'),
#   ('산', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('쳐다보고', 'O'),
#   (' ', 'O'),
#   ('성화가', 'O'),
#   (' ', 'O'),
#   ('진정시키는겈ㅌㅌㅌㅋ', 'O')],
#  [('Boys,', 'O'),
#   (' ', 'O'),
#   ('what', 'O'),
#   (' ', 'O'),
#   ('are', 'O'),
#   (' ', 'O'),
#   ('you', 'O'),
#   (' ', 'O'),
#   ('doing?❤❤❤', 'O'),
#   (' ', 'O'),
#   ('당신을', 'O'),
#   (' ', 'O'),
#   ('많이', 'O'),
#   (' ', 'O'),
#   ('사랑해요😭🥰❤', 'O')],
#  [('안녕하세요!!', 'O'),
#   (' ', 'O'),
#   ('저는', 'O'),
#   (' ', 'O'),
#   ('일본인', 'CIVILIZATION'),
#   ('입니다', 'O')],
#  [('Σ(❛□❛✿)', 'O'),
#   (' ', 'O'),
#   ('TWICE', 'PERSON'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('정말', 'O'),
#   (' ', 'O'),
#   ('좋아합니다', 'O')],
#  [('계속', 'O'),
#   (' ', 'O'),
#   ('응원하고', 'O'),
#   (' ', 'O'),
#   ('있어요', 'O'),
#   (' ', 'O'),
#   ('♡', 'O')],
#  [('채영', 'PERSON'),
#   ('이는', 'O'),
#   (' ', 'O'),
#   ('저', 'O'),
#   (' ', 'O'),
#   ('기장', 'O'),
#   (' ', 'O'),
#   ('치마', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('입으니까', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('어색하다', 'O'),
#   (' ', 'O'),
#   ('ㅋㅋ', 'O')],
#  [('오디션으로', 'O'), (' ', 'O'), ('뽑힌거', 'O'), (' ', 'O'), ('아니었나?', 'O')],
#  [('함께', 'O'),
#   (' ', 'O'),
#   ('노래하고', 'O'),
#   (' ', 'O'),
#   ('싶은', 'O'),
#   (' ', 'O'),
#   ('트와이스', 'PERSON'),
#   ('와', 'O'),
#   (' ', 'O'),
#   ('블랙핑크', 'PERSON')],
#  [('나연', 'PERSON'),
#   (' ', 'O'),
#   ('치마', 'CIVILIZATION'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('저게', 'O'),
#   (' ', 'O'),
#   ('뭐냐', 'O'),
#   (' ', 'O'),
#   ('속', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('보이게', 'O')],
#  [('불편해서', 'O'),
#   (' ', 'O'),
#   ('다리', 'ANIMAL'),
#   (' ', 'O'),
#   ('쓰는', 'O'),
#   (' ', 'O'),
#   ('동작도', 'O'),
#   (' ', 'O'),
#   ('잘', 'O'),
#   (' ', 'O'),
#   ('못', 'O'),
#   (' ', 'O'),
#   ('하는구만', 'O'),
#   (' ', 'O'),
#   ('ㅠㅠ', 'O'),
#   (' ', 'O'),
#   ('속상', 'O'),
#   (' ', 'O'),
#   ('해', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O')],
#  [('효', 'O'),
#   (' ', 'O'),
#   ('자기파트에서', 'O'),
#   (' ', 'O'),
#   ('틀린다고?', 'O'),
#   (' ', 'O'),
#   ('?ㅋㅋ', 'O')],
#  [('트와이스', 'PERSON'),
#   (' ', 'O'),
#   ('평생', 'O'),
#   (' ', 'O'),
#   ('톰브라운', 'PERSON'),
#   (' ', 'O'),
#   ('입어줘', 'O')],
#  [('채영', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('저렇게입으니까', 'O'),
#   (' ', 'O'),
#   ('고딩같고', 'O'),
#   (' ', 'O'),
#   ('너무예쁘다', 'O')],
#  [('근데', 'O'),
#   (' ', 'O'),
#   ('다현', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('춤', 'O'),
#   (' ', 'O'),
#   ('왜케', 'O'),
#   (' ', 'O'),
#   ('성의없냐', 'O')],
#  [('ㅡㅡ', 'O'),
#   (' ', 'O'),
#   ('혼자', 'O'),
#   (' ', 'O'),
#   ('아에', 'O'),
#   (' ', 'O'),
#   ('발', 'ANIMAL'),
#   ('을', 'O'),
#   (' ', 'O'),
#   ('안쓰네', 'O')],
#  [('아이유', 'PERSON'),
#   ('랑', 'O'),
#   (' ', 'O'),
#   ('같은', 'O'),
#   (' ', 'O'),
#   ('세기에', 'O'),
#   (' ', 'O'),
#   ('살고있어서', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('좋아', 'O'),
#   (' ', 'O'),
#   ('💜', 'O')],
#  [('사실', 'O'),
#   (' ', 'O'),
#   ('노래가', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('좋아요,', 'O'),
#   (' ', 'O'),
#   ('가사도', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('좋아요', 'O'),
#   (' ', 'O'),
#   ('ㅠㅠㅠ,', 'O'),
#   (' ', 'O'),
#   ('이건', 'O'),
#   (' ', 'O'),
#   ('제', 'O'),
#   (' ', 'O'),
#   ('재일', 'O'),
#   (' ', 'O'),
#   ('좋아하는', 'O'),
#   (' ', 'O'),
#   ('노래이에요', 'O'),
#   (' ', 'O'),
#   ('♡♡♡', 'O')],
#  [('모두들', 'O'),
#   (' ', 'O'),
#   ('2021년', 'DATE'),
#   (' ', 'O'),
#   ('잘', 'O'),
#   (' ', 'O'),
#   ('보내주고', 'O'),
#   (' ', 'O'),
#   ('2022년', 'DATE'),
#   ('에는', 'O'),
#   (' ', 'O'),
#   ('더', 'O'),
#   (' ', 'O'),
#   ('대박나세요', 'O'),
#   (' ', 'O'),
#   ('!!', 'O'),
#   (' ', 'O'),
#   ('지은이', 'OCCUPATION'),
#   (' ', 'O'),
#   ('누나', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('노래', 'O'),
#   (' ', 'O'),
#   ('들으면서', 'O'),
#   (' ', 'O'),
#   ('힘냅시다', 'O'),
#   (' ', 'O'),
#   ('🥰🥰', 'O')],
#  [('목소리', 'O'),
#   (' ', 'O'),
#   ('무슨일!!!!', 'O'),
#   (' ', 'O'),
#   ('언니', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('사랑해', 'O'),
#   (' ', 'O'),
#   ('ㅜㅜㅠㅜㅜ', 'O'),
#   (' ', 'O'),
#   ('언니', 'CIVILIZATION'),
#   ('나', 'O'),
#   (' ', 'O'),
#   ('오늘', 'DATE'),
#   (' ', 'O'),
#   ('아이유', 'PERSON'),
#   (' ', 'O'),
#   ('달력', 'O'),
#   (' ', 'O'),
#   ('샀어!!!', 'O'),
#   (' ', 'O'),
#   ('내인생에', 'O'),
#   (' ', 'O'),
#   ('나타나', 'O'),
#   (' ', 'O'),
#   ('줘서', 'O'),
#   (' ', 'O'),
#   ('고마워ㅓ', 'O'),
#   (' ', 'O'),
#   ('사랑해', 'O'),
#   (' ', 'O'),
#   ('아이유', 'PERSON'),
#   ('!', 'O'),
#   (' ', 'O'),
#   ('❤', 'O')],
#  [('진짜', 'O'),
#   (' ', 'O'),
#   ('보자마자', 'O'),
#   (' ', 'O'),
#   ('몇분동안', 'O'),
#   (' ', 'O'),
#   ('입', 'ANIMAL'),
#   (' ', 'O'),
#   ('다물지', 'O'),
#   (' ', 'O'),
#   ('못했던', 'O'),
#   (' ', 'O'),
#   ('노래', 'O')],
#  [('이', 'O'),
#   (' ', 'O'),
#   ('노래', 'O'),
#   (' ', 'O'),
#   ('처음', 'O'),
#   (' ', 'O'),
#   ('들었을', 'O'),
#   (' ', 'O'),
#   ('때', 'O'),
#   (' ', 'O'),
#   ('그', 'O'),
#   (' ', 'O'),
#   ('느낌으로', 'O'),
#   (' ', 'O'),
#   ('돌아가고', 'O'),
#   (' ', 'O'),
#   ('싶다', 'O')],
#  [('봄', 'DATE'),
#   (' ', 'O'),
#   ('한 송이', 'QUANTITY'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('여름', 'DATE'),
#   (' ', 'O'),
#   ('한 컵', 'QUANTITY'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('가을', 'DATE'),
#   (' ', 'O'),
#   ('한 장', 'QUANTITY'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('겨울', 'DATE'),
#   (' ', 'O'),
#   ('한', 'O'),
#   (' ', 'O'),
#   ('숨', 'O')],
#  [('사계절이', 'O'),
#   (' ', 'O'),
#   ('그득', 'O'),
#   (' ', 'O'),
#   ('담긴', 'O'),
#   (' ', 'O'),
#   ('당신의', 'O'),
#   (' ', 'O'),
#   ('노래에', 'O'),
#   (' ', 'O'),
#   ('올해', 'DATE'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('마지막을', 'O'),
#   (' ', 'O'),
#   ('누구보다', 'O'),
#   (' ', 'O'),
#   ('흐드러지게', 'O'),
#   (' ', 'O'),
#   ('마무리하네요', 'O')],
#  [('매번', 'O'),
#   (' ', 'O'),
#   ('고마워요!', 'O'),
#   (' ', 'O'),
#   ('LOVEya', 'O'),
#   (' ', 'O'),
#   ('0', 'QUANTITY')],
#  [('I', 'O'),
#   (' ', 'O'),
#   ('love', 'O'),
#   (' ', 'O'),
#   ('you,', 'O'),
#   (' ', 'O'),
#   ('you', 'O'),
#   (' ', 'O'),
#   ('are', 'O'),
#   (' ', 'O'),
#   ('my', 'O'),
#   (' ', 'O'),
#   ('queen', 'O'),
#   (' ', 'O'),
#   ('💕', 'O'),
#   (' ', 'O'),
#   ('사랑해', 'O')],
#  [('새해', 'DATE'),
#   ('복', 'O'),
#   (' ', 'O'),
#   ('꼭꼭', 'O'),
#   (' ', 'O'),
#   ('많이', 'O'),
#   (' ', 'O'),
#   ('받아요!!', 'O'),
#   (' ', 'O'),
#   ('♡♡♡♡', 'O')],
#  [('새해', 'DATE'),
#   (' ', 'O'),
#   ('복', 'O'),
#   (' ', 'O'),
#   ('많이', 'O'),
#   (' ', 'O'),
#   ('받으세요🙏', 'O'),
#   (' ', 'O'),
#   ('❤❤', 'O')],
#  [('사랑스러운', 'O'), (' ', 'O'), ('사랑스러운', 'O'), (' ', 'O'), ('IU♥♥♥♥', 'O')],
#  [('이번', 'O'),
#   (' ', 'O'),
#   ('조각집은', 'O'),
#   (' ', 'O'),
#   ('LP', 'TERM'),
#   ('로', 'O'),
#   (' ', 'O'),
#   ('나오면', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('행복하겠다', 'O')],
#  [('지은아', 'PERSON'),
#   (' ', 'O'),
#   ('노래', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('좋다', 'O'),
#   (' ', 'O'),
#   ('정말', 'O'),
#   (' ', 'O'),
#   ('연말', 'DATE'),
#   (' ', 'O'),
#   ('선물', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('고마워', 'O')],
#  [('힘들어', 'O'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('널', 'O'),
#   (' ', 'O'),
#   ('안아서', 'O'),
#   (' ', 'O'),
#   ('먹인', 'O'),
#   (' ', 'O'),
#   ('물보다', 'O'),
#   (' ', 'O'),
#   ('흘린', 'O'),
#   (' ', 'O'),
#   ('눈물이', 'O'),
#   (' ', 'O'),
#   ('많던', 'O'),
#   (' ', 'O'),
#   ('그날', 'DATE'),
#   (' ', 'O'),
#   ('내가', 'O'),
#   (' ', 'O'),
#   ('했던말', 'O'),
#   (' ', 'O'),
#   ('혹시', 'O'),
#   (' ', 'O'),
#   ('기억하니?', 'O'),
#   (' ', 'O'),
#   ('다음주', 'DATE'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('겨울', 'DATE'),
#   (' ', 'O'),
#   ('바다', 'O'),
#   (' ', 'O'),
#   ('보러가고,', 'O'),
#   (' ', 'O'),
#   ('따스한', 'O'),
#   (' ', 'O'),
#   ('봄', 'DATE'),
#   ('에는', 'O'),
#   (' ', 'O'),
#   ('꽃', 'O'),
#   (' ', 'O'),
#   ('보러', 'O'),
#   (' ', 'O'),
#   ('가고,', 'O'),
#   (' ', 'O'),
#   ('여름', 'DATE'),
#   ('에는', 'O'),
#   (' ', 'O'),
#   ('계곡도', 'O'),
#   (' ', 'O'),
#   ('가자', 'O'),
#   (' ', 'O'),
#   ('했던', 'O'),
#   (' ', 'O'),
#   ('그', 'O'),
#   (' ', 'O'),
#   ('말', 'O')],
#  [('그렇게', 'O'),
#   (' ', 'O'),
#   ('딱', 'O'),
#   (' ', 'O'),
#   ('일년만', 'DATE'),
#   (' ', 'O'),
#   ('더', 'O'),
#   (' ', 'O'),
#   ('버텨달라했는데', 'O'),
#   (' ', 'O'),
#   ('내', 'O'),
#   (' ', 'O'),
#   ('걱정만', 'O'),
#   (' ', 'O'),
#   ('가득하다', 'O'),
#   (' ', 'O'),
#   ('먼저', 'O'),
#   (' ', 'O'),
#   ('먼길을', 'O'),
#   (' ', 'O'),
#   ('갔네', 'O'),
#   (' ', 'O'),
#   ('우리', 'O'),
#   (' ', 'O'),
#   ('아가', 'O'),
#   (' ', 'O'),
#   ('딱', 'O'),
#   (' ', 'O'),
#   ('가사', 'O'),
#   (' ', 'O'),
#   ('처럼', 'O'),
#   (' ', 'O'),
#   ('조각잠을', 'O'),
#   (' ', 'O'),
#   ('자듯', 'O'),
#   (' ', 'O'),
#   ('마지막', 'O'),
#   (' ', 'O'),
#   ('숨을', 'O'),
#   (' ', 'O'),
#   ('내쉬고', 'O'),
#   (' ', 'O'),
#   ('편안하게', 'O'),
#   (' ', 'O'),
#   ('가던', 'O'),
#   (' ', 'O'),
#   ('모습', 'O'),
#   (' ', 'O'),
#   ('보니', 'O'),
#   (' ', 'O'),
#   ('슬프면서도', 'O'),
#   (' ', 'O'),
#   ('다행이라', 'O'),
#   (' ', 'O'),
#   ('생각되더라', 'O')],
#  [('아프지말고', 'O'),
#   (' ', 'O'),
#   ('행복하게', 'O'),
#   (' ', 'O'),
#   ('뛰어놀다', 'O'),
#   (' ', 'O'),
#   ('뭐하고', 'O'),
#   (' ', 'O'),
#   ('지냈는지', 'O'),
#   (' ', 'O'),
#   ('재잘재잘', 'O'),
#   (' ', 'O'),
#   ('떠들어주렴', 'O')],
#  [('가끔은', 'O'),
#   (' ', 'O'),
#   ('꿈', 'O'),
#   (' ', 'O'),
#   ('우체통에', 'O'),
#   (' ', 'O'),
#   ('소식', 'O'),
#   (' ', 'O'),
#   ('남겨', 'O'),
#   (' ', 'O'),
#   ('만나러', 'O'),
#   (' ', 'O'),
#   ('와주렴', 'O')],
#  [('와', 'O'),
#   (' ', 'O'),
#   ('노래', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('좋아요', 'O'),
#   (' ', 'O'),
#   ('힐링~~~😍😍', 'O')],
#  [('2021년', 'DATE'),
#   (' ', 'O'),
#   ('마지막 날', 'DATE'),
#   (' ', 'O'),
#   ('최고의', 'O'),
#   (' ', 'O'),
#   ('선물,,', 'O')],
#  [('내가', 'O'),
#   (' ', 'O'),
#   ('다른', 'O'),
#   (' ', 'O'),
#   ('가수', 'CIVILIZATION'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('덕질', 'O'),
#   (' ', 'O'),
#   ('안', 'O'),
#   (' ', 'O'),
#   ('하는데', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('아이유', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('할수밖에', 'O'),
#   (' ', 'O'),
#   ('없었ㄷ', 'O')],
#  [('r★', 'O'),
#   (' ', 'O'),
#   ('그리고', 'O'),
#   (' ', 'O'),
#   ('이번', 'O'),
#   (' ', 'O'),
#   ('앨범', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('빠진ㄷ', 'O')],
#  [('r★', 'O'),
#   (' ', 'O'),
#   ('★라이브', 'O'),
#   (' ', 'O'),
#   ('하시느라', 'O'),
#   (' ', 'O'),
#   ('수고하셨습니다', 'O'),
#   (' ', 'O'),
#   ('★', 'O')],
#  [('징짱', 'O'),
#   (' ', 'O'),
#   ('최고예여!!', 'O'),
#   (' ', 'O'),
#   ('30대', 'QUANTITY'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('유애나', 'PERSON'),
#   ('와', 'O'),
#   (' ', 'O'),
#   ('함께', 'O'),
#   (' ', 'O'),
#   ('좋은', 'O'),
#   (' ', 'O'),
#   ('추억', 'O'),
#   (' ', 'O'),
#   ('만들어봐요!!', 'O')],
#  [('dont', 'O'),
#   (' ', 'O'),
#   ('give', 'O'),
#   (' ', 'O'),
#   ('a', 'O'),
#   (' ', 'O'),
#   ('what이', 'O'),
#   (' ', 'O'),
#   ('제일', 'O'),
#   (' ', 'O'),
#   ('좋아', 'O'),
#   (' ', 'O'),
#   ('난', 'O')],
#  [('류진', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('앞머리', 'ANIMAL'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('잘어울려서', 'O'),
#   (' ', 'O'),
#   ('심장마비', 'TERM'),
#   ('올뻔…', 'O'),
#   (' ', 'O'),
#   ('위험해…', 'O')],
#  [('아름다운', 'O'),
#   (' ', 'O'),
#   ('아름다운', 'O'),
#   (' ', 'O'),
#   ('귀한', 'O'),
#   (' ', 'O'),
#   ('신성', 'O'),
#   (' ', 'O'),
#   ('💜💜', 'O')],
#  [('마피아', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('진짜ㅋㅋㅋㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('식스센스급', 'O'),
#   (' ', 'O'),
#   ('반전', 'O')],
#  [('아', 'O'),
#   (' ', 'O'),
#   ('ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ마지막', 'O'),
#   (' ', 'O'),
#   ('결과', 'O'),
#   (' ', 'O'),
#   ('미쳤다ㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('아이엠그라운드', 'ORGANIZATION'),
#   ('에서', 'O'),
#   (' ', 'O'),
#   ('이미', 'O'),
#   (' ', 'O'),
#   ('한번', 'O'),
#   (' ', 'O'),
#   ('걸려서', 'O'),
#   (' ', 'O'),
#   ('당연히', 'O'),
#   (' ', 'O'),
#   ('인성', 'PERSON'),
#   ('이인줄', 'O'),
#   (' ', 'O'),
#   ('활동', 'O'),
#   (' ', 'O'),
#   ('수고', 'O'),
#   (' ', 'O'),
#   ('많았어!!!!!', 'O')],
#  [('ㅋㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('ㅜㅠㅠ', 'O'),
#   (' ', 'O'),
#   ('"', 'O'),
#   ('트리', 'PERSON'),
#   ('"우마활동', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('멋있었어!!!', 'O'),
#   (' ', 'O'),
#   ('세계', 'O'),
#   (' ', 'O'),
#   ('최강', 'O'),
#   (' ', 'O'),
#   ('셒구ㅋㅋㅋㅋ!!!', 'O')],
#  [('요즈음', 'O'),
#   (' ', 'O'),
#   ('최고의메이킹', 'O'),
#   (' ', 'O'),
#   ('좀', 'O'),
#   (' ', 'O'),
#   ('많이', 'O'),
#   (' ', 'O'),
#   ('재밌었다', 'O')],
#  [('우리', 'O'),
#   (' ', 'O'),
#   ('셒구!!!', 'O'),
#   (' ', 'O'),
#   ('트라우마', 'TERM'),
#   (' ', 'O'),
#   ('활동', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('수고많았고', 'O'),
#   (' ', 'O'),
#   ('고생많았어요!!!', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('9명', 'QUANTITY'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('같이', 'O'),
#   (' ', 'O'),
#   ('할수있어서', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('고맙고', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('이렇게', 'O'),
#   (' ', 'O'),
#   ('멋진', 'O'),
#   (' ', 'O'),
#   ('무대를', 'O'),
#   (' ', 'O'),
#   ('보여줘서', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('고맙고', 'O'),
#   (' ', 'O'),
#   ('우리', 'O'),
#   (' ', 'O'),
#   ('셒구', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('같이', 'O'),
#   (' ', 'O'),
#   ('있으면', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('애기들', 'O'),
#   (' ', 'O'),
#   ('모인', 'PERSON'),
#   ('처럼', 'O'),
#   (' ', 'O'),
#   ('ㅋㅋㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('귀엽다', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('대기실에', 'O'),
#   (' ', 'O'),
#   ('그', 'O'),
#   (' ', 'O'),
#   ('모습이', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('사랑스럽다', 'O'),
#   (' ', 'O'),
#   ('으이그~~~', 'O'),
#   (' ', 'O'),
#   ('이제', 'O'),
#   (' ', 'O'),
#   ('콘서트', 'O'),
#   (' ', 'O'),
#   ('준비중인데', 'O'),
#   (' ', 'O'),
#   ('화댝하고', 'O'),
#   (' ', 'O'),
#   ('온라인으로도', 'O'),
#   (' ', 'O'),
#   ('보게', 'O'),
#   (' ', 'O'),
#   ('해주세요', 'O'),
#   (' ', 'O'),
#   ('제발', 'O'),
#   (' ', 'O'),
#   ('ㅠㅠㅠ', 'O'),
#   (' ', 'O'),
#   ('해외타지', 'O'),
#   (' ', 'O'),
#   ('울어요', 'O'),
#   (' ', 'O'),
#   ('후후', 'O'),
#   (' ', 'O'),
#   ('임튼', 'PERSON'),
#   (' ', 'O'),
#   ('많이', 'O'),
#   (' ', 'O'),
#   ('고맙고', 'O'),
#   (' ', 'O'),
#   ('많이', 'O'),
#   (' ', 'O'),
#   ('사랑하고', 'O'),
#   (' ', 'O'),
#   ('앞으로도', 'O'),
#   (' ', 'O'),
#   ('함께하고', 'O'),
#   (' ', 'O'),
#   ('응원할게용!!', 'O')],
#  [('미쳤어', 'O'),
#   (' ', 'O'),
#   ('김영빈', 'PERSON'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('대박!!!', 'O'),
#   (' ', 'O'),
#   ('나도', 'O'),
#   (' ', 'O'),
#   ('속았어', 'O'),
#   (' ', 'O'),
#   ('우와', 'O'),
#   (' ', 'O'),
#   ('소름', 'O'),
#   (' ', 'O'),
#   ('아니', 'O'),
#   (' ', 'O'),
#   ('연기도', 'O'),
#   (' ', 'O'),
#   ('왜케', 'O'),
#   (' ', 'O'),
#   ('잘해요', 'O'),
#   (' ', 'O'),
#   ('ㅋㅋㅋㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('아', 'O'),
#   (' ', 'O'),
#   ('미치겠네', 'O'),
#   (' ', 'O'),
#   ('아니', 'O'),
#   (' ', 'O'),
#   ('진짜로', 'O'),
#   (' ', 'O'),
#   ('오빠', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('드라마', 'O'),
#   (' ', 'O'),
#   ('더', 'O'),
#   (' ', 'O'),
#   ('보고싶다', 'O'),
#   (' ', 'O'),
#   ('하', 'O'),
#   (' ', 'O'),
#   ('미치겠네', 'O')],
#  [('2021년', 'DATE'),
#   (' ', 'O'),
#   ('좀', 'O'),
#   (' ', 'O'),
#   ('서운한', 'O'),
#   (' ', 'O'),
#   ('활동이긴', 'O'),
#   (' ', 'O'),
#   ('했지만', 'O')],
#  [('남은', 'O'),
#   (' ', 'O'),
#   ('시간', 'O'),
#   (' ', 'O'),
#   ('건강하게', 'O'),
#   (' ', 'O'),
#   ('잘', 'O'),
#   (' ', 'O'),
#   ('마물하구', 'O')],
#  [('2022년도', 'DATE'), (' ', 'O'), ('쭈우욱~~~~~~파이팅~♡^^♡', 'O')],
#  [('SF9', 'ARTIFACT'),
#   (' ', 'O'),
#   ('최고야~~항상', 'O'),
#   (' ', 'O'),
#   ('건강하고', 'O'),
#   (' ', 'O'),
#   ('행복해야해😍', 'O'),
#   (' ', 'O'),
#   ('와중에', 'O'),
#   (' ', 'O'),
#   ('영빈', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('저', 'O'),
#   (' ', 'O'),
#   ('아니라구요!!!!!!', 'O')],
#  [('영빈', 'PERSON'), (' ', 'O'), ('ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ메소드연기다', 'O')],
#  [('함께', 'O'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('SF9', 'ARTIFACT'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('행복한', 'O'),
#   (' ', 'O'),
#   ('모습을', 'O'),
#   (' ', 'O'),
#   ('보는', 'O'),
#   (' ', 'O'),
#   ('것만으로도', 'O'),
#   (' ', 'O'),
#   ('저는', 'O'),
#   (' ', 'O'),
#   ('충분합니다', 'O')],
#  [('짧은', 'O'),
#   (' ', 'O'),
#   ('프로모션이지만', 'O'),
#   (' ', 'O'),
#   ('당신은', 'O'),
#   (' ', 'O'),
#   ('우리에게', 'O'),
#   (' ', 'O'),
#   ('행복을', 'O'),
#   (' ', 'O'),
#   ('가져다', 'O'),
#   (' ', 'O'),
#   ('줍니다', 'O')],
#  [('매일매일', 'O'),
#   (' ', 'O'),
#   ('우리의', 'O'),
#   (' ', 'O'),
#   ('영감이', 'O'),
#   (' ', 'O'),
#   ('되어줘서', 'O')],
#  [('이', 'O'),
#   (' ', 'O'),
#   ('가족', 'CIVILIZATION'),
#   ('을', 'O'),
#   (' ', 'O'),
#   ('보호하고', 'O'),
#   (' ', 'O'),
#   ('서로를', 'O'),
#   (' ', 'O'),
#   ('지지하자', 'O')],
#  [('애두다', 'O'),
#   (' ', 'O'),
#   ('활동', 'O'),
#   (' ', 'O'),
#   ('넘넘', 'O'),
#   (' ', 'O'),
#   ('수고했어❤❤', 'O')],
#  [('재윤', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('레드컬', 'TERM'),
#   ('러', 'O'),
#   (' ', 'O'),
#   ('잘어울린다', 'O'),
#   (' ', 'O'),
#   ('😍', 'O')],
#  [('김영빈', 'PERSON'),
#   (' ', 'O'),
#   ('일줄은', 'O'),
#   (' ', 'O'),
#   ('알았는데', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('김영빈', 'PERSON'),
#   ('이네', 'O'),
#   (' ', 'O'),
#   ('ㅋㅋㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('귀엽다', 'O'),
#   (' ', 'O'),
#   ('너희', 'O')],
#  [('아', 'O'),
#   (' ', 'O'),
#   ('스물여덟살', 'QUANTITY'),
#   ('이라서', 'O'),
#   (' ', 'O'),
#   ('28윤', 'QUANTITY'),
#   ('임?', 'O'),
#   (' ', 'O'),
#   ('ㅋㅋㅋ', 'O')],
#  [('멋진', 'O'),
#   (' ', 'O'),
#   ('무대', 'O'),
#   (' ', 'O'),
#   ('보여주신', 'O'),
#   (' ', 'O'),
#   ('우리', 'O'),
#   (' ', 'O'),
#   ('셒구', 'O'),
#   (' ', 'O'),
#   ('감사합니다', 'O')],
#  [('우리', 'O'),
#   (' ', 'O'),
#   ('1위', 'QUANTITY'),
#   (' ', 'O'),
#   ('가수', 'CIVILIZATION'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('언제나', 'O'),
#   (' ', 'O'),
#   ('사랑해^^', 'O')],
#  [('대기실에서', 'O'),
#   (' ', 'O'),
#   ('마피아', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('에셒나인', 'PERSON'),
#   ('이라닝', 'O'),
#   (' ', 'O'),
#   ('짱', 'O'),
#   (' ', 'O'),
#   ('기여웡ㅋㅋㅋㅋ나', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('영빈', 'PERSON'),
#   ('인', 'O'),
#   (' ', 'O'),
#   ('줄', 'O'),
#   (' ', 'O'),
#   ('몰랏성ㅋㅋㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('활동', 'O'),
#   (' ', 'O'),
#   ('짧아서', 'O'),
#   (' ', 'O'),
#   ('넘', 'O'),
#   (' ', 'O'),
#   ('아쉬웠지만', 'O'),
#   (' ', 'O'),
#   ('또', 'O'),
#   (' ', 'O'),
#   ('좋은', 'O'),
#   (' ', 'O'),
#   ('소식', 'O'),
#   (' ', 'O'),
#   ('기대할게❤❤', 'O')],
#  [('S섹시', 'O'),
#   (' ', 'O'),
#   ('F판타지 9', 'ARTIFACT'),
#   (' ', 'O'),
#   ('정말', 'O'),
#   (' ', 'O'),
#   ('오랜만의', 'O'),
#   (' ', 'O'),
#   ('마피아', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('게임이다~', 'O')],
#  [('비하인드에', 'O'),
#   (' ', 'O'),
#   ('브이라이브', 'O'),
#   (' ', 'O'),
#   ('2개', 'QUANTITY'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('날라가는', 'O'),
#   (' ', 'O'),
#   ('아쉬움은', 'O'),
#   (' ', 'O'),
#   ('나뿐인가요', 'O'),
#   (' ', 'O'),
#   ('ㅠㅠ', 'O'),
#   (' ', 'O'),
#   ('트라우마', 'TERM'),
#   (' ', 'O'),
#   ('수록곡들이', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('좋아서', 'O'),
#   (' ', 'O'),
#   ('매일', 'O'),
#   (' ', 'O'),
#   ('잘', 'O'),
#   (' ', 'O'),
#   ('듣고', 'O'),
#   (' ', 'O'),
#   ('있어요', 'O'),
#   (' ', 'O'),
#   ('셒구', 'O'),
#   (' ', 'O'),
#   ('❤❤❤', 'O'),
#   (' ', 'O'),
#   ('화이팅', 'O')],
#  [('와우', 'ARTIFACT'),
#   (' ', 'O'),
#   ('역시', 'O'),
#   (' ', 'O'),
#   ('우리의', 'O'),
#   (' ', 'O'),
#   ('웃긴', 'O'),
#   (' ', 'O'),
#   ('나인ㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('우리', 'O'),
#   (' ', 'O'),
#   ('셒구', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('잘했어!!', 'O'),
#   (' ', 'O'),
#   ('항상', 'O'),
#   (' ', 'O'),
#   ('고마워^^', 'O'),
#   (' ', 'O'),
#   ('항상', 'O'),
#   (' ', 'O'),
#   ('건강하고', 'O'),
#   (' ', 'O'),
#   ('함께', 'O'),
#   (' ', 'O'),
#   ('행복합시다!', 'O'),
#   (' ', 'O'),
#   ('사랑해~', 'O')],
#  [('ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('와', 'O'),
#   (' ', 'O'),
#   ('연기돌', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('마지막', 'O'),
#   (' ', 'O'),
#   ('쿠키', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('영상', 'O'),
#   (' ', 'O'),
#   ('없었으면', 'O'),
#   (' ', 'O'),
#   ('순간', 'O'),
#   (' ', 'O'),
#   ('나도', 'O'),
#   (' ', 'O'),
#   ('착각할', 'O'),
#   (' ', 'O'),
#   ('뻔했네', 'O')],
#  [('짧았던', 'O'),
#   (' ', 'O'),
#   ('활동기간이었지만', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('수고많았고', 'O'),
#   (' ', 'O'),
#   ('그', 'O'),
#   (' ', 'O'),
#   ('준비하는', 'O'),
#   (' ', 'O'),
#   ('시간도', 'O'),
#   (' ', 'O'),
#   ('길었을텐데', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('고생했어!!', 'O'),
#   (' ', 'O'),
#   ('사랑해❤', 'O')],
#  [('1:28 ㅋㅋㅋ', 'QUANTITY'),
#   ('ㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('태양', 'LOCATION'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('가죽', 'O'),
#   (' ', 'O'),
#   ('등짝', 'ANIMAL'),
#   (' ', 'O'),
#   ('때리는', 'O'),
#   (' ', 'O'),
#   ('찬희', 'PERSON'),
#   (' ', 'O'),
#   ('찰져', 'O'),
#   (' ', 'O'),
#   ('ㅋㅋㅋㅋㅋ', 'O')],
#  [('영빈', 'PERSON'),
#   ('이였다구요????????????????????????!!!!!!!!!!!!!!!!!!', 'O'),
#   (' ', 'O'),
#   ('연기', 'O'),
#   (' ', 'O'),
#   ('많이', 'O'),
#   (' ', 'O'),
#   ('늘었어!!!!!!!!!!!!!!!!!ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'O')],
#  [('항상', 'O'),
#   (' ', 'O'),
#   ('응원해', 'O'),
#   (' ', 'O'),
#   ('우리', 'O'),
#   (' ', 'O'),
#   ('셒구💛', 'O'),
#   (' ', 'O'),
#   ('그리구', 'O'),
#   (' ', 'O'),
#   ('썸네일', 'O'),
#   (' ', 'O'),
#   ('좋아🐣💛', 'O')],
#  [('얘들아', 'O'),
#   (' ', 'O'),
#   ('수고많았어~~', 'O'),
#   (' ', 'O'),
#   ('멋진무대', 'O'),
#   (' ', 'O'),
#   ('보여줘서', 'O'),
#   (' ', 'O'),
#   ('넘', 'O'),
#   (' ', 'O'),
#   ('고마워!!', 'O'),
#   (' ', 'O'),
#   ('다음활동도', 'O'),
#   (' ', 'O'),
#   ('기대할께!!', 'O'),
#   (' ', 'O'),
#   ('사랑해!!!', 'O')],
#  [('백현', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('보고싶어서', 'O'),
#   (' ', 'O'),
#   ('기다리고', 'O'),
#   (' ', 'O'),
#   ('있어🥺❤', 'O')],
#  [('우아에ㅔㅇ엥ㅇ', 'O'),
#   (' ', 'O'),
#   ('ㅇ', 'O'),
#   ('변백현', 'PERSON'),
#   (' ', 'O'),
#   ('ㅠㅠㅠㅠㅠㅠㅠ', 'O')],
#  [('아이고', 'O'),
#   (' ', 'O'),
#   ('감사합니다🙇\u200d♀', 'O'),
#   (' ', 'O'),
#   ('🙇\u200d♀', 'O'),
#   (' ', 'O'),
#   ('🙇\u200d♀', 'O')],
#  [('1일', 'DATE'),
#   ('4~~50음', 'QUANTITY'),
#   (' ', 'O'),
#   ('중임', 'O'),
#   (' ', 'O'),
#   ('ㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('안무영상에서', 'O'),
#   (' ', 'O'),
#   ('못벗어남', 'O'),
#   (' ', 'O'),
#   ('!', 'O'),
#   (' ', 'O'),
#   ('몸', 'ANIMAL'),
#   (' ', 'O'),
#   ('움직임', 'O'),
#   (' ', 'O'),
#   ('예술임!', 'O'),
#   (' ', 'O'),
#   ('베이스음', 'O'),
#   (' ', 'O'),
#   ('쿵', 'O'),
#   (' ', 'O'),
#   ('쿵', 'O'),
#   (' ', 'O'),
#   ('내리칠때', 'O'),
#   (' ', 'O'),
#   ('몸', 'ANIMAL'),
#   (' ', 'O'),
#   ('팍팍', 'O'),
#   (' ', 'O'),
#   ('힘주는거', 'O'),
#   (' ', 'O'),
#   ('기절!', 'O'),
#   (' ', 'O'),
#   ('안무영상', 'O'),
#   (' ', 'O'),
#   ('간지철철', 'O'),
#   (' ', 'O'),
#   ('발놀림', 'O'),
#   (' ', 'O'),
#   ('장난없네!', 'O'),
#   (' ', 'O'),
#   ('춤선이', 'O'),
#   (' ', 'O'),
#   ('단정하면서', 'O'),
#   (' ', 'O'),
#   ('일케', 'O'),
#   (' ', 'O'),
#   ('예쁠수도', 'O'),
#   (' ', 'O'),
#   ('있나', 'O'),
#   (' ', 'O'),
#   ('마루바닥이', 'O'),
#   (' ', 'O'),
#   ('부러울', 'O'),
#   (' ', 'O'),
#   ('지경', 'O'),
#   (' ', 'O'),
#   ('🤪', 'O')],
#  [('백현', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('제대하면', 'O'),
#   (' ', 'O'),
#   ('라디오', 'TERM'),
#   (' ', 'O'),
#   ('디제이', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('했으묜', 'O')],
#  [('백현아', 'PERSON'),
#   (' ', 'O'),
#   ('정말보고싶어', 'O'),
#   (' ', 'O'),
#   ('겨울', 'DATE'),
#   ('이라', 'O'),
#   (' ', 'O'),
#   ('많이춥지?', 'O'),
#   (' ', 'O'),
#   ('감기', 'DISEASE'),
#   ('걸리지말고', 'O'),
#   (' ', 'O'),
#   ('건강해야돼', 'O'),
#   (' ', 'O'),
#   ('우리', 'O'),
#   (' ', 'O'),
#   ('에리들이', 'O'),
#   (' ', 'O'),
#   ('씩씩하게', 'O'),
#   (' ', 'O'),
#   ('기다릴게!', 'O'),
#   (' ', 'O'),
#   ('사랑해💖💖', 'O')],
#  [('울셒구', 'O'),
#   (' ', 'O'),
#   ('고생했어', 'O'),
#   (' ', 'O'),
#   ('~어디서', 'O'),
#   (' ', 'O'),
#   ('뭘하든', 'O'),
#   (' ', 'O'),
#   ('항상', 'O'),
#   (' ', 'O'),
#   ('응원할께', 'O'),
#   (' ', 'O'),
#   ('~', 'O')],
#  [('얘들아', 'O'),
#   (' ', 'O'),
#   ('활동', 'O'),
#   (' ', 'O'),
#   ('열심히', 'O'),
#   (' ', 'O'),
#   ('해줘서', 'O'),
#   (' ', 'O'),
#   ('고마워!', 'O'),
#   (' ', 'O'),
#   ('피디', 'CIVILIZATION'),
#   ('님!', 'O'),
#   (' ', 'O'),
#   ('다음에는', 'O'),
#   (' ', 'O'),
#   ('석우', 'PERSON'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('많이', 'O'),
#   (' ', 'O'),
#   ('찍어주세요ㅠㅠ', 'O')],
#  [('ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('팔윤', 'PERSON'),
#   ('이랑', 'O'),
#   (' ', 'O'),
#   ('용펠', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('어떻게!!!!!!', 'O')],
#  [('와', 'O'),
#   (' ', 'O'),
#   ('김영빈', 'PERSON'),
#   ('…이제', 'O'),
#   (' ', 'O'),
#   ('연기자', 'OCCUPATION'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('됐네!!', 'O')],
#  [('그래도', 'O'),
#   (' ', 'O'),
#   ('연말무대', 'O'),
#   (' ', 'O'),
#   ('봐서', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('기뻤고😭', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('마무리', 'O'),
#   (' ', 'O'),
#   ('잘합시다~👍', 'O')],
#  [('귀야워', 'O'),
#   (' ', 'O'),
#   ('역시', 'O'),
#   (' ', 'O'),
#   ('찬희', 'PERSON'),
#   (' ', 'O'),
#   ('막내', 'CIVILIZATION'),
#   ('온탑', 'O'),
#   (' ', 'O'),
#   ('ㅠㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'O'),
#   ('인성', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('솜방망이', 'O'),
#   (' ', 'O'),
#   ('언제', 'O'),
#   (' ', 'O'),
#   ('맞나', 'O'),
#   (' ', 'O'),
#   ('했다', 'O'),
#   (' ', 'O'),
#   ('ㅋㅋㅋㅋㅋㅋ', 'O')],
#  [('❤❤❤', 'O'),
#   ('SF9', 'ARTIFACT'),
#   ('덕분에', 'O'),
#   (' ', 'O'),
#   ('항상', 'O'),
#   (' ', 'O'),
#   ('행복해요!', 'O'),
#   (' ', 'O'),
#   ('❤❤❤', 'O'),
#   (' ', 'O'),
#   ('🥰항상', 'O'),
#   (' ', 'O'),
#   ('감사합니다🥰', 'O')],
#  [('너멜되만', 'O'),
#   (' ', 'O'),
#   ('하면', 'O'),
#   (' ', 'O'),
#   ('레전드', 'O'),
#   (' ', 'O'),
#   ('갱신하는', 'O'),
#   (' ', 'O'),
#   ('창섭', 'PERSON'),
#   ('오빠', 'CIVILIZATION')],
#  [('나와는', 'O'),
#   (' ', 'O'),
#   ('날', 'O'),
#   (' ', 'O'),
#   ('부터', 'O'),
#   (' ', 'O'),
#   ('매일', 'O'),
#   (' ', 'O'),
#   ('듣는데', 'O'),
#   (' ', 'O'),
#   ('아직도', 'O'),
#   (' ', 'O'),
#   ('소름~', 'O'),
#   (' ', 'O'),
#   ('와아', 'O'),
#   (' ', 'O'),
#   ('어떻게', 'O'),
#   (' ', 'O'),
#   ('이렇게', 'O'),
#   (' ', 'O'),
#   ('잘', 'O'),
#   (' ', 'O'),
#   ('불러?', 'O'),
#   (' ', 'O'),
#   ('역시', 'O'),
#   (' ', 'O'),
#   ('비투비', 'PERSON'),
#   ('…', 'O'),
#   (' ', 'O'),
#   ('역시', 'O'),
#   (' ', 'O'),
#   ('이창섭', 'PERSON')],
#  [('10년 대', 'DATE'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('아직도', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('잘했어', 'O'),
#   (' ', 'O'),
#   ('놀라게', 'O'),
#   (' ', 'O'),
#   ('해', 'O')],
#  [('사랑해', 'O'), (' ', 'O'), ('이창섭', 'PERSON'), (' ', 'O'), ('사랑한다고!!!', 'O')],
#  [('저', 'O'),
#   (' ', 'O'),
#   ('일본', 'COUNTRY'),
#   ('사람인데', 'O'),
#   (' ', 'O'),
#   ('오빠', 'CIVILIZATION'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('부르면', 'O'),
#   (' ', 'O'),
#   ('또', 'O'),
#   (' ', 'O'),
#   ('느낌이', 'O'),
#   (' ', 'O'),
#   ('달라서', 'O'),
#   (' ', 'O'),
#   ('멋져요…진짜로', 'O')],
#  [("'", 'O'),
#   ('미즈노 아츠 - 살다', 'ARTIFACT'),
#   ("'", 'O'),
#   (' ', 'O'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('불러주면', 'O'),
#   (' ', 'O'),
#   ('좋겠다', 'O')],
#  [('은광', 'PERSON'),
#   ('이형', 'CIVILIZATION'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('언젠가', 'O'),
#   (' ', 'O'),
#   ('어떤', 'O'),
#   (' ', 'O'),
#   ('프로에', 'O'),
#   (' ', 'O'),
#   ('나와서', 'O'),
#   (' ', 'O'),
#   ('본인의', 'O'),
#   (' ', 'O'),
#   ('목소리를', 'O'),
#   (' ', 'O'),
#   ('그제서야', 'O'),
#   (' ', 'O'),
#   ('찾은', 'O'),
#   (' ', 'O'),
#   ('것', 'O'),
#   (' ', 'O'),
#   ('같다고', 'O'),
#   (' ', 'O'),
#   ('인터뷰했던', 'O'),
#   (' ', 'O'),
#   ('거', 'O'),
#   (' ', 'O'),
#   ('같은데,', 'O'),
#   (' ', 'O'),
#   ('창섭', 'PERSON'),
#   ('이도', 'O'),
#   (' ', 'O'),
#   ('그저', 'O'),
#   (' ', 'O'),
#   ('예쁘고', 'O'),
#   (' ', 'O'),
#   ('듣기', 'O'),
#   (' ', 'O'),
#   ('좋은', 'O'),
#   (' ', 'O'),
#   ('소리(그건', 'O'),
#   (' ', 'O'),
#   ('그거대로', 'O'),
#   (' ', 'O'),
#   ('또', 'O'),
#   (' ', 'O'),
#   ('좋지만)를', 'O'),
#   (' ', 'O'),
#   ('넘어서', 'O'),
#   (' ', 'O'),
#   ('이창섭', 'PERSON'),
#   ('이라는', 'O'),
#   (' ', 'O'),
#   ('사람의', 'O'),
#   (' ', 'O'),
#   ('시그니쳐', 'O'),
#   (' ', 'O'),
#   ('목소리를', 'O'),
#   (' ', 'O'),
#   ('만들고,', 'O'),
#   (' ', 'O'),
#   ('또', 'O'),
#   (' ', 'O'),
#   ('만들어가고', 'O'),
#   (' ', 'O'),
#   ('있는', 'O'),
#   (' ', 'O'),
#   ('것', 'O'),
#   (' ', 'O'),
#   ('같다', 'O')],
#  [('0:27', 'QUANTITY'),
#   (' ', 'O'),
#   ('미국인', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('프니', 'PERSON'),
#   ('한테', 'O'),
#   (' ', 'O'),
#   ('영어', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('많다고', 'O'),
#   (' ', 'O'),
#   ('하고', 'O'),
#   (' ', 'O'),
#   ('자각하는', 'O'),
#   (' ', 'O'),
#   ('뎨', 'O'),
#   (' ', 'O'),
#   ('1:08', 'TIME'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('하리보', 'PERSON'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('춤추는', 'O'),
#   (' ', 'O'),
#   ('거', 'O'),
#   (' ', 'O'),
#   ('같아', 'O')],
#  [('ㅜ', 'O'),
#   (' ', 'O'),
#   ('2:10', 'QUANTITY'),
#   (' ', 'O'),
#   ('지짜', 'O'),
#   (' ', 'O'),
#   ('깨물어주고', 'O'),
#   (' ', 'O'),
#   ('싶다', 'O'),
#   (' ', 'O'),
#   ('ㅜ', 'O'),
#   (' ', 'O'),
#   ('다들', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('귀여워', 'O'),
#   (' ', 'O'),
#   ('하', 'O')],
#  [('ㅜ', 'O'),
#   (' ', 'O'),
#   ('2:34', 'TIME'),
#   (' ', 'O'),
#   ('이래놓고', 'O'),
#   (' ', 'O'),
#   ('100점', 'QUANTITY'),
#   (' ', 'O'),
#   ('나오니까', 'O'),
#   (' ', 'O'),
#   ('곰돌이', 'ANIMAL'),
#   (' ', 'O'),
#   ('같이', 'O'),
#   (' ', 'O'),
#   ('덩실덩실', 'O'),
#   (' ', 'O'),
#   ('귀엽게', 'O'),
#   (' ', 'O'),
#   ('춤추는거', 'O'),
#   (' ', 'O'),
#   ('ㄹㅇ', 'O'),
#   (' ', 'O'),
#   ('발린다', 'O')],
#  [('노래', 'O'),
#   (' ', 'O'),
#   ('잘', 'O'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('남자', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('좋다', 'O')],
#  [('와', 'O'),
#   (' ', 'O'),
#   ('옛날부터', 'O'),
#   (' ', 'O'),
#   ('좋아하던', 'O'),
#   (' ', 'O'),
#   ('노랜데', 'O')],
#  [('노래는', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('항상', 'O'),
#   (' ', 'O'),
#   ('듣던건데', 'O'),
#   (' ', 'O'),
#   ('새삼스레', 'O'),
#   (' ', 'O'),
#   ('미치겠고', 'O'),
#   (' ', 'O'),
#   ('모자까지', 'O'),
#   (' ', 'O'),
#   ('컨셉진짜', 'O'),
#   (' ', 'O'),
#   ('미쳤다', 'O')],
#  [('와', 'O'),
#   (' ', 'O'),
#   ('이노래', 'O'),
#   (' ', 'O'),
#   ('학생', 'OCCUPATION'),
#   ('때', 'O'),
#   (' ', 'O'),
#   ('엄청', 'O'),
#   (' ', 'O'),
#   ('좋아했던', 'O'),
#   (' ', 'O'),
#   ('노랜데', 'O')],
#  [('제발', 'O'),
#   (' ', 'O'),
#   ('박효신', 'PERSON'),
#   ('님의', 'O'),
#   (' ', 'O'),
#   ("'숨'도", 'O'),
#   (' ', 'O'),
#   ('커버해주세요', 'O')],
#  [('힘들고', 'O'),
#   (' ', 'O'),
#   ('지칠때', 'O'),
#   (' ', 'O'),
#   ('듣는', 'O'),
#   (' ', 'O'),
#   ('노래입니다', 'O')],
#  [('로', 'ARTIFACT'),
#   ('직', 'O'),
#   (' ', 'O'),
#   ('노래', 'O'),
#   (' ', 'O'),
#   ('듣고', 'O'),
#   (' ', 'O'),
#   ('그', 'O'),
#   (' ', 'O'),
#   ('다음으로', 'O'),
#   (' ', 'O'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('노래를', 'O'),
#   (' ', 'O'),
#   ('들으려', 'O'),
#   (' ', 'O'),
#   ('왔는데', 'O'),
#   (' ', 'O'),
#   ('창섭', 'PERSON'),
#   ('님의', 'O'),
#   (' ', 'O'),
#   ('노래를', 'O'),
#   (' ', 'O'),
#   ('들으며', 'O'),
#   (' ', 'O'),
#   ('더', 'O'),
#   (' ', 'O'),
#   ('힘이나네요', 'O')],
#  [('오랜만에', 'O'),
#   (' ', 'O'),
#   ('우연히', 'O'),
#   (' ', 'O'),
#   ('이끌려', 'O'),
#   (' ', 'O'),
#   ('왔는데', 'O'),
#   (' ', 'O'),
#   ('오빠', 'CIVILIZATION'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('여전하네요', 'O')],
#  [('예전에', 'O'),
#   (' ', 'O'),
#   ('at the end', 'ARTIFACT'),
#   (' ', 'O'),
#   ('들으면서', 'O'),
#   (' ', 'O'),
#   ('한참', 'O'),
#   (' ', 'O'),
#   ('울고', 'O'),
#   (' ', 'O'),
#   ('그랬는데', 'O'),
#   (' ', 'O'),
#   ('이제는', 'O'),
#   (' ', 'O'),
#   ('오빠', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('노래', 'O'),
#   (' ', 'O'),
#   ('편하게', 'O'),
#   (' ', 'O'),
#   ('들을', 'O'),
#   (' ', 'O'),
#   ('수', 'O'),
#   (' ', 'O'),
#   ('있을', 'O'),
#   (' ', 'O'),
#   ('것', 'O'),
#   (' ', 'O'),
#   ('같아요', 'O')],
#  [('가장', 'O'),
#   (' ', 'O'),
#   ('힘들던', 'O'),
#   (' ', 'O'),
#   ('시절', 'O'),
#   (' ', 'O'),
#   ('내가', 'O'),
#   (' ', 'O'),
#   ('기댈', 'O'),
#   (' ', 'O'),
#   ('수', 'O'),
#   (' ', 'O'),
#   ('있는', 'O'),
#   (' ', 'O'),
#   ('지지대가', 'O'),
#   (' ', 'O'),
#   ('되어줘서', 'O'),
#   (' ', 'O'),
#   ('고마웠고,', 'O'),
#   (' ', 'O'),
#   ('여전히', 'O'),
#   (' ', 'O'),
#   ('좋은', 'O'),
#   (' ', 'O'),
#   ('노래', 'O'),
#   (' ', 'O'),
#   ('들려줘서', 'O'),
#   (' ', 'O'),
#   ('고마워요', 'O')],
#  [('진짜', 'O'),
#   (' ', 'O'),
#   ('눈물난다', 'O'),
#   (' ', 'O'),
#   ('어떻게', 'O'),
#   (' ', 'O'),
#   ('첫', 'O'),
#   (' ', 'O'),
#   ('소절부터', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('먹먹히게', 'O'),
#   (' ', 'O'),
#   ('잘', 'O'),
#   (' ', 'O'),
#   ('부르지?', 'O'),
#   (' ', 'O'),
#   ('목소리부터', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('창섭', 'PERSON'),
#   ('님', 'O'),
#   (' ', 'O'),
#   ('곡인것처럼', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('찰떡임', 'O'),
#   (' ', 'O'),
#   ('ㅠㅠㅠ', 'O'),
#   (' ', 'O'),
#   ('loser', 'ARTIFACT'),
#   ('라는', 'O'),
#   (' ', 'O'),
#   ('곡도', 'O'),
#   (' ', 'O'),
#   ('어울리실듯', 'O')],
#  [('맞다', 'O'),
#   (' ', 'O'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('분', 'O'),
#   (' ', 'O'),
#   ('가수', 'CIVILIZATION'),
#   ('였지…', 'O'),
#   ('예능인', 'OCCUPATION'),
#   (' ', 'O'),
#   ('아니였지…', 'O')],
#  [('왁,,', 'O'),
#   (' ', 'O'),
#   ('이노래를', 'O'),
#   (' ', 'O'),
#   ('불러줄지', 'O'),
#   (' ', 'O'),
#   ('몰랐다,,', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('좋은', 'O'),
#   (' ', 'O'),
#   ('노래,,,', 'O')],
#  [('창섭', 'PERSON'),
#   ('오빠', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('평생', 'O'),
#   (' ', 'O'),
#   ('음악해주세요', 'O'),
#   (' ', 'O'),
#   ('항상응원하', 'O'),
#   ('눈', 'ANIMAL'),
#   (' ', 'O'),
#   ('팬', 'OCCUPATION'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('될께요', 'O')],
#  [('우와', 'O'),
#   (' ', 'O'),
#   ('우연히', 'O'),
#   (' ', 'O'),
#   ('들어온', 'O'),
#   (' ', 'O'),
#   ('타팬', 'O'),
#   (' ', 'O'),
#   ('일본인', 'CIVILIZATION'),
#   ('인데', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('잘한다', 'O')],
#  [('2:08', 'TIME'),
#   (' ', 'O'),
#   ('아', 'O'),
#   (' ', 'O'),
#   ('응강', 'O'),
#   ('오빠', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('졸귀네', 'O'),
#   (' ', 'O'),
#   ('ㅋㅋㅋㅋㅋㅋㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('자리찾아서', 'O'),
#   (' ', 'O'),
#   ('뽈뽈뽈', 'O'),
#   (' ', 'O'),
#   ('ㅎㅎ', 'O')],
#  [('진짜,,', 'O'),
#   (' ', 'O'),
#   ('뭔가', 'O'),
#   (' ', 'O'),
#   ('심장', 'TERM'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('아리는', 'O'),
#   (' ', 'O'),
#   ('기분,,', 'O'),
#   (' ', 'O'),
#   ('일주일', 'DATE'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('넘도록', 'O'),
#   (' ', 'O'),
#   ('계속', 'O'),
#   (' ', 'O'),
#   ('듣고', 'O'),
#   (' ', 'O'),
#   ('있는데', 'O'),
#   (' ', 'O'),
#   ('이걸', 'O'),
#   (' ', 'O'),
#   ('처음', 'O'),
#   (' ', 'O'),
#   ('들을', 'O'),
#   (' ', 'O'),
#   ('때로', 'O'),
#   (' ', 'O'),
#   ('돌아가고', 'O'),
#   (' ', 'O'),
#   ('싶다', 'O')],
#  [('그', 'O'),
#   (' ', 'O'),
#   ('때의', 'O'),
#   (' ', 'O'),
#   ('벅참과', 'O'),
#   (' ', 'O'),
#   ('쓰라림을', 'O'),
#   (' ', 'O'),
#   ('다시', 'O'),
#   (' ', 'O'),
#   ('느끼고', 'O'),
#   (' ', 'O'),
#   ('싶어', 'O'),
#   (' ', 'O'),
#   ('지금은,,', 'O'),
#   (' ', 'O'),
#   ('친한', 'O'),
#   (' ', 'O'),
#   ('친구', 'CIVILIZATION'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('괜찮다고', 'O'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('기분이고', 'O'),
#   (' ', 'O'),
#   ('처음', 'O'),
#   (' ', 'O'),
#   ('들었을', 'O'),
#   (' ', 'O'),
#   ('때는', 'O'),
#   (' ', 'O'),
#   ('길에서', 'O'),
#   (' ', 'O'),
#   ('내가', 'O'),
#   (' ', 'O'),
#   ('펑펑', 'O'),
#   (' ', 'O'),
#   ('울고', 'O'),
#   (' ', 'O'),
#   ('있을', 'O'),
#   (' ', 'O'),
#   ('때', 'O'),
#   (' ', 'O'),
#   ('모르는', 'O'),
#   (' ', 'O'),
#   ('누군가가', 'O'),
#   (' ', 'O'),
#   ('가만히', 'O'),
#   (' ', 'O'),
#   ('나에게', 'O'),
#   (' ', 'O'),
#   ('옷', 'O'),
#   (' ', 'O'),
#   ('덮어주고', 'O'),
#   (' ', 'O'),
#   ('가는', 'O'),
#   (' ', 'O'),
#   ('기분이야', 'O'),
#   (' ', 'O'),
#   ('무심하게', 'O'),
#   (' ', 'O'),
#   ('옷', 'O'),
#   (' ', 'O'),
#   ('덮어주고', 'O'),
#   (' ', 'O'),
#   ('가버리는', 'O'),
#   (' ', 'O'),
#   ('그래서', 'O'),
#   (' ', 'O'),
#   ('더', 'O'),
#   (' ', 'O'),
#   ('위로되고', 'O'),
#   (' ', 'O'),
#   ('눈물나는', 'O')],
#  [('맨날', 'O'),
#   (' ', 'O'),
#   ('죽으려고할때마다', 'O'),
#   (' ', 'O'),
#   ('울면서', 'O'),
#   (' ', 'O'),
#   ('들어서', 'O'),
#   (' ', 'O'),
#   ('그런지', 'O'),
#   (' ', 'O'),
#   ('맨정신으로', 'O'),
#   (' ', 'O'),
#   ('듣는거', 'O'),
#   (' ', 'O'),
#   ('첨이다', 'O'),
#   (' ', 'O'),
#   ('그만큼', 'O'),
#   (' ', 'O'),
#   ('나', 'O'),
#   (' ', 'O'),
#   ('이제', 'O'),
#   (' ', 'O'),
#   ('괜찮아졌구나', 'O')],
#  [('진짜', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('귀여오미치겐눼,,,,,,,,,ㅠㅠㅠㅠㅠㅠㅠ', 'O')],
#  [('42:57', 'TIME'),
#   (' ', 'O'),
#   ('프니', 'PERSON'),
#   ('와', 'O'),
#   (' ', 'O'),
#   ('섭이', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('작당모의^_^', 'O'),
#   (' ', 'O'),
#   ('1:01:40', 'TIME'),
#   (' ', 'O'),
#   ('결과ㅋㅋㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('1:01:50', 'TIME'),
#   (' ', 'O'),
#   ('귀여웡💙💙', 'O')],
#  [('이창섭', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('노래에', 'O'),
#   (' ', 'O'),
#   ('정말', 'O'),
#   (' ', 'O'),
#   ('진심이구나', 'O')],
#  [('?', 'O'),
#   (' ', 'O'),
#   ('평소에', 'O'),
#   (' ', 'O'),
#   ('좋아하는', 'O'),
#   (' ', 'O'),
#   ('노래를', 'O'),
#   (' ', 'O'),
#   ('호감인', 'O'),
#   (' ', 'O'),
#   ('사람이', 'O'),
#   (' ', 'O'),
#   ('부른다', 'O')],
#  [('성재', 'PERSON'),
#   ('야', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('멋있어', 'O'),
#   (' ', 'O'),
#   ('어떻게', 'O'),
#   (' ', 'O'),
#   ('<', 'O'),
#   ('3', 'QUANTITY')],
#  [('헠', 'O'),
#   (' ', 'O'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('노래를', 'O'),
#   (' ', 'O'),
#   ('커버해주시다니ㅠㅠㅠㅠㅠㅠ', 'O'),
#   (' ', 'O'),
#   ('역시', 'O'),
#   (' ', 'O'),
#   ('믿고', 'O'),
#   (' ', 'O'),
#   ('듣는', 'O'),
#   (' ', 'O'),
#   ('비투비', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('믿고', 'O'),
#   (' ', 'O'),
#   ('듣는', 'O'),
#   (' ', 'O'),
#   ('이창섭', 'PERSON')],
#  [('Happy', 'O'),
#   (' ', 'O'),
#   ('Ateez', 'O'),
#   (' ', 'O'),
#   ('🖤\U0001f90d🕊😍', 'O'),
#   (' ', 'O'),
#   ('Handsomest', 'O'),
#   (' ', 'O'),
#   ('Humble', 'O'),
#   (' ', 'O'),
#   ('Epic', 'O')],
#  [("I'm", 'O'),
#   (' ', 'O'),
#   ('your', 'O'),
#   (' ', 'O'),
#   ('number', 'O'),
#   (' ', 'O'),
#   ('1', 'QUANTITY'),
#   (' ', 'O'),
#   ('fan', 'O'),
#   (' ', 'O'),
#   ('😄', 'O')],
#  [('에이티즈', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('항상', 'O'),
#   (' ', 'O'),
#   ('행복할', 'O'),
#   (' ', 'O'),
#   ('것', 'O'),
#   (' ', 'O'),
#   ('꼭', 'O'),
#   (' ', 'O'),
#   ('그래야만', 'O'),
#   (' ', 'O'),
#   ('돼', 'O'),
#   (' ', 'O'),
#   ('덕분에', 'O'),
#   (' ', 'O'),
#   ('내가', 'O'),
#   (' ', 'O'),
#   ('오늘', 'DATE'),
#   (' ', 'O'),
#   ('하루', 'DATE'),
#   (' ', 'O'),
#   ('많이', 'O'),
#   (' ', 'O'),
#   ('행복했으니까', 'O')],
#  [('나연', 'PERSON'),
#   ('이는', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('왜케', 'O'),
#   (' ', 'O'),
#   ('부드럽게', 'O'),
#   (' ', 'O'),
#   ('잘추냐', 'O'),
#   (' ', 'O'),
#   ('선이', 'O'),
#   (' ', 'O'),
#   ('계속', 'O'),
#   (' ', 'O'),
#   ('이어지는데', 'O'),
#   (' ', 'O'),
#   ('대단스', 'O')],
#  [('근데왜', 'O'),
#   (' ', 'O'),
#   ('타투를', 'O'),
#   (' ', 'O'),
#   ('많이햇냐?', 'O'),
#   (' ', 'O'),
#   ('지우개로', 'O'),
#   (' ', 'O'),
#   ('없에고', 'O'),
#   (' ', 'O'),
#   ('싶네', 'O')],
#  [('안녕하세요', 'O'),
#   (' ', 'O'),
#   ('당신은', 'O'),
#   (' ', 'O'),
#   ('매우', 'O'),
#   (' ', 'O'),
#   ('아름답습니다', 'O'),
#   (' ', 'O'),
#   ('나는', 'O'),
#   (' ', 'O'),
#   ('당신의', 'O'),
#   (' ', 'O'),
#   ('팬', 'OCCUPATION'),
#   ('입니다', 'O'),
#   (' ', 'O'),
#   ('당신은', 'O'),
#   (' ', 'O'),
#   ('매우', 'O'),
#   (' ', 'O'),
#   ('아름답습니까?', 'O')],
#  [('🌹😘', 'O'),
#   (' ', 'O'),
#   ('MINA', 'O'),
#   (' ', 'O'),
#   ('FOR', 'O'),
#   (' ', 'O'),
#   ('EVER', 'O'),
#   (' ', 'O'),
#   ('💌', 'O')],
#  [('나는', 'O'),
#   (' ', 'O'),
#   ('우리가', 'O'),
#   (' ', 'O'),
#   ('당신을', 'O'),
#   (' ', 'O'),
#   ('사랑', 'O'),
#   (' ', 'O'),
#   ('당신으로이', 'O'),
#   (' ', 'O'),
#   ('자랑스러운', 'O'),
#   (' ', 'O'),
#   ('커버', 'O'),
#   (' ', 'O'),
#   ('광산', 'O'),
#   (' ', 'O'),
#   ('열한', 'QUANTITY'),
#   (' ', 'O'),
#   ('사랑', 'O'),
#   (' ', 'O'),
#   ('💓💓💓', 'O')],
#  [('원래', 'O'),
#   (' ', 'O'),
#   ('이쁜건', 'O'),
#   (' ', 'O'),
#   ('알았지만', 'O'),
#   (' ', 'O'),
#   ('여전히', 'O'),
#   (' ', 'O'),
#   ('싱그럽고', 'O'),
#   (' ', 'O'),
#   ('아름답구나', 'O'),
#   (' ', 'O'),
#   ('😍😚💕', 'O'),
#   (' ', 'O'),
#   ('그저', 'O'),
#   (' ', 'O'),
#   ('행복하고', 'O'),
#   (' ', 'O'),
#   ('정신적,', 'O'),
#   (' ', 'O'),
#   ('육체적으로', 'O'),
#   (' ', 'O'),
#   ('매우', 'O'),
#   (' ', 'O'),
#   ('건강하길', 'O'),
#   (' ', 'O'),
#   ('바란다', 'O')],
#  [('ㅜㅜ', 'O'),
#   (' ', 'O'),
#   ('뿌까머리', 'O'),
#   (' ', 'O'),
#   ('한번만', 'QUANTITY'),
#   (' ', 'O'),
#   ('해주라', 'O')],
#  [('나연', 'PERSON'),
#   ('언니', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('다음영상때', 'O'),
#   (' ', 'O'),
#   ('뿌까머리하고', 'O'),
#   (' ', 'O'),
#   ('나오면', 'O'),
#   (' ', 'O'),
#   ('나', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('소원없을거', 'O'),
#   (' ', 'O'),
#   ('같아', 'O')],
#  [('귀여워', 'O'),
#   (' ', 'O'),
#   ('(*', 'O'),
#   (' ', 'O'),
#   ('*)', 'O'),
#   (' ', 'O'),
#   ('♡', 'O')],
#  [('때', 'O'),
#   (' ', 'O'),
#   ('이른', 'O'),
#   (' ', 'O'),
#   ('봄', 'DATE'),
#   (' ', 'O'),
#   ('몇', 'O'),
#   (' ', 'O'),
#   ('송이', 'O'),
#   (' ', 'O'),
#   ('꺾어다', 'O'),
#   (' ', 'O'),
#   ('너의', 'O'),
#   (' ', 'O'),
#   ('방', 'O'),
#   (' ', 'O'),
#   ('문', 'O'),
#   (' ', 'O'),
#   ('앞', 'TERM'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('두었어', 'O'),
#   (' ', 'O'),
#   ('긴', 'O'),
#   (' ', 'O'),
#   ('잠', 'O'),
#   (' ', 'O'),
#   ('실컷', 'O'),
#   (' ', 'O'),
#   ('자고', 'O'),
#   (' ', 'O'),
#   ('나오면', 'O'),
#   (' ', 'O'),
#   ('그때쯤엔', 'O'),
#   (' ', 'O'),
#   ('예쁘게', 'O'),
#   (' ', 'O'),
#   ('피어', 'O'),
#   (' ', 'O'),
#   ('있겠다', 'O'),
#   (' ', 'O'),
#   ('별', 'O'),
#   (' ', 'O'),
#   ('띄운', 'O'),
#   (' ', 'O'),
#   ('여름', 'DATE'),
#   (' ', 'O'),
#   ('한 컵', 'QUANTITY'),
#   (' ', 'O'),
#   ('따라다', 'O'),
#   (' ', 'O'),
#   ('너의', 'O'),
#   (' ', 'O'),
#   ('머리맡에', 'O'),
#   (' ', 'O'),
#   ('두었어', 'O'),
#   (' ', 'O'),
#   ('금세', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('녹아버릴', 'O'),
#   (' ', 'O'),
#   ('텐데', 'O'),
#   (' ', 'O'),
#   ('너는', 'O'),
#   (' ', 'O'),
#   ('아직', 'O'),
#   (' ', 'O'),
#   ('혼자', 'O'),
#   (' ', 'O'),
#   ('쉬고', 'O'),
#   (' ', 'O'),
#   ('싶은가', 'O'),
#   (' ', 'O'),
#   ('봐', 'O'),
#   (' ', 'O'),
#   ('너', 'O'),
#   (' ', 'O'),
#   ('없이', 'O'),
#   (' ', 'O'),
#   ('보는', 'O'),
#   (' ', 'O'),
#   ('첫', 'O'),
#   (' ', 'O'),
#   ('봄', 'DATE'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('여름', 'DATE'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('괜히', 'O'),
#   (' ', 'O'),
#   ('왜', 'O'),
#   (' ', 'O'),
#   ('이렇게', 'O'),
#   (' ', 'O'),
#   ('예쁘니', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('가기', 'O'),
#   (' ', 'O'),
#   ('전에', 'O'),
#   (' ', 'O'),
#   ('널', 'O'),
#   (' ', 'O'),
#   ('보여줘야', 'O'),
#   (' ', 'O'),
#   ('하는데', 'O'),
#   (' ', 'O'),
#   ('음', 'O'),
#   (' ', 'O'),
#   ('꼭', 'O'),
#   (' ', 'O'),
#   ('봐야', 'O'),
#   (' ', 'O'),
#   ('하는데', 'O'),
#   (' ', 'O'),
#   ('내게', 'O'),
#   (' ', 'O'),
#   ('기대어', 'O'),
#   (' ', 'O'),
#   ('조각잠을', 'O'),
#   (' ', 'O'),
#   ('자던', 'O'),
#   (' ', 'O'),
#   ('그', 'O'),
#   (' ', 'O'),
#   ('모습', 'O'),
#   (' ', 'O'),
#   ('그대로', 'O'),
#   (' ', 'O'),
#   ('잠들었구나', 'O'),
#   (' ', 'O'),
#   ('무슨', 'O'),
#   (' ', 'O'),
#   ('꿈을', 'O'),
#   (' ', 'O'),
#   ('꾸니', 'O'),
#   (' ', 'O'),
#   ('깨어나면', 'O'),
#   (' ', 'O'),
#   ('이야기해', 'O'),
#   (' ', 'O'),
#   ('줄', 'O'),
#   (' ', 'O'),
#   ('거지', 'O'),
#   (' ', 'O'),
#   ('언제나의', 'O'),
#   (' ', 'O'),
#   ('아침', 'TIME'),
#   ('처럼', 'O'),
#   (' ', 'O'),
#   ('음', 'O'),
#   (' ', 'O'),
#   ('빼곡한', 'O'),
#   (' ', 'O'),
#   ('가을', 'DATE'),
#   (' ', 'O'),
#   ('한 장', 'QUANTITY'),
#   (' ', 'O'),
#   ('접어다', 'O'),
#   (' ', 'O'),
#   ('너의', 'O'),
#   (' ', 'O'),
#   ('우체통에', 'O'),
#   (' ', 'O'),
#   ('넣었어', 'O'),
#   (' ', 'O'),
#   ('가장', 'O'),
#   (' ', 'O'),
#   ('좋았던', 'O'),
#   (' ', 'O'),
#   ('문장', 'O'),
#   (' ', 'O'),
#   ('아', 'TERM'),
#   ('래', 'O'),
#   (' ', 'O'),
#   ('밑줄', 'O'),
#   (' ', 'O'),
#   ('그어', 'O'),
#   (' ', 'O'),
#   ('나', 'O'),
#   (' ', 'O'),
#   ('만나면', 'O'),
#   (' ', 'O'),
#   ('읽어줄래', 'O'),
#   (' ', 'O'),
#   ('새하얀', 'O'),
#   (' ', 'O'),
#   ('겨울', 'DATE'),
#   (' ', 'O'),
#   ('한', 'O'),
#   (' ', 'O'),
#   ('숨', 'O'),
#   (' ', 'O'),
#   ('속에다', 'O'),
#   (' ', 'O'),
#   ('나의', 'O'),
#   (' ', 'O'),
#   ('혼잣말을', 'O'),
#   (' ', 'O'),
#   ('담았어', 'O'),
#   (' ', 'O'),
#   ('줄곧', 'O'),
#   (' ', 'O'),
#   ('잘', 'O'),
#   (' ', 'O'),
#   ('참아내다가도', 'O'),
#   (' ', 'O'),
#   ('가끔은', 'O'),
#   (' ', 'O'),
#   ('철없이', 'O'),
#   (' ', 'O'),
#   ('보고', 'O'),
#   (' ', 'O'),
#   ('싶어', 'O'),
#   (' ', 'O'),
#   ('새삼', 'O'),
#   (' ', 'O'),
#   ('차가운', 'O'),
#   (' ', 'O'),
#   ('연말', 'DATE'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('공기가', 'O'),
#   (' ', 'O'),
#   ('뼈', 'TERM'),
#   (' ', 'O'),
#   ('틈', 'O'),
#   (' ', 'O'),
#   ('사이사이', 'O'),
#   (' ', 'O'),
#   ('시려와', 'O'),
#   (' ', 'O'),
#   ('움츠려', 'O'),
#   (' ', 'O'),
#   ('있을', 'O'),
#   (' ', 'O'),
#   ('너의', 'O'),
#   (' ', 'O'),
#   ('그', 'O'),
#   (' ', 'O'),
#   ('마른', 'O'),
#   (' ', 'O'),
#   ('어깨', 'ANIMAL'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('꼭', 'O'),
#   (' ', 'O'),
#   ('안아줘야', 'O'),
#   (' ', 'O'),
#   ('하는데', 'O'),
#   (' ', 'O'),
#   ('내게', 'O'),
#   (' ', 'O'),
#   ('기대어', 'O'),
#   (' ', 'O'),
#   ('조각잠을', 'O'),
#   (' ', 'O'),
#   ('자던', 'O'),
#   (' ', 'O'),
#   ('그', 'O'),
#   (' ', 'O'),
#   ('모습', 'O'),
#   (' ', 'O'),
#   ('그대로', 'O'),
#   (' ', 'O'),
#   ('잠들었구나', 'O'),
#   (' ', 'O'),
#   ('무슨', 'O'),
#   (' ', 'O'),
#   ('꿈을', 'O'),
#   (' ', 'O'),
#   ('꾸니', 'O'),
#   (' ', 'O'),
#   ('깨어나면', 'O'),
#   (' ', 'O'),
#   ('이야기해', 'O'),
#   (' ', 'O'),
#   ('줄', 'O'),
#   (' ', 'O'),
#   ('거지', 'O'),
#   (' ', 'O'),
#   ('언제나의', 'O'),
#   (' ', 'O'),
#   ('아침', 'TIME'),
#   ('처럼', 'O'),
#   (' ', 'O'),
#   ('음', 'O')],
#  [('코로나', 'EVENT'),
#   (' ', 'O'),
#   ('끝나서', 'O'),
#   (' ', 'O'),
#   ('징짱', 'PERSON'),
#   (' ', 'O'),
#   ('콘서트장', 'O'),
#   (' ', 'O'),
#   ('가고', 'O'),
#   (' ', 'O'),
#   ('싶다', 'O')],
#  [('겨울', 'DATE'),
#   ('잠', 'O'),
#   (' ', 'O'),
#   ('최고~~~조각집', 'O'),
#   (' ', 'O'),
#   ('앨범', 'O'),
#   (' ', 'O'),
#   ('끝없이', 'O'),
#   (' ', 'O'),
#   ('흥행합시다', 'O'),
#   (' ', 'O'),
#   ('ㅎㅎ', 'O')],
#  [('연말', 'DATE'),
#   (' ', 'O'),
#   ('선물', 'O'),
#   (' ', 'O'),
#   ('사랑해요', 'O'),
#   (' ', 'O'),
#   ('해피뉴이어', 'ARTIFACT'),
#   (' ', 'O'),
#   ('22년도', 'DATE'),
#   (' ', 'O'),
#   ('우리', 'O'),
#   (' ', 'O'),
#   ('함께해요!', 'O'),
#   (' ', 'O'),
#   ('💖', 'O')],
#  [('왜', 'O'),
#   (' ', 'O'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('노래', 'O'),
#   (' ', 'O'),
#   ('들으면', 'O'),
#   (' ', 'O'),
#   ('울컥하는지', 'O')],
#  [('다른', 'O'),
#   (' ', 'O'),
#   ('곡들도', 'O'),
#   (' ', 'O'),
#   ('좋지만', 'O'),
#   (' ', 'O'),
#   ('나한테', 'O'),
#   (' ', 'O'),
#   ('겨울', 'DATE'),
#   ('잠이', 'O'),
#   (' ', 'O'),
#   ('제일', 'O'),
#   (' ', 'O'),
#   ('좋다', 'O')],
#  [('2022년', 'DATE'),
#   (' ', 'O'),
#   ('5시간전', 'TIME'),
#   (' ', 'O'),
#   ('최고의', 'O'),
#   (' ', 'O'),
#   ('선물', 'O')],
#  [('올해', 'DATE'),
#   (' ', 'O'),
#   ('마지막', 'O'),
#   (' ', 'O'),
#   ('선물', 'O'),
#   (' ', 'O'),
#   ('고마워요', 'O'),
#   (' ', 'O'),
#   ('☺', 'O')],
#  [('언니', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('사랑래', 'O'),
#   (' ', 'O'),
#   ('시즌그리팅도', 'O'),
#   (' ', 'O'),
#   ('잘', 'O'),
#   (' ', 'O'),
#   ('간직할게♡', 'O')],
#  [('MY', 'O'),
#   (' ', 'O'),
#   ('LOOOVE!!!!!!!!🥰🥰🥰🥰🥰😘😘😘', 'O'),
#   (' ', 'O'),
#   ('노래좋다!!!!!!!!', 'O'),
#   (' ', 'O'),
#   ('🥰🥰🥰🥰🥰😘😘😘', 'O')],
#  [('그나저나', 'O'),
#   (' ', 'O'),
#   ('가사', 'O'),
#   (' ', 'O'),
#   ('뭐임ㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('사실상', 'O'),
#   (' ', 'O'),
#   ('시집', 'O')],
#  [('왁', 'PERSON'),
#   ('씨', 'O'),
#   (' ', 'O'),
#   ('활동', 'O'),
#   (' ', 'O'),
#   ('비하인드', 'O'),
#   (' ', 'O'),
#   ('ㅎㅎㅎ', 'O'),
#   (' ', 'O'),
#   ('ㅎㅎ', 'O'),
#   (' ', 'O'),
#   ('ㅎㅎㅎㅎ', 'O'),
#   (' ', 'O'),
#   (',,,', 'O'),
#   (' ', 'O'),
#   ('시작부터', 'O'),
#   (' ', 'O'),
#   ('쏘큐티', 'O'),
#   (' ', 'O'),
#   ('인성과', 'O'),
#   (' ', 'O'),
#   ('아이엠그라운드', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('ㅋㅋㄹㄹㅋㄹㅋㄹㅋㄹㅋㄹㅋㄹㅋㄹㅋㄹㅋㄹㅋㄹㅋㄹㅋㄹㅋㄹㅋㄹㅋㄹㅋㄹㅋㄹㅋㄹㅋㄹㅋㄹㅋㄹㅋ', 'O'),
#   (' ', 'O'),
#   ('벌써웃기고잉', 'O'),
#   (' ', 'O'),
#   ('판타지', 'O'),
#   (' ', 'O'),
#   ('맘잘알', 'O'),
#   (' ', 'O'),
#   ('이상혁', 'PERSON'),
#   (' ', 'O'),
#   (',,,,,,', 'O'),
#   (' ', 'O'),
#   ('알러뷰', 'O'),
#   (' ', 'O'),
#   ('에세푸✨\U0001f90d', 'O')],
#  [('오늘', 'DATE'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('눈부시게', 'O'),
#   (' ', 'O'),
#   ('빛나는', 'O'),
#   (' ', 'O'),
#   ('SF9', 'ARTIFACT'),
#   (' ', 'O'),
#   ('Fighting!', 'O'),
#   (' ', 'O'),
#   (':)', 'O')],
#  [('저같은', 'O'),
#   (' ', 'O'),
#   ('아이돌린이에게', 'O'),
#   (' ', 'O'),
#   ('저', 'O'),
#   (' ', 'O'),
#   ('코디는', 'O'),
#   (' ', 'O'),
#   ('정말정말', 'O'),
#   (' ', 'O'),
#   ('좋아요', 'O')],
#  [('아,', 'O'),
#   (' ', 'O'),
#   ('주호', 'PERSON'),
#   ('구나,', 'O'),
#   (' ', 'O'),
#   ('영빈', 'PERSON'),
#   ('이구나', 'O'),
#   (' ', 'O'),
#   ('딱딱', 'O'),
#   (' ', 'O'),
#   ('알', 'O'),
#   (' ', 'O'),
#   ('수', 'O'),
#   (' ', 'O'),
#   ('있으니까', 'O')],
#  [('고맙고', 'O'),
#   (' ', 'O'),
#   ('사랑합니당', 'O'),
#   (' ', 'O'),
#   ('for', 'O'),
#   (' ', 'O'),
#   ('ever', 'O'),
#   (' ', 'O'),
#   ('and', 'O'),
#   (' ', 'O'),
#   ('ever~💜', 'O')],
#  [('우리', 'O'),
#   (' ', 'O'),
#   ('다원', 'PERSON'),
#   ('이,', 'O'),
#   (' ', 'O'),
#   ('우리', 'O'),
#   (' ', 'O'),
#   ('이섹귀', 'PERSON'),
#   ('~', 'O'),
#   (' ', 'O'),
#   ('개그도', 'O'),
#   (' ', 'O'),
#   ('잘하고', 'O'),
#   (' ', 'O'),
#   ('이리', 'O'),
#   (' ', 'O'),
#   ('노래도', 'O'),
#   (' ', 'O'),
#   ('잘하고', 'O'),
#   (' ', 'O'),
#   ('^^', 'O'),
#   (' ', 'O'),
#   ('전', 'O'),
#   (' ', 'O'),
#   ('아미', 'PERSON'),
#   ('인데', 'O'),
#   (' ', 'O'),
#   ('다원이', 'PERSON'),
#   (' ', 'O'),
#   ('땜에', 'O'),
#   (' ', 'O'),
#   ('판타지', 'STUDY_FIELD'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('하게', 'O'),
#   (' ', 'O'),
#   ('됐음', 'O'),
#   (' ', 'O'),
#   ('^^;;', 'O'),
#   (' ', 'O'),
#   ('지민', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('목소리', 'O'),
#   (' ', 'O'),
#   ('만큼이나', 'O'),
#   (' ', 'O'),
#   ('상큼하니', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('듣기', 'O'),
#   (' ', 'O'),
#   ('좋네요', 'O')],
#  [('깊은', 'O'),
#   (' ', 'O'),
#   ('아쉬움', 'O'),
#   (' ', 'O'),
#   ('할말은', 'O'),
#   (' ', 'O'),
#   ('많지만', 'O'),
#   (' ', 'O'),
#   ('참는다', 'O')],
#  [('애들', 'O'),
#   (' ', 'O'),
#   ('하고싶은대로', 'O'),
#   (' ', 'O'),
#   ('다양한', 'O'),
#   (' ', 'O'),
#   ('경험', 'O'),
#   (' ', 'O'),
#   ('많이', 'O'),
#   (' ', 'O'),
#   ('할', 'O'),
#   (' ', 'O'),
#   ('수', 'O'),
#   (' ', 'O'),
#   ('있었기에', 'O'),
#   (' ', 'O'),
#   ('멤버', 'CIVILIZATION'),
#   ('들도', 'O'),
#   (' ', 'O'),
#   ('행복해하고', 'O'),
#   (' ', 'O'),
#   ('보는', 'O'),
#   (' ', 'O'),
#   ('저희도', 'O'),
#   (' ', 'O'),
#   ('넘', 'O'),
#   (' ', 'O'),
#   ('행복했어요', 'O'),
#   (' ', 'O'),
#   ('마지막까지', 'O'),
#   (' ', 'O'),
#   ('맛있는게', 'O'),
#   (' ', 'O'),
#   ('잔뜩', 'O'),
#   (' ', 'O'),
#   ('먹여주셔서', 'O'),
#   (' ', 'O'),
#   ('감사해용', 'O'),
#   (' ', 'O'),
#   ('셒센타2', 'ARTIFACT'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('기대해봅니당~❤', 'O')],
#  [('사랑해', 'O'),
#   (' ', 'O'),
#   ('김인성', 'PERSON'),
#   (' ', 'O'),
#   ('…', 'O'),
#   (' ', 'O'),
#   ('어느', 'O'),
#   (' ', 'O'),
#   ('정도로', 'O'),
#   (' ', 'O'),
#   ('사랑하냐면…', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('사랑해…', 'O')],
#  [('이', 'O'),
#   (' ', 'O'),
#   ('남자를', 'O'),
#   (' ', 'O'),
#   ('…', 'O'),
#   (' ', 'O'),
#   ('군대보낼', 'O'),
#   (' ', 'O'),
#   ('생각에…', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('눈물난다……', 'O'),
#   (' ', 'O'),
#   ('내가', 'O'),
#   (' ', 'O'),
#   ('대신', 'O'),
#   (' ', 'O'),
#   ('가면', 'O'),
#   (' ', 'O'),
#   ('안될까', 'O'),
#   (' ', 'O'),
#   ('한국', 'COUNTRY'),
#   ('아……', 'O')],
#  [('약 1년 동안', 'DATE'),
#   (' ', 'O'),
#   ('셒센타', 'ARTIFACT'),
#   (' ', 'O'),
#   ('제작을', 'O'),
#   (' ', 'O'),
#   ('위해', 'O'),
#   (' ', 'O'),
#   ('힘써주신', 'O'),
#   (' ', 'O'),
#   ('스태프', 'CIVILIZATION'),
#   ('님들', 'O'),
#   (' ', 'O'),
#   ('감사하고', 'O'),
#   (' ', 'O'),
#   ('수고하셨어요', 'O'),
#   (' ', 'O'),
#   ('💓', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('아쉽고', 'O'),
#   (' ', 'O'),
#   ('섭섭하지만', 'O'),
#   (' ', 'O'),
#   ('또', 'O'),
#   (' ', 'O'),
#   ('다른', 'O'),
#   (' ', 'O'),
#   ('자컨', 'ARTIFACT'),
#   ('과', 'O'),
#   (' ', 'O'),
#   ('시즌 2', 'QUANTITY'),
#   ('!', 'O'),
#   (' ', 'O'),
#   ('기대하겠습니다', 'O'),
#   (' ', 'O'),
#   ('😉💕', 'O')],
#  [('셒센타', 'ORGANIZATION'),
#   (':', 'O'),
#   (' ', 'O'),
#   ('ㅇㅇ응', 'O'),
#   (' ', 'O'),
#   ('시즌', 'O'),
#   (' ', 'O'),
#   ('2', 'QUANTITY'),
#   (' ', 'O'),
#   ('내줄게', 'O')],
#  [('시즌 2', 'QUANTITY'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('조속한', 'O'),
#   (' ', 'O'),
#   ('방송을', 'O'),
#   (' ', 'O'),
#   ('기다리면서', 'O'),
#   (' ', 'O'),
#   ('시즌 1', 'DATE'),
#   (' ', 'O'),
#   ('수고', 'O'),
#   (' ', 'O'),
#   ('많았어요', 'O'),
#   (' ', 'O'),
#   ('관계자', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('분들', 'O'),
#   (' ', 'O'),
#   ('모두와', 'O'),
#   (' ', 'O'),
#   ('셒구들', 'O'),
#   (' ', 'O'),
#   ('시즌 2', 'QUANTITY'),
#   (' ', 'O'),
#   ('에서는', 'O'),
#   (' ', 'O'),
#   ('다원', 'PERSON'),
#   ('과', 'O'),
#   (' ', 'O'),
#   ('로운', 'PERSON'),
#   (' ', 'O'),
#   ('섭외하기', 'O'),
#   (' ', 'O'),
#   ('프로젝트', 'O'),
#   (' ', 'O'),
#   ('부터', 'O'),
#   (' ', 'O'),
#   ('시작해', 'O'),
#   (' ', 'O'),
#   ('주세요', 'O'),
#   (' ', 'O'),
#   ('프리즈~~~', 'O')],
#  [('누가', 'O'),
#   (' ', 'O'),
#   ('그렇게', 'O'),
#   (' ', 'O'),
#   ('귀여우래', 'O'),
#   (' ', 'O'),
#   ('김영균', 'PERSON')],
#  [('학창시절', 'O'),
#   (' ', 'O'),
#   ('없던', 'O'),
#   (' ', 'O'),
#   ('태권도장', 'O'),
#   (' ', 'O'),
#   ('추억', 'O'),
#   (' ', 'O'),
#   ('만들어주네', 'O')],
#  [('쟁찌같은', 'O'),
#   (' ', 'O'),
#   ('사범', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('한번쯤', 'QUANTITY'),
#   (' ', 'O'),
#   ('마음에', 'O'),
#   (' ', 'O'),
#   ('품어봤자나', 'O'),
#   (' ', 'O'),
#   ('왜', 'O')],
#  [('2주년', 'DATE'),
#   (' ', 'O'),
#   ('기념으로', 'O'),
#   (' ', 'O'),
#   ('찾아왔어요', 'O'),
#   (' ', 'O'),
#   ('💝', 'O'),
#   (' ', 'O'),
#   ('역시', 'O'),
#   (' ', 'O'),
#   ('인성', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('재윤', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('최고야!', 'O'),
#   (' ', 'O'),
#   ('💗', 'O'),
#   (' ', 'O'),
#   ('눈', 'O'),
#   ('오늘', 'DATE'),
#   (' ', 'O'),
#   ('오늘', 'DATE'),
#   (' ', 'O'),
#   ('딱', 'O'),
#   (' ', 'O'),
#   ('듣기', 'O'),
#   (' ', 'O'),
#   ('좋은', 'O'),
#   (' ', 'O'),
#   ('노래☃', 'O')],
#  [('ㅜㅜㅜ셒센타', 'O'), (' ', 'O'), ('수고하셨습니다ㅜㅜ', 'O'), (' ', 'O'), ('재밌었어요', 'O')],
#  [('상혁', 'PERSON'),
#   ('이랑', 'O'),
#   (' ', 'O'),
#   ('석우', 'PERSON'),
#   (' ', 'O'),
#   ('꿈은', 'O'),
#   (' ', 'O'),
#   ('어디갔니ㅜㅜ', 'O'),
#   (' ', 'O'),
#   ('조금', 'O'),
#   (' ', 'O'),
#   ('더', 'O'),
#   (' ', 'O'),
#   ('할줄알았는데', 'O'),
#   (' ', 'O'),
#   ('어느새', 'O'),
#   (' ', 'O'),
#   ('끝나버렸네', 'O')],
#  [('그동안', 'O'),
#   (' ', 'O'),
#   ('우리', 'O'),
#   (' ', 'O'),
#   ('멤버', 'CIVILIZATION'),
#   ('들', 'O'),
#   (' ', 'O'),
#   ('수고', 'O'),
#   (' ', 'O'),
#   ('많았고', 'O'),
#   (' ', 'O'),
#   ('열심히', 'O'),
#   (' ', 'O'),
#   ('촬영해주시고', 'O'),
#   (' ', 'O'),
#   ('편집', 'O'),
#   (' ', 'O'),
#   ('맛깔나게', 'O'),
#   (' ', 'O'),
#   ('해주신', 'O'),
#   (' ', 'O'),
#   ('제작진', 'CIVILIZATION'),
#   ('분들', 'O'),
#   (' ', 'O'),
#   ('감사했습니다~', 'O'),
#   (' ', 'O'),
#   ('셉센타', 'ARTIFACT'),
#   ('2', 'O')],
#  [('뭐야', 'O'),
#   (' ', 'O'),
#   ('김석우', 'PERSON'),
#   ('랑', 'O'),
#   (' ', 'O'),
#   ('이상혁', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('안나와?', 'O')],
#  [('마지막까지', 'O'), (' ', 'O'), ('고마오용', 'O'), (' ', 'O'), ('~~~~!!!!', 'O')],
#  [('마지막회까지', 'O'),
#   (' ', 'O'),
#   ('셒구', 'O'),
#   (' ', 'O'),
#   ('특징', 'O'),
#   (' ', 'O'),
#   ('잘', 'O'),
#   (' ', 'O'),
#   ('살린', 'O'),
#   (' ', 'O'),
#   ('편집', 'O'),
#   (' ', 'O'),
#   ('감사해요', 'O'),
#   (' ', 'O'),
#   ('잇♥', 'O'),
#   (' ', 'O'),
#   ('영빈', 'PERSON'),
#   ('이가', 'O'),
#   (' ', 'O'),
#   ('말했듯', 'O'),
#   (' ', 'O'),
#   ('애들이', 'O'),
#   (' ', 'O'),
#   ('편하게', 'O'),
#   (' ', 'O'),
#   ('찍은것', 'O'),
#   (' ', 'O'),
#   ('같아서', 'O'),
#   (' ', 'O'),
#   ('보면서도', 'O'),
#   (' ', 'O'),
#   ('흐뭇🥰', 'O'),
#   (' ', 'O'),
#   ('완전체가', 'O'),
#   (' ', 'O'),
#   ('많이', 'O'),
#   (' ', 'O'),
#   ('안나와서', 'O'),
#   (' ', 'O'),
#   ('좀', 'O'),
#   (' ', 'O'),
#   ('아쉽지만', 'O'),
#   (' ', 'O'),
#   ('셒센타 2', 'ARTIFACT'),
#   (' ', 'O'),
#   ('나', 'O'),
#   (' ', 'O'),
#   ('다른', 'O'),
#   (' ', 'O'),
#   ('자컨', 'ARTIFACT'),
#   ('으로', 'O'),
#   (' ', 'O'),
#   ('또', 'O'),
#   (' ', 'O'),
#   ('만나면', 'O'),
#   (' ', 'O'),
#   ('되니까', 'O'),
#   (' ', 'O'),
#   ('!', 'O'),
#   (' ', 'O'),
#   ('사랑해', 'O'),
#   (' ', 'O'),
#   ('SF9', 'ARTIFACT'),
#   (' ', 'O'),
#   ('💖', 'O')],
#  [('함께여서', 'O'),
#   (' ', 'O'),
#   ('즐거웠어요!', 'O'),
#   (' ', 'O'),
#   ('시즌2', 'QUANTITY'),
#   ('기다릴꾸얌♥', 'O')],
#  [('아닛ㅋㅋㅋㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('11:18부터', 'TIME'),
#   (' ', 'O'),
#   ('미친듯이', 'O'),
#   (' ', 'O'),
#   ('웃었넼ㅋㅋㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('우리', 'O'),
#   (' ', 'O'),
#   ('셒구', 'O'),
#   (' ', 'O'),
#   ('말랑이들♥', 'O'),
#   (' ', 'O'),
#   ('이벤트', 'O'),
#   (' ', 'O'),
#   ('좋아하는구나!', 'O'),
#   (' ', 'O'),
#   ('너네가', 'O'),
#   (' ', 'O'),
#   ('왜이렇게', 'O'),
#   (' ', 'O'),
#   ('좋을까', 'O'),
#   (' ', 'O'),
#   ('셒센타 2', 'ARTIFACT'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('기대할게요!', 'O'),
#   (' ', 'O'),
#   ('다소', 'O'),
#   (' ', 'O'),
#   ('세속(?)적이어도', 'O'),
#   (' ', 'O'),
#   ('이해할게요!!ㅋㅋㅋㅋㅋㅋ', 'O')],
#  [('김인성', 'PERSON'), ('ㅋㅋㅌㅋㅋㅋㅋㅋㅋㅋ너무', 'O'), (' ', 'O'), ('웃겨ㅋㅋㅋㅋㅋㅋㅋㅋㅋ', 'O')],
#  [('18화', 'QUANTITY'),
#   ('동안', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('고생한', 'O'),
#   (' ', 'O'),
#   ('우리', 'O'),
#   (' ', 'O'),
#   ('인성', 'PERSON'),
#   ('대표', 'OCCUPATION'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('이', 'PERSON'),
#   ('실장', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('재윤', 'PERSON'),
#   ('이,', 'O'),
#   (' ', 'O'),
#   ('빈', 'CIVILIZATION'),
#   ('인턴', 'CIVILIZATION'),
#   ('까지', 'O'),
#   (' ', 'O'),
#   ('❤형아즈', 'PERSON'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('잘해줘서', 'O'),
#   (' ', 'O'),
#   ('그동안', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('재밌게', 'O'),
#   (' ', 'O'),
#   ('봤어요', 'O'),
#   (' ', 'O'),
#   ('👍', 'O'),
#   (' ', 'O'),
#   ('시즌2', 'QUANTITY'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('형아들', 'CIVILIZATION'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('빈자리를', 'O'),
#   (' ', 'O'),
#   ('막내즈', 'CIVILIZATION'),
#   ('들이', 'O'),
#   (' ', 'O'),
#   ('또', 'O'),
#   (' ', 'O'),
#   ('열심히', 'O'),
#   (' ', 'O'),
#   ('꾸려가도', 'O'),
#   (' ', 'O'),
#   ('색다른', 'O'),
#   (' ', 'O'),
#   ('재미일듯', 'O'),
#   (' ', 'O'),
#   ('ㅎㅎㅎ기다릴게요', 'O'),
#   (' ', 'O'),
#   ('에펜', 'PERSON'),
#   ('씨!!!!!!', 'O'),
#   (' ', 'O'),
#   ('ㅠㅠ', 'O'),
#   (' ', 'O'),
#   ('넘', 'O'),
#   (' ', 'O'),
#   ('고생했다', 'O'),
#   (' ', 'O'),
#   ('영', 'PERSON'),
#   ('빈인', 'O'),
#   ('성재윤', 'PERSON'),
#   (' ', 'O'),
#   ('우리', 'O'),
#   (' ', 'O'),
#   ('아기', 'O'),
#   (' ', 'O'),
#   ('토끼', 'ANIMAL'),
#   (' ', 'O'),
#   ('고양이', 'ANIMAL'),
#   (' ', 'O'),
#   ('강쥐', 'ANIMAL'),
#   ('들', 'O'),
#   (' ', 'O'),
#   ('넘', 'O'),
#   (' ', 'O'),
#   ('사랑혀♥♥♥♥', 'O')],
#  [('아', 'O'),
#   (' ', 'O'),
#   ('이제', 'O'),
#   (' ', 'O'),
#   ('여기', 'O'),
#   (' ', 'O'),
#   ('올라오는구나ㅜㅜㅜㅜ', 'O'),
#   (' ', 'O'),
#   ('울', 'O'),
#   (' ', 'O'),
#   ('애기', 'O'),
#   (' ', 'O'),
#   ('보고싶었ㄷ', 'O')],
#  [('백현', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('목소리', 'O'),
#   (' ', 'O'),
#   ('너무너무', 'O'),
#   (' ', 'O'),
#   ('좋아ㅜㅜ', 'O'),
#   (' ', 'O'),
#   ('잘때', 'O'),
#   (' ', 'O'),
#   ('asmr', 'TERM'),
#   (' ', 'O'),
#   ('틀어놓고', 'O'),
#   (' ', 'O'),
#   ('자는데', 'O'),
#   (' ', 'O'),
#   ('이영상', 'O'),
#   (' ', 'O'),
#   ('틀어놔야겠다ㅜㅜㅜㅜㅜㅜ', 'O'),
#   (' ', 'O'),
#   ('우리', 'O'),
#   ('백현', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('너무너무', 'O'),
#   (' ', 'O'),
#   ('사랑해', 'O'),
#   (' ', 'O'),
#   ('그리고', 'O'),
#   (' ', 'O'),
#   ('보구싶다ㅠㅠㅠ', 'O')],
#  [('이', 'O'),
#   (' ', 'O'),
#   ('책', 'O'),
#   (' ', 'O'),
#   ('사야겠다', 'O'),
#   (' ', 'O'),
#   ('같이', 'O'),
#   (' ', 'O'),
#   ('읽게🖤', 'O')],
#  [('이제', 'O'),
#   (' ', 'O'),
#   ('좀', 'O'),
#   (' ', 'O'),
#   ('살', 'O'),
#   (' ', 'O'),
#   ('거', 'O'),
#   (' ', 'O'),
#   ('같아', 'O'),
#   (' ', 'O'),
#   ('백현아', 'PERSON'),
#   (' ', 'O'),
#   ('제발', 'O')],
#  [('진짜', 'O'),
#   (' ', 'O'),
#   ('사랑해', 'O'),
#   (' ', 'O'),
#   ('사랑스러워', 'O'),
#   (' ', 'O'),
#   ('정말', 'O'),
#   (' ', 'O'),
#   ('보고싳다', 'O'),
#   (' ', 'O'),
#   ('비비에이치', 'PERSON')],
#  [('나는', 'O'),
#   (' ', 'O'),
#   ('정말', 'O'),
#   (' ', 'O'),
#   ('너를', 'O'),
#   (' ', 'O'),
#   ('매우', 'O'),
#   (' ', 'O'),
#   ('그리워한다', 'O')],
#  [('소중하고', 'O'),
#   (' ', 'O'),
#   ('사랑받는', 'O'),
#   (' ', 'O'),
#   ('많은', 'O'),
#   ('백현', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('opp항상', 'O'),
#   (' ', 'O'),
#   ('행복하게', 'O'),
#   (' ', 'O'),
#   ('해주셔서', 'O'),
#   (' ', 'O'),
#   ('감사합니다', 'O'),
#   (' ', 'O'),
#   ('영원히', 'O'),
#   (' ', 'O'),
#   ('사랑해주셔서', 'O'),
#   (' ', 'O'),
#   ('감사합니다', 'O'),
#   (' ', 'O'),
#   ('많이', 'O'),
#   (' ', 'O'),
#   ('사랑해주셔서', 'O'),
#   (' ', 'O'),
#   ('감사합니다', 'O'),
#   (' ', 'O'),
#   ('오빠', 'CIVILIZATION'),
#   ('\U0001f90d\U0001f90d\U0001f90d\U0001f90d\U0001f90d', 'O')],
#  [('백현', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('착한', 'O'),
#   (' ', 'O'),
#   ('줄', 'O'),
#   (' ', 'O'),
#   ('알았는데', 'O'),
#   (' ', 'O'),
#   ('목소리로', 'O'),
#   (' ', 'O'),
#   ('사람', 'O'),
#   (' ', 'O'),
#   ('귀', 'ANIMAL'),
#   (' ', 'O'),
#   ('녹이네', 'O')],
#  [('오늘', 'DATE'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('내', 'O'),
#   (' ', 'O'),
#   ('생일이고', 'O'),
#   (' ', 'O'),
#   ('당신이', 'O'),
#   (' ', 'O'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('선물을', 'O'),
#   (' ', 'O'),
#   ('주었어요', 'O')],
#  [('백현아', 'PERSON'),
#   (' ', 'O'),
#   ('고마워요\U0001f90d', 'O'),
#   (' ', 'O'),
#   ('사랑해요💖', 'O')],
#  [('ㅠ큥', 'O'),
#   ('튜브', 'TERM'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('돌아와서', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('기뻐ㅠㅠㅠㅠㅠ', 'O'),
#   (' ', 'O'),
#   ('미리', 'O'),
#   (' ', 'O'),
#   ('크리스마스', 'DATE'),
#   (' ', 'O'),
#   ('선물', 'O'),
#   (' ', 'O'),
#   ('받은', 'O'),
#   (' ', 'O'),
#   ('기분이야!', 'O'),
#   (' ', 'O'),
#   ('심지어', 'O'),
#   (' ', 'O'),
#   ('읽어주는', 'O'),
#   (' ', 'O'),
#   ('구절들이', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('좋다', 'O'),
#   (' ', 'O'),
#   ('백현아', 'PERSON'),
#   ('😭', 'O'),
#   (' ', 'O'),
#   ('책', 'O'),
#   (' ', 'O'),
#   ('읽어주는', 'O'),
#   (' ', 'O'),
#   ('큥', 'O'),
#   (' ', 'O'),
#   ('최고야☝❤', 'O')],
#  [('당신은', 'O'),
#   (' ', 'O'),
#   ('내', 'O'),
#   (' ', 'O'),
#   ('두려움을', 'O'),
#   (' ', 'O'),
#   ('가지고', 'O'),
#   (' ', 'O'),
#   ('나에게', 'O'),
#   (' ', 'O'),
#   ('당신의', 'O'),
#   (' ', 'O'),
#   ('빛을', 'O'),
#   (' ', 'O'),
#   ('제공♥', 'O')],
#  [('신상', 'O'),
#   ('팬', 'OCCUPATION'),
#   ('이라', 'O'),
#   (' ', 'O'),
#   ('복습중인데', 'O'),
#   (' ', 'O'),
#   ('amnesia', 'O'),
#   (' ', 'O'),
#   ('에서', 'O'),
#   (' ', 'O'),
#   ('음', 'O'),
#   (' ', 'O'),
#   ('으로', 'O'),
#   (' ', 'O'),
#   ('넘어갈때', 'O'),
#   (' ', 'O'),
#   ('오래된', 'O'),
#   (' ', 'O'),
#   ('사진첩을', 'O'),
#   (' ', 'O'),
#   ('넘기는거같이', 'O'),
#   (' ', 'O'),
#   ('뭔가', 'O'),
#   (' ', 'O'),
#   ('서사적임', 'O'),
#   (' ', 'O'),
#   ('예능에서', 'O'),
#   (' ', 'O'),
#   ('예상외로', 'O'),
#   (' ', 'O'),
#   ('털털한거같아', 'O'),
#   (' ', 'O'),
#   ('좋게', 'O'),
#   (' ', 'O'),
#   ('생각하다', 'O'),
#   (' ', 'O'),
#   ('솔로앨범', 'O'),
#   (' ', 'O'),
#   ('음', 'O'),
#   (' ', 'O'),
#   ('뮤비보고', 'O'),
#   (' ', 'O'),
#   ('입덕함', 'O'),
#   (' ', 'O'),
#   ('ㅋㅋ', 'O')],
#  [('I', 'O'),
#   (' ', 'O'),
#   ('hear', 'O'),
#   (' ', 'O'),
#   ('this', 'O'),
#   (' ', 'O'),
#   ('want', 'O'),
#   (' ', 'O'),
#   ('to', 'O'),
#   (' ', 'O'),
#   ('sleep', 'O'),
#   (' ', 'O'),
#   ('Don’t', 'O'),
#   (' ', 'O'),
#   ('laugh', 'O'),
#   (' ', 'O'),
#   ('at', 'O'),
#   (' ', 'O'),
#   ('me', 'O'),
#   (' ', 'O'),
#   ('정말', 'O'),
#   (' ', 'O'),
#   ('졸려요', 'O'),
#   (' ', 'O'),
#   ('이것이', 'O'),
#   (' ', 'O'),
#   ('내가', 'O'),
#   (' ', 'O'),
#   ('성적이', 'O'),
#   (' ', 'O'),
#   ('좋지', 'O'),
#   (' ', 'O'),
#   ('않은', 'O'),
#   (' ', 'O'),
#   ('이유일', 'O'),
#   (' ', 'O'),
#   ('것이다', 'O')],
#  [('내일', 'DATE'),
#   (' ', 'O'),
#   ('시험을', 'O'),
#   (' ', 'O'),
#   ('봐야', 'O'),
#   (' ', 'O'),
#   ('한다나는', 'O'),
#   (' ', 'O'),
#   ('공부하러', 'O'),
#   (' ', 'O'),
#   ('갔다', 'O'),
#   (' ', 'O'),
#   ('모두', 'O'),
#   (' ', 'O'),
#   ('안녕히', 'O'),
#   (' ', 'O'),
#   ('주무세요', 'O')],
#  [('백현', 'PERSON'),
#   ('오빠', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('이제', 'O'),
#   (' ', 'O'),
#   ('인생', 'O'),
#   (' ', 'O'),
#   ('선배', 'CIVILIZATION'),
#   ('까지', 'O'),
#   (' ', 'O'),
#   ('해주시는', 'O'),
#   (' ', 'O'),
#   ('건가요?ㅜㅜ', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('위로된다', 'O'),
#   (' ', 'O'),
#   ('정말', 'O'),
#   (' ', 'O'),
#   ('고마워요', 'O')],
#  [('Itzy Mitzy', 'PERSON'),
#   ('에게', 'O'),
#   (' ', 'O'),
#   ('투표합시다', 'O'),
#   (' ', 'O'),
#   ('girl', 'O'),
#   (' ', 'O'),
#   ('이기면', 'O'),
#   (' ', 'O'),
#   ('좋겠어요', 'O')],
#  [('나는', 'O'),
#   (' ', 'O'),
#   ('당신을', 'O'),
#   (' ', 'O'),
#   ('숭배합니다', 'O'),
#   (' ', 'O'),
#   ('atzy', 'O'),
#   (' ', 'O'),
#   ('우리', 'O'),
#   (' ', 'O'),
#   ('모두', 'O'),
#   (' ', 'O'),
#   ('당신을', 'O'),
#   (' ', 'O'),
#   ('숭배하는', 'O'),
#   (' ', 'O'),
#   ('동안', 'O'),
#   (' ', 'O'),
#   ('당신이', 'O'),
#   (' ', 'O'),
#   ('나에게', 'O'),
#   (' ', 'O'),
#   ('대답하기를', 'O'),
#   (' ', 'O'),
#   ('바랍니다', 'O')]]

# %%
review_results=[]
for i in tqdm_notebook(body_youtube):
  result = review(i)
  review_results.append(result)
review_results
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/200 [00:00<?, ?it/s]
# [4.6,
#  5.02,
#  5.02,
#  4.7,
#  4.63,
#  3.22,
#  3.97,
#  4.93,
#  4.01,
#  1.88,
#  4.71,
#  4.38,
#  4.02,
#  4.78,
#  4.9,
#  4.21,
#  2.28,
#  4.45,
#  1.26,
#  1.51,
#  2.07,
#  4.53,
#  4.6,
#  3.96,
#  1.51,
#  4.87,
#  5.03,
#  4.97,
#  5.01,
#  4.95,
#  2.52,
#  4.36,
#  4.91,
#  4.58,
#  4.75,
#  4.68,
#  4.05,
#  4.87,
#  4.41,
#  4.93,
#  3.9,
#  3.28,
#  4.52,
#  4.24,
#  4.87,
#  4.46,
#  4.98,
#  4.71,
#  4.94,
#  4.95,
#  3.73,
#  3.87,
#  4.64,
#  4.62,
#  1.21,
#  4.98,
#  4.52,
#  5.04,
#  5.03,
#  3.85,
#  4.36,
#  4.54,
#  5.03,
#  3.16,
#  4.83,
#  4.78,
#  4.73,
#  4.52,
#  4.51,
#  4.55,
#  4.62,
#  3.92,
#  4.89,
#  4.99,
#  4.91,
#  4.79,
#  4.82,
#  4.95,
#  4.4,
#  4.73,
#  2.89,
#  4.84,
#  4.78,
#  4.98,
#  4.77,
#  4.78,
#  4.19,
#  5.03,
#  4.7,
#  4.85,
#  4.57,
#  5.03,
#  2.36,
#  4.94,
#  4.48,
#  5.01,
#  5.04,
#  1.35,
#  5.0,
#  4.99,
#  4.88,
#  4.9,
#  4.29,
#  4.97,
#  1.55,
#  4.4,
#  1.85,
#  4.9,
#  4.36,
#  4.9,
#  4.56,
#  2.91,
#  4.28,
#  4.7,
#  4.26,
#  4.85,
#  4.87,
#  5.0,
#  3.36,
#  4.96,
#  4.87,
#  4.96,
#  2.41,
#  3.0,
#  3.57,
#  4.87,
#  4.9,
#  2.67,
#  4.71,
#  2.88,
#  4.17,
#  5.03,
#  4.78,
#  4.36,
#  4.95,
#  4.87,
#  1.99,
#  4.17,
#  4.37,
#  4.95,
#  4.5,
#  3.92,
#  4.87,
#  4.84,
#  4.56,
#  4.74,
#  4.87,
#  4.82,
#  2.81,
#  4.8,
#  4.72,
#  3.27,
#  4.96,
#  4.95,
#  2.87,
#  4.7,
#  4.95,
#  4.85,
#  4.49,
#  4.79,
#  4.94,
#  2.18,
#  5.02,
#  4.94,
#  4.36,
#  4.76,
#  4.2,
#  4.38,
#  4.71,
#  4.77,
#  1.47,
#  4.9,
#  4.08,
#  2.3,
#  5.02,
#  1.84,
#  4.72,
#  4.89,
#  4.83,
#  4.95,
#  4.9,
#  4.96,
#  4.86,
#  5.0,
#  4.61,
#  4.73,
#  4.57,
#  4.61,
#  5.01,
#  3.21,
#  4.58,
#  4.49,
#  5.06,
#  4.83,
#  4.92,
#  1.87,
#  2.89,
#  5.0,
#  4.1,
#  4.78]

# %%
ner_results=[]
for i in tqdm_notebook(body_news):
  result = ner(i)
  ner_results.append(result)
ner_results
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/200 [00:00<?, ?it/s]
# [[('이수현', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('"우리는', 'O'),
#   (' ', 'O'),
#   ('은퇴를', 'O'),
#   (' ', 'O'),
#   ('하면', 'O'),
#   (' ', 'O'),
#   ('했지', 'O'),
#   (' ', 'O'),
#   ('YG', 'ORGANIZATION'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('떠날', 'O'),
#   (' ', 'O'),
#   ('생각을', 'O'),
#   (' ', 'O'),
#   ('단', 'O'),
#   (' ', 'O'),
#   ('한 번', 'QUANTITY'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('해', 'O'),
#   (' ', 'O'),
#   ('본', 'O'),
#   (' ', 'O'),
#   ('적', 'O'),
#   (' ', 'O'),
#   ('없다"며', 'O'),
#   (' ', 'O'),
#   ('YG', 'ORGANIZATION'),
#   ('와의', 'O'),
#   (' ', 'O'),
#   ('끈끈한', 'O'),
#   (' ', 'O'),
#   ('의리를', 'O'),
#   (' ', 'O'),
#   ('자랑했다', 'O')],
#  [('저스틴 비버', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('4개월 만', 'DATE'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('또', 'O'),
#   (' ', 'O'),
#   ('1위', 'QUANTITY'),
#   (' ', 'O'),
#   ('[', 'O'),
#   ('9월 1주차', 'DATE'),
#   (' ', 'O'),
#   ('멜론차트', 'TERM'),
#   (']', 'O')],
#  [('지난 4일', 'DATE'),
#   (' ', 'O'),
#   ('발표된', 'O'),
#   (' ', 'O'),
#   ('빌보드', 'ORGANIZATION'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('핫 100', 'ARTIFACT'),
#   ("'(HOT 100", 'QUANTITY'),
#   (')', 'O'),
#   (' ', 'O'),
#   ('차트에서', 'O'),
#   (' ', 'O'),
#   ('1위', 'QUANTITY'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('차지하며', 'O'),
#   (' ', 'O'),
#   ('4주', 'DATE'),
#   (' ', 'O'),
#   ('연속', 'O'),
#   (' ', 'O'),
#   ('자리를', 'O'),
#   (' ', 'O'),
#   ('지켰으며', 'O'),
#   (' ', 'O'),
#   ('유튜브', 'TERM'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('공개된', 'O'),
#   (' ', 'O'),
#   ('공식', 'O'),
#   (' ', 'O'),
#   ('뮤직비디오는', 'O'),
#   (' ', 'O'),
#   ('1억 4천뷰', 'QUANTITY'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('육박하고', 'O'),
#   (' ', 'O'),
#   ('있다', 'O')],
#  [('이런', 'O'),
#   (' ', 'O'),
#   ('가운데', 'O'),
#   (' ', 'O'),
#   ('숏폼', 'O'),
#   (' ', 'O'),
#   ('콘텐츠', 'O'),
#   (' ', 'O'),
#   ('플랫폼', 'O'),
#   (' ', 'O'),
#   ('등에서', 'O'),
#   (' ', 'O'),
#   ('인기를', 'O'),
#   (' ', 'O'),
#   ('모으고', 'O'),
#   (' ', 'O'),
#   ('있는', 'O'),
#   (' ', 'O'),
#   ('디핵', 'PERSON'),
#   (' ', 'O'),
#   ('(D-Hack),', 'O'),
#   (' ', 'O'),
#   ('파테코', 'PERSON'),
#   (' ', 'O'),
#   ('(PATEKO)의', 'O'),
#   (' ', 'O'),
#   ('곡', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('오하요 마이 나이트', 'ARTIFACT'),
#   ("'(OHAYO", 'O'),
#   (' ', 'O'),
#   ('MY', 'O'),
#   (' ', 'O'),
#   ('NIGHT)와', 'O'),
#   (' ', 'O'),
#   ('전소미', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('신곡', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('덤 덤', 'ARTIFACT'),
#   ("'(DUMB", 'O'),
#   (' ', 'O'),
#   ('DUMB)', 'O'),
#   (' ', 'O'),
#   ('등이', 'O'),
#   (' ', 'O'),
#   ('젊은층', 'O'),
#   (' ', 'O'),
#   ('공략에', 'O'),
#   (' ', 'O'),
#   ('성공하며', 'O'),
#   (' ', 'O'),
#   ('눈', 'ANIMAL'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('띄는', 'O'),
#   (' ', 'O'),
#   ('성적을', 'O'),
#   (' ', 'O'),
#   ('내고', 'O'),
#   (' ', 'O'),
#   ('있다', 'O')],
#  [("'", 'O'),
#   ('오하요 마이 나이트', 'ARTIFACT'),
#   ("'는", 'O'),
#   (' ', 'O'),
#   ('전주', 'DATE'),
#   (' ', 'O'),
#   ('대비', 'O'),
#   (' ', 'O'),
#   ('1계단', 'QUANTITY'),
#   (' ', 'O'),
#   ('상승하며', 'O'),
#   (' ', 'O'),
#   ('8위', 'QUANTITY'),
#   ('를,', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('덤 덤', 'ARTIFACT'),
#   ("'은", 'O'),
#   (' ', 'O'),
#   ('2계단', 'QUANTITY'),
#   (' ', 'O'),
#   ('오르며', 'O'),
#   (' ', 'O'),
#   ('10위', 'QUANTITY'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('기록했다', 'O')],
#  [('"벌이', 'O'),
#   (' ', 'O'),
#   ('없어', 'O'),
#   (' ', 'O'),
#   ('차', 'ARTIFACT'),
#   (' ', 'O'),
#   ('팔았다"', 'O'),
#   (' ', 'O'),
#   ('최정윤', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('생활고', 'O'),
#   (' ', 'O'),
#   ('고백→', 'O'),
#   ('정이랑', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('훈남', 'O'),
#   ('남편', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('깜짝', 'O'),
#   (' ', 'O'),
#   ('공개', 'O'),
#   (' ', 'O'),
#   ('(워맨스)', 'O'),
#   (' ', 'O'),
#   ('[Oh!쎈', 'O'),
#   (' ', 'O'),
#   ('리뷰]', 'O')],
#  [('9일', 'DATE'),
#   (' ', 'O'),
#   ('SBS', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('예능', 'O'),
#   (' ', 'O'),
#   ('‘', 'O'),
#   ('워맨스가 필요해', 'ARTIFACT'),
#   ('’가', 'O'),
#   (' ', 'O'),
#   ('전파를', 'O'),
#   (' ', 'O'),
#   ('탔다', 'O')],
#  [('이날', 'DATE'),
#   (' ', 'O'),
#   ('최정윤', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('절친', 'O'),
#   (' ', 'O'),
#   ('개그우먼', 'OCCUPATION'),
#   ('이자', 'O'),
#   (' ', 'O'),
#   ('배우', 'OCCUPATION'),
#   ('로', 'O'),
#   (' ', 'O'),
#   ('활동', 'O'),
#   (' ', 'O'),
#   ('중인', 'O'),
#   (' ', 'O'),
#   ('정이랑', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('배우', 'OCCUPATION'),
#   (' ', 'O'),
#   ('진선미', 'PERSON'),
#   ('와', 'O'),
#   (' ', 'O'),
#   ('만났다', 'O')],
#  [('특히', 'O'),
#   (' ', 'O'),
#   ('진선미', 'PERSON'),
#   ('와는', 'O'),
#   (' ', 'O'),
#   ('사투리를', 'O'),
#   (' ', 'O'),
#   ('배우며', 'O'),
#   (' ', 'O'),
#   ('친해졌다면“작품할', 'O'),
#   (' ', 'O'),
#   ('때', 'O'),
#   (' ', 'O'),
#   ('상황도', 'O'),
#   (' ', 'O'),
#   ('힘들었는데', 'O'),
#   (' ', 'O'),
#   ('이지할', 'O'),
#   (' ', 'O'),
#   ('곳이', 'O'),
#   (' ', 'O'),
#   ('필요했는데', 'O'),
#   (' ', 'O'),
#   ('그게', 'O'),
#   (' ', 'O'),
#   ('선미', 'PERSON'),
#   ('였다”며', 'O'),
#   (' ', 'O'),
#   ('버팀목이', 'O'),
#   (' ', 'O'),
#   ('된', 'O'),
#   (' ', 'O'),
#   ('친구', 'CIVILIZATION'),
#   ('라고', 'O'),
#   (' ', 'O'),
#   ('했다', 'O')],
#  [('정이랑', 'PERSON'),
#   (' ', 'O'),
#   ('새삼', 'O'),
#   (' ', 'O'),
#   ('최정윤', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('미모에', 'O'),
#   (' ', 'O'),
#   ('감탄했다', 'O')],
#  [('특히', 'O'),
#   (' ', 'O'),
#   ('최정윤', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('미모', 'O'),
#   (' ', 'O'),
#   ('뿐만', 'O'),
#   (' ', 'O'),
#   ('아니라', 'O'),
#   (' ', 'O'),
#   ('몸매도', 'O'),
#   (' ', 'O'),
#   ('극찬한', 'O'),
#   (' ', 'O'),
#   ('두 사람', 'QUANTITY')],
#  [('진선미', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('“목욕탕', 'O'),
#   (' ', 'O'),
#   ('갔을', 'O'),
#   (' ', 'O'),
#   ('때도', 'O'),
#   (' ', 'O'),
#   ('몸매가', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('예뻤다,', 'O'),
#   (' ', 'O'),
#   ('살결이', 'O'),
#   (' ', 'O'),
#   ('우윳빛', 'TERM'),
#   ('”이라고', 'O'),
#   (' ', 'O'),
#   ('했고', 'O'),
#   (' ', 'O'),
#   ('정이랑', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('“(내)', 'O'),
#   (' ', 'O'),
#   ('남편', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('앞', 'TERM'),
#   ('에선', 'O'),
#   (' ', 'O'),
#   ('얘기하지마라,', 'O'),
#   (' ', 'O'),
#   ('상상하게', 'O'),
#   (' ', 'O'),
#   ('된다”며', 'O'),
#   (' ', 'O'),
#   ('견제했다', 'O')],
#  [('정이랑', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('훈남', 'O'),
#   (' ', 'O'),
#   ('남편', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('모습을', 'O'),
#   (' ', 'O'),
#   ('공개해', 'O'),
#   (' ', 'O'),
#   ('시선을', 'O'),
#   (' ', 'O'),
#   ('사로', 'O'),
#   (' ', 'O'),
#   ('잡은', 'O'),
#   (' ', 'O'),
#   ('바', 'O'),
#   (' ', 'O'),
#   ('있다', 'O')],
#  [('정이랑', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('훈남', 'O'),
#   (' ', 'O'),
#   ('남편', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('모습을', 'O'),
#   (' ', 'O'),
#   ('공개해', 'O'),
#   (' ', 'O'),
#   ('시선을', 'O'),
#   (' ', 'O'),
#   ('사로', 'O'),
#   (' ', 'O'),
#   ('잡은', 'O'),
#   (' ', 'O'),
#   ('바', 'O'),
#   (' ', 'O'),
#   ('있다', 'O')],
#  [('진선미', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('“우리', 'O'),
#   (' ', 'O'),
#   ('남편', 'CIVILIZATION'),
#   ('한테도', 'O'),
#   (' ', 'O'),
#   ('정윤', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('글래머라고해,', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('완벽한데', 'O'),
#   (' ', 'O'),
#   ('왜', 'O'),
#   (' ', 'O'),
#   ('남편', 'CIVILIZATION'),
#   ('이', 'O')],
#  [('”라며', 'O'),
#   (' ', 'O'),
#   ('이혼', 'O'),
#   (' ', 'O'),
#   ('조정중인', 'O'),
#   (' ', 'O'),
#   ('것을', 'O'),
#   (' ', 'O'),
#   ('언급,', 'O'),
#   (' ', 'O'),
#   ('찐친이라', 'O'),
#   (' ', 'O'),
#   ('가능한', 'O'),
#   (' ', 'O'),
#   ('농담이었다', 'O')],
#  [('”라며', 'O'),
#   (' ', 'O'),
#   ('이혼', 'O'),
#   (' ', 'O'),
#   ('조정중인', 'O'),
#   (' ', 'O'),
#   ('것을', 'O'),
#   (' ', 'O'),
#   ('언급,', 'O'),
#   (' ', 'O'),
#   ('찐친이라', 'O'),
#   (' ', 'O'),
#   ('가능한', 'O'),
#   (' ', 'O'),
#   ('농담이었다', 'O')],
#  [('진선미', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('“이런', 'O'),
#   (' ', 'O'),
#   ('곳엔', 'O'),
#   (' ', 'O'),
#   ('신랑', 'CIVILIZATION'),
#   ('이랑', 'O'),
#   (' ', 'O'),
#   ('와야하는데,', 'O'),
#   (' ', 'O'),
#   ('미안하다', 'O'),
#   (' ', 'O'),
#   ('입버릇이디”며', 'O'),
#   (' ', 'O'),
#   ('민망,', 'O'),
#   ('최정윤', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('“아이', 'O'),
#   (' ', 'O'),
#   ('젠장!', 'O'),
#   (' ', 'O'),
#   ('작작해라', 'O'),
#   (' ', 'O'),
#   ('진짜,', 'O'),
#   (' ', 'O'),
#   ('지겹다”며', 'O'),
#   (' ', 'O'),
#   ('속마음을', 'O'),
#   (' ', 'O'),
#   ('전했다', 'O')],
#  [('모두', 'O'),
#   (' ', 'O'),
#   ('“이혼', 'O'),
#   (' ', 'O'),
#   ('소송중인', 'O'),
#   (' ', 'O'),
#   ('신랑', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('앞', 'TERM'),
#   ('에서', 'O'),
#   (' ', 'O'),
#   ('신랑', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('얘기', 'O'),
#   (' ', 'O'),
#   ('쉽지', 'O'),
#   (' ', 'O'),
#   ('않은데', 'O'),
#   (' ', 'O'),
#   ('정말', 'O'),
#   (' ', 'O'),
#   ('찐친이다”며', 'O'),
#   (' ', 'O'),
#   ('놀라워했다', 'O')],
#  [('[기동취재]', 'O'),
#   (' ', 'O'),
#   ('"폐기물', 'O'),
#   (' ', 'O'),
#   ('아니다"던', 'O'),
#   (' ', 'O'),
#   ('포항', 'CITY'),
#   (' ', 'O'),
#   ('A업체', 'O'),
#   (' ', 'O'),
#   ('파렴치한', 'O'),
#   (' ', 'O'),
#   ('민낯...', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('알루미늄', 'MATERIAL'),
#   (' ', 'O'),
#   ('분진', 'O'),
#   (' ', 'O'),
#   ('등', 'O'),
#   (' ', 'O'),
#   ('폐기물', 'O'),
#   (' ', 'O'),
#   ("방치'", 'O')],
#  [('com', 'O'),
#   (' ', 'O'),
#   ('무단전재', 'O'),
#   (' ', 'O'),
#   ('및', 'O'),
#   (' ', 'O'),
#   ('재배포금지', 'O'),
#   (' ', 'O'),
#   ('포항시', 'ORGANIZATION')],
#  [('“다수', 'O'),
#   (' ', 'O'),
#   ('위법사항', 'O'),
#   (' ', 'O'),
#   ('적발,', 'O'),
#   (' ', 'O'),
#   ('원칙에', 'O'),
#   (' ', 'O'),
#   ('따라', 'O'),
#   (' ', 'O'),
#   ('처리', 'O'),
#   (' ', 'O'),
#   ('하겠다”', 'O'),
#   (' ', 'O'),
#   ('또', 'O'),
#   (' ', 'O'),
#   ('다른', 'O'),
#   (' ', 'O'),
#   ('한통', 'QUANTITY'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('제보를', 'O'),
#   (' ', 'O'),
#   ('받고', 'O'),
#   (' ', 'O'),
#   ('찾아간', 'O'),
#   (' ', 'O'),
#   ('곳은', 'O'),
#   (' ', 'O'),
#   ('경북', 'LOCATION'),
#   (' ', 'O'),
#   ('포항시', 'CITY'),
#   (' ', 'O'),
#   ('청하면', 'LOCATION'),
#   (' ', 'O'),
#   ('고현리', 'LOCATION'),
#   (' ', 'O'),
#   ('일대로', 'O'),
#   (' ', 'O'),
#   ('앞서', 'O'),
#   (' ', 'O'),
#   ('<본보', 'O'),
#   (' ', 'O'),
#   ('2021년 6월 9일자', 'DATE'),
#   (' ', 'O'),
#   ('포항', 'CITY'),
#   (' ', 'O'),
#   ('청하면', 'LOCATION'),
#   (' ', 'O'),
#   ('A업체', 'O'),
#   (' ', 'O'),
#   ('방치물품', 'O'),
#   (' ', 'O'),
#   ('화재위험성', 'O'),
#   (' ', 'O'),
#   ('모르쇠', 'O'),
#   (' ', 'O'),
#   ('일관', 'O')],
#  [('‘물품', 'O'),
#   (' ', 'O'),
#   ('설명', 'O'),
#   (' ', 'O'),
#   ('회피’>관련,', 'O'),
#   (' ', 'O'),
#   ('해당', 'O'),
#   (' ', 'O'),
#   ('업체가', 'O'),
#   (' ', 'O'),
#   ('방치한', 'O'),
#   (' ', 'O'),
#   ('다량의', 'O'),
#   (' ', 'O'),
#   ('물품에서', 'O'),
#   (' ', 'O'),
#   ('일으키는', 'O'),
#   (' ', 'O'),
#   ('악취로', 'O'),
#   (' ', 'O'),
#   ('인근', 'O'),
#   (' ', 'O'),
#   ('주민', 'CIVILIZATION'),
#   ('들은', 'O'),
#   (' ', 'O'),
#   ('극심한', 'O'),
#   (' ', 'O'),
#   ('고통을', 'O'),
#   (' ', 'O'),
#   ('겪고', 'O'),
#   (' ', 'O'),
#   ('있었다', 'O')],
#  [('최정윤', 'PERSON'),
#   (' ', 'O'),
#   ('"생활비', 'O'),
#   (' ', 'O'),
#   ('없어', 'O'),
#   (' ', 'O'),
#   ('차', 'ARTIFACT'),
#   ('+가방', 'O'),
#   (' ', 'O'),
#   ('팔아서', 'O'),
#   (' ', 'O'),
#   ('생활"→"', 'O'),
#   ('딸', 'CIVILIZATION'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('동생', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('갖고', 'O'),
#   (' ', 'O'),
#   ('싶다고"(\'워맨스\')[종합]', 'O')],
#  [("'", 'O'),
#   ('워맨스가 필요해', 'ARTIFACT'),
#   ("'", 'O'),
#   (' ', 'O'),
#   ('최정윤', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('생활고를', 'O'),
#   (' ', 'O'),
#   ('고백했다', 'O')],
#  [('9일', 'DATE'),
#   (' ', 'O'),
#   ('방송된', 'O'),
#   (' ', 'O'),
#   ('SBS', 'ORGANIZATION'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('워맨스가 필요해', 'ARTIFACT'),
#   ("'에서는", 'O'),
#   (' ', 'O'),
#   ('배우', 'OCCUPATION'),
#   (' ', 'O'),
#   ('최정윤', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('절친', 'O'),
#   (' ', 'O'),
#   ('배우', 'OCCUPATION'),
#   (' ', 'O'),
#   ('진선미', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('정이랑', 'PERSON'),
#   ('을', 'O'),
#   (' ', 'O'),
#   ('만나', 'O'),
#   (' ', 'O'),
#   ('그들의', 'O'),
#   (' ', 'O'),
#   ("'비밀", 'O'),
#   (' ', 'O'),
#   ("아지트'를", 'O'),
#   (' ', 'O'),
#   ('방문했다', 'O')],
#  [('이날', 'DATE'),
#   (' ', 'O'),
#   ('최정윤', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('영화', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('감쪽같은 그녀', 'ARTIFACT'),
#   ("'를", 'O'),
#   (' ', 'O'),
#   ('준비하던', 'O'),
#   (' ', 'O'),
#   ('2017년', 'DATE'),
#   (' ', 'O'),
#   ('당시,', 'O'),
#   (' ', 'O'),
#   ('배역을', 'O'),
#   (' ', 'O'),
#   ('위해', 'O'),
#   (' ', 'O'),
#   ('경상도', 'LOCATION'),
#   (' ', 'O'),
#   ('사투리를', 'O'),
#   (' ', 'O'),
#   ('배우며', 'O'),
#   (' ', 'O'),
#   ('연을', 'O'),
#   (' ', 'O'),
#   ('맺은', 'O'),
#   (' ', 'O'),
#   ('절친', 'O'),
#   (' ', 'O'),
#   ('배우', 'OCCUPATION'),
#   (' ', 'O'),
#   ('진선미', 'PERSON'),
#   ('와', 'O'),
#   (' ', 'O'),
#   ('후배', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('정이랑', 'PERSON'),
#   ('을', 'O'),
#   (' ', 'O'),
#   ('만나', 'O'),
#   (' ', 'O'),
#   ('산', 'O'),
#   (' ', 'O'),
#   ('속에', 'O'),
#   (' ', 'O'),
#   ('위치한', 'O'),
#   (' ', 'O'),
#   ("'힐링", 'O'),
#   (' ', 'O'),
#   ("아지트'를", 'O'),
#   (' ', 'O'),
#   ('찾았다', 'O')],
#  [('최정윤', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('"그', 'O'),
#   (' ', 'O'),
#   ('작품을', 'O'),
#   (' ', 'O'),
#   ('하면서', 'O'),
#   (' ', 'O'),
#   ('상황도', 'O'),
#   (' ', 'O'),
#   ('힘들었고', 'O'),
#   (' ', 'O'),
#   ('의지할', 'O'),
#   (' ', 'O'),
#   ('곳이', 'O'),
#   (' ', 'O'),
#   ('필요했는데', 'O'),
#   (' ', 'O'),
#   ('그게', 'O'),
#   (' ', 'O'),
#   ('선미', 'PERSON'),
#   ('였던', 'O'),
#   (' ', 'O'),
#   ('거', 'O'),
#   (' ', 'O'),
#   ('같다"며', 'O'),
#   (' ', 'O'),
#   ('웃었다', 'O')],
#  [('진선미', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('"', 'O'),
#   ('정윤', 'PERSON'),
#   ('이가', 'O'),
#   (' ', 'O'),
#   ('이혼', 'O'),
#   (' ', 'O'),
#   ('기사가', 'O'),
#   (' ', 'O'),
#   ('나고', 'O'),
#   (' ', 'O'),
#   ('나는', 'O'),
#   (' ', 'O'),
#   ('스트레스를', 'O'),
#   (' ', 'O'),
#   ('받으면', 'O'),
#   (' ', 'O'),
#   ('울고,', 'O'),
#   (' ', 'O'),
#   ('이랑이', 'ANIMAL'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('소리를', 'O'),
#   (' ', 'O'),
#   ('지른다', 'O')],
#  [('정윤', 'PERSON'),
#   ('이는', 'O'),
#   (' ', 'O'),
#   ('스트레스', 'O'),
#   (' ', 'O'),
#   ('푸는', 'O'),
#   (' ', 'O'),
#   ('법이', 'O'),
#   (' ', 'O'),
#   ('없다"며', 'O'),
#   (' ', 'O'),
#   ('"우리랑', 'O'),
#   (' ', 'O'),
#   ('있으면', 'O'),
#   (' ', 'O'),
#   ('스트레스를', 'O'),
#   (' ', 'O'),
#   ('많이', 'O'),
#   (' ', 'O'),
#   ('푼다', 'O')],
#  [('후광이', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('예뻤다"고', 'O'),
#   (' ', 'O'),
#   ('떠올렸다', 'O')],
#  [('그때', 'O'),
#   (' ', 'O'),
#   ('진선미', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('"', 'O'),
#   ('정윤', 'PERSON'),
#   ('이는', 'O'),
#   (' ', 'O'),
#   ('몸매가', 'O'),
#   (' ', 'O'),
#   ('정말', 'O'),
#   (' ', 'O'),
#   ('예쁘다', 'O')],
#  [('남편', 'CIVILIZATION'),
#   ('한테', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('정윤', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('글래머에', 'O'),
#   (' ', 'O'),
#   ('우윳빛', 'TERM'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('허리', 'ANIMAL'),
#   ('로', 'O'),
#   (' ', 'O'),
#   ('들어가고', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('좋은데', 'O'),
#   (' ', 'O'),
#   ('왜', 'O'),
#   (' ', 'O'),
#   ('남편', 'CIVILIZATION'),
#   ('이', 'O')],
#  [('이에', 'O'),
#   (' ', 'O'),
#   ('최정윤', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('"세상', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('가질', 'O'),
#   (' ', 'O'),
#   ('수', 'O'),
#   (' ', 'O'),
#   ('없다"면서', 'O'),
#   (' ', 'O'),
#   ('"다음', 'O'),
#   (' ', 'O'),
#   ('생애', 'O'),
#   (' ', 'O'),
#   ('네가', 'O'),
#   (' ', 'O'),
#   ('내', 'O'),
#   (' ', 'O'),
#   ('남편', 'CIVILIZATION'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('되어달라"고', 'O'),
#   (' ', 'O'),
#   ('했다', 'O')],
#  [('그러자', 'O'),
#   (' ', 'O'),
#   ('진선미', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('"나는', 'O'),
#   (' ', 'O'),
#   ('네가', 'O'),
#   (' ', 'O'),
#   ('되고', 'O'),
#   (' ', 'O'),
#   ('싶다"고', 'O'),
#   (' ', 'O'),
#   ('했고,', 'O'),
#   (' ', 'O'),
#   ('최정윤', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('"나는', 'O'),
#   (' ', 'O'),
#   ('네가', 'O'),
#   (' ', 'O'),
#   ('부럽다', 'O')],
#  [('남편', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('사랑받지"라고', 'O'),
#   (' ', 'O'),
#   ('한', 'O'),
#   (' ', 'O'),
#   ('뒤', 'O'),
#   (' ', 'O'),
#   ('분위기가', 'O'),
#   (' ', 'O'),
#   ('싸해져', 'O'),
#   (' ', 'O'),
#   ('웃음을', 'O'),
#   (' ', 'O'),
#   ('안겼다', 'O')],
#  [('최정윤', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('"예전에', 'O'),
#   (' ', 'O'),
#   ('딸', 'CIVILIZATION'),
#   ('과', 'O'),
#   (' ', 'O'),
#   ('여기', 'O'),
#   (' ', 'O'),
#   ('올', 'O'),
#   (' ', 'O'),
#   ('때', 'O'),
#   (' ', 'O'),
#   ('눈물이', 'O'),
#   (' ', 'O'),
#   ('났었다"며', 'O'),
#   (' ', 'O'),
#   ('"힘들고', 'O'),
#   (' ', 'O'),
#   ('외롭기도', 'O'),
#   (' ', 'O'),
#   ('했지만', 'O'),
#   (' ', 'O'),
#   ('만감이', 'O'),
#   (' ', 'O'),
#   ('교차하는', 'O'),
#   (' ', 'O'),
#   ('기분이었다"고', 'O'),
#   (' ', 'O'),
#   ('떠올렸다', 'O')],
#  [('진선미', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('"우리', 'O'),
#   (' ', 'O'),
#   ('울', 'O'),
#   (' ', 'O'),
#   ('때', 'O'),
#   (' ', 'O'),
#   ('한심해', 'O'),
#   (' ', 'O'),
#   ('하지', 'O'),
#   (' ', 'O'),
#   ('않았냐"고', 'O'),
#   (' ', 'O'),
#   ('했고,', 'O'),
#   (' ', 'O'),
#   ('최정윤', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('"혼자', 'O'),
#   (' ', 'O'),
#   ('있을', 'O'),
#   (' ', 'O'),
#   ('땐', 'O'),
#   (' ', 'O'),
#   ('나도', 'O'),
#   (' ', 'O'),
#   ('운다"고', 'O'),
#   (' ', 'O'),
#   ('했다', 'O')],
#  [('이에', 'O'),
#   (' ', 'O'),
#   ('진선미', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('"네가', 'O'),
#   (' ', 'O'),
#   ('항상', 'O'),
#   (' ', 'O'),
#   ('덤덤하게', 'O'),
#   (' ', 'O'),
#   ('말한다"고', 'O'),
#   (' ', 'O'),
#   ('하자,', 'O'),
#   (' ', 'O'),
#   ('최정윤', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('"덤덤해야지', 'O'),
#   (' ', 'O'),
#   ('어떡해"라며', 'O'),
#   (' ', 'O'),
#   ('덤덤하게', 'O'),
#   (' ', 'O'),
#   ('말했다', 'O')],
#  [('세 사람', 'QUANTITY'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('족욕을', 'O'),
#   (' ', 'O'),
#   ('하며', 'O'),
#   (' ', 'O'),
#   ('전화로', 'O'),
#   (' ', 'O'),
#   ('사주를', 'O'),
#   (' ', 'O'),
#   ('봤다', 'O')],
#  [('그는', 'O'),
#   (' ', 'O'),
#   ('"', 'O'),
#   ('지우', 'PERSON'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('위해서는', 'O'),
#   (' ', 'O'),
#   ('뭐든', 'O'),
#   (' ', 'O'),
#   ('할거다', 'O')],
#  [('진선미', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('최정윤', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('가방을', 'O'),
#   (' ', 'O'),
#   ('팔고', 'O'),
#   (' ', 'O'),
#   ('왔던', 'O'),
#   (' ', 'O'),
#   ('일을', 'O'),
#   (' ', 'O'),
#   ('떠올렸다', 'O')],
#  [('차', 'ARTIFACT'),
#   (' ', 'O'),
#   ('팔아서', 'O'),
#   (' ', 'O'),
#   ('생활하고,', 'O'),
#   (' ', 'O'),
#   ('있는', 'O'),
#   (' ', 'O'),
#   ('걸', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('팔아야겠다는', 'O'),
#   (' ', 'O'),
#   ('생각을', 'O'),
#   (' ', 'O'),
#   ('했었다', 'O')],
#  [('청하', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('정규', 'O'),
#   (' ', 'O'),
#   ('1집', 'QUANTITY'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('Querencia', 'ARTIFACT'),
#   ("'", 'O'),
#   (' ', 'O'),
#   ('美', 'LOCATION'),
#   (' ', 'O'),
#   ('빌보드', 'ORGANIZATION'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('베스트', 'QUANTITY'),
#   (' ', 'O'),
#   ('앨범', 'O'),
#   (' ', 'O'),
#   ('50', 'QUANTITY'),
#   ("'", 'O'),
#   (' ', 'O'),
#   ('선정', 'O')],
#  [('솔로', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('아티스트', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('청하', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('첫 번째', 'QUANTITY'),
#   (' ', 'O'),
#   ('정규앨범이', 'O'),
#   (' ', 'O'),
#   ('빌보드', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('선정', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('베스트 앨', 'ARTIFACT'),
#   ('범', 'O'),
#   (' ', 'O'),
#   ('50', 'QUANTITY'),
#   ("'에", 'O'),
#   (' ', 'O'),
#   ('선정됐다', 'O')],
#  [('세계에서', 'O'),
#   (' ', 'O'),
#   ('가장', 'O'),
#   (' ', 'O'),
#   ('권위', 'O'),
#   (' ', 'O'),
#   ('있는', 'O'),
#   (' ', 'O'),
#   ('음악', 'O'),
#   (' ', 'O'),
#   ('전문', 'O'),
#   (' ', 'O'),
#   ('매체', 'O'),
#   (' ', 'O'),
#   ('빌보드', 'ORGANIZATION'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('최근', 'O'),
#   (' ', 'O'),
#   ('공식', 'O'),
#   (' ', 'O'),
#   ('홈페이지를', 'O'),
#   (' ', 'O'),
#   ('통해', 'O'),
#   (' ', 'O'),
#   ('발표한', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('2021 베스트 앨범 50', 'ARTIFACT'),
#   ("'에", 'O'),
#   (' ', 'O'),
#   ('따르면', 'O'),
#   (' ', 'O'),
#   ('지난 2월', 'DATE'),
#   (' ', 'O'),
#   ('발매된', 'O'),
#   (' ', 'O'),
#   ('청하', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('정규', 'O'),
#   (' ', 'O'),
#   ('1집', 'QUANTITY'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('Querencia', 'ARTIFACT'),
#   (' ', 'O'),
#   ('(', 'O'),
#   ('케렌시아', 'ARTIFACT'),
#   (")'는", 'O'),
#   (' ', 'O'),
#   ('쟁쟁한', 'O'),
#   (' ', 'O'),
#   ('글로벌', 'O'),
#   (' ', 'O'),
#   ('아티스트', 'CIVILIZATION'),
#   ('들의', 'O'),
#   (' ', 'O'),
#   ('앨범과', 'O'),
#   (' ', 'O'),
#   ('함께', 'O'),
#   (' ', 'O'),
#   ('베스트 50', 'QUANTITY'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('이름을', 'O'),
#   (' ', 'O'),
#   ('올렸다', 'O')],
#  [("'", 'O'),
#   ('Querencia', 'ARTIFACT'),
#   ("'를", 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('베스트 앨범', 'ARTIFACT'),
#   (' ', 'O'),
#   ('50', 'ARTIFACT'),
#   ("'에", 'O'),
#   (' ', 'O'),
#   ('추천한', 'O'),
#   (' ', 'O'),
#   ('빌보드', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('에디터', 'OCCUPATION'),
#   (' ', 'O'),
#   ('놀란 페니', 'PERSON'),
#   ('(Nolan', 'O'),
#   (' ', 'O'),
#   ('Feeney)는', 'O'),
#   (' ', 'O'),
#   ('청하', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('음반에', 'O'),
#   (' ', 'O'),
#   ('대해', 'O'),
#   (' ', 'O'),
#   ('"간주', 'O'),
#   (' ', 'O'),
#   ('부분까지', 'O'),
#   (' ', 'O'),
#   ('귀', 'ANIMAL'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('박히는', 'O'),
#   (' ', 'O'),
#   ('음반이다', 'O')],
#  [('21개', 'QUANTITY'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('트랙을', 'O'),
#   (' ', 'O'),
#   ('4개', 'QUANTITY'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('테마로', 'O'),
#   (' ', 'O'),
#   ('나눠', 'O'),
#   (' ', 'O'),
#   ('야심', 'O'),
#   (' ', 'O'),
#   ('차게', 'O'),
#   (' ', 'O'),
#   ('담아냈다"고', 'O'),
#   (' ', 'O'),
#   ('소개했다', 'O')],
#  [('특히', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('Stay Tonight', 'ARTIFACT'),
#   (' ', 'O'),
#   ('(', 'O'),
#   ('스테이 투나잇', 'ARTIFACT'),
#   (")'", 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('X', 'ARTIFACT'),
#   (' ', 'O'),
#   ('(', 'O'),
#   ('걸어온 길에 꽃밭 따윈 없었죠', 'ARTIFACT'),
#   (")'", 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('Demente', 'ARTIFACT'),
#   (' ', 'O'),
#   ('(', 'O'),
#   ('데멘테', 'ARTIFACT'),
#   (")'", 'O'),
#   (' ', 'O'),
#   ('등의', 'O'),
#   (' ', 'O'),
#   ('수록곡을', 'O'),
#   (' ', 'O'),
#   ('언급하며', 'O'),
#   (' ', 'O'),
#   ('"', 'O'),
#   ('EDM', 'STUDY_FIELD'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('록 발라드', 'STUDY_FIELD'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('라틴음악', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('등', 'O'),
#   (' ', 'O'),
#   ('다채로운', 'O'),
#   (' ', 'O'),
#   ('장르가', 'O'),
#   (' ', 'O'),
#   ('인상적"이라고', 'O'),
#   (' ', 'O'),
#   ('덧붙였다', 'O')],
#  [('그뿐만', 'O'),
#   (' ', 'O'),
#   ('아니라', 'O'),
#   (' ', 'O'),
#   ('"\'', 'O'),
#   ('Querencia', 'ARTIFACT'),
#   ("'에는", 'O'),
#   (' ', 'O'),
#   ('다양한', 'O'),
#   (' ', 'O'),
#   ('사운드를', 'O'),
#   (' ', 'O'),
#   ('하나', 'QUANTITY'),
#   ('로', 'O'),
#   (' ', 'O'),
#   ('묶는', 'O'),
#   (' ', 'O'),
#   ('정교함이', 'O'),
#   (' ', 'O'),
#   ('있으며,', 'O'),
#   (' ', 'O'),
#   ('청하', 'PERSON'),
#   (' ', 'O'),
#   ('특유의', 'O'),
#   (' ', 'O'),
#   ('카멜레온을', 'O'),
#   (' ', 'O'),
#   ('연상케', 'O'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('독특한', 'O'),
#   (' ', 'O'),
#   ('보이스는', 'O'),
#   (' ', 'O'),
#   ('음악을', 'O'),
#   (' ', 'O'),
#   ('더', 'O'),
#   (' ', 'O'),
#   ('듣고', 'O'),
#   (' ', 'O'),
#   ('싶게', 'O'),
#   (' ', 'O'),
#   ('만든다"고', 'O'),
#   (' ', 'O'),
#   ('극찬했다', 'O')],
#  [("'", 'O'),
#   ('빌보드', 'EVENT'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('베스트 앨', 'EVENT'),
#   ('범', 'O'),
#   (' ', 'O'),
#   ('50', 'QUANTITY'),
#   ("'에", 'O'),
#   (' ', 'O'),
#   ('이름을', 'O'),
#   (' ', 'O'),
#   ('올린', 'O'),
#   (' ', 'O'),
#   ('청하', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('정규', 'O'),
#   (' ', 'O'),
#   ('1집', 'QUANTITY'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('Querencia', 'ARTIFACT'),
#   ("'는", 'O'),
#   (' ', 'O'),
#   ('타이틀곡', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('Bicycle', 'ARTIFACT'),
#   (' ', 'O'),
#   ('(', 'O'),
#   ('바이시클', 'ARTIFACT'),
#   (")'을", 'O'),
#   (' ', 'O'),
#   ('비롯해', 'O'),
#   (' ', 'O'),
#   ('청하', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('음악적', 'O'),
#   (' ', 'O'),
#   ('역량을', 'O'),
#   (' ', 'O'),
#   ('확인할', 'O'),
#   (' ', 'O'),
#   ('수', 'O'),
#   (' ', 'O'),
#   ('있는', 'O'),
#   (' ', 'O'),
#   ('다양한', 'O'),
#   (' ', 'O'),
#   ('장르의', 'O'),
#   (' ', 'O'),
#   ('21개', 'QUANTITY'),
#   (' ', 'O'),
#   ('트랙으로', 'O'),
#   (' ', 'O'),
#   ('꽉', 'O'),
#   (' ', 'O'),
#   ('채운', 'O'),
#   (' ', 'O'),
#   ('웰메이드', 'O'),
#   (' ', 'O'),
#   ('음반이다', 'O')],
#  [('한편,', 'O'),
#   (' ', 'O'),
#   ('청하', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('최근', 'O'),
#   (' ', 'O'),
#   ('콜드', 'ORGANIZATION'),
#   ('와', 'O'),
#   (' ', 'O'),
#   ('리메이크', 'O'),
#   (' ', 'O'),
#   ('음원', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('내 입술 따뜻한 커피처럼', 'ARTIFACT'),
#   ("'을", 'O'),
#   (' ', 'O'),
#   ('발매하고', 'O'),
#   (' ', 'O'),
#   ('각종', 'O'),
#   (' ', 'O'),
#   ('음원사이트', 'O'),
#   (' ', 'O'),
#   ('실시간', 'O'),
#   (' ', 'O'),
#   ('차트에서', 'O'),
#   (' ', 'O'),
#   ('1위', 'QUANTITY'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('차지하는', 'O'),
#   (' ', 'O'),
#   ('등', 'O'),
#   (' ', 'O'),
#   ('가파른', 'O'),
#   (' ', 'O'),
#   ('상승세를', 'O'),
#   (' ', 'O'),
#   ('보이며', 'O'),
#   (' ', 'O'),
#   ('뜨거운', 'O'),
#   (' ', 'O'),
#   ('반응을', 'O'),
#   (' ', 'O'),
#   ('얻고', 'O'),
#   (' ', 'O'),
#   ('있다', 'O')],
#  [('사진', 'O'),
#   (' ', 'O'),
#   ('=', 'O'),
#   (' ', 'O'),
#   ('MNH엔터테인먼트', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('제공', 'O'),
#   (' ', 'O'),
#   ('※', 'O'),
#   (' ', 'O'),
#   ('ⓒ', 'O'),
#   (' ', 'O'),
#   ('SBS', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('&', 'O'),
#   (' ', 'O'),
#   ('SBS', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('Digital', 'O'),
#   (' ', 'O'),
#   ('News', 'O'),
#   (' ', 'O'),
#   ('Lab', 'O')],
#  [('YG', 'ORGANIZATION'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('AKMU', 'ORGANIZATION'),
#   ('와', 'O'),
#   (' ', 'O'),
#   ('5년', 'DATE'),
#   (' ', 'O'),
#   ('재계약', 'O'),
#   (' ', 'O'),
#   ('체결', 'O'),
#   (' ', 'O'),
#   ('공식', 'O'),
#   (' ', 'O'),
#   ('발표', 'O'),
#   (' ', 'O'),
#   ('"은퇴를', 'O'),
#   (' ', 'O'),
#   ('하면', 'O'),
#   (' ', 'O'),
#   ('했지', 'O'),
#   (' ', 'O'),
#   ('다른', 'O'),
#   (' ', 'O'),
#   ('회사', 'O'),
#   (' ', 'O'),
#   ('갈', 'O'),
#   (' ', 'O'),
#   ('생각', 'O'),
#   (' ', 'O'),
#   ('한 번', 'QUANTITY'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('해', 'O'),
#   (' ', 'O'),
#   ('본', 'O'),
#   (' ', 'O'),
#   ('적', 'O'),
#   (' ', 'O'),
#   ('없다"', 'O')],
#  [('7년간', 'DATE'),
#   (' ', 'O'),
#   ('단', 'O'),
#   (' ', 'O'),
#   ('한 번', 'QUANTITY'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('작은', 'O'),
#   (' ', 'O'),
#   ('마찰이나', 'O'),
#   (' ', 'O'),
#   ('의견', 'O'),
#   (' ', 'O'),
#   ('대립', 'O'),
#   (' ', 'O'),
#   ('없이', 'O'),
#   (' ', 'O'),
#   ('우리가', 'O'),
#   (' ', 'O'),
#   ('나아가자', 'O'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('방향으로', 'O'),
#   (' ', 'O'),
#   ('든든하게', 'O'),
#   (' ', 'O'),
#   ('지원해주고', 'O'),
#   (' ', 'O'),
#   ('어린', 'O'),
#   (' ', 'O'),
#   ('우리들을', 'O'),
#   (' ', 'O'),
#   ('잘', 'O'),
#   (' ', 'O'),
#   ('이끌어준', 'O'),
#   (' ', 'O'),
#   ('회사"라며', 'O'),
#   (' ', 'O'),
#   ('YG', 'ORGANIZATION'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('대한', 'O'),
#   (' ', 'O'),
#   ('무한', 'O'),
#   (' ', 'O'),
#   ('신뢰를', 'O'),
#   (' ', 'O'),
#   ('표현했다', 'O')],
#  [('특히', 'O'),
#   (' ', 'O'),
#   ('AKMU', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('이수현', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('소감이', 'O'),
#   (' ', 'O'),
#   ('눈길을', 'O'),
#   (' ', 'O'),
#   ('끈다', 'O')],
#  [('이수현', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('"우리는', 'O'),
#   (' ', 'O'),
#   ('은퇴를', 'O'),
#   (' ', 'O'),
#   ('하면', 'O'),
#   (' ', 'O'),
#   ('했지', 'O'),
#   (' ', 'O'),
#   ('YG', 'ORGANIZATION'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('떠날', 'O'),
#   (' ', 'O'),
#   ('생각을', 'O'),
#   (' ', 'O'),
#   ('단', 'O'),
#   (' ', 'O'),
#   ('한 번', 'QUANTITY'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('해', 'O'),
#   (' ', 'O'),
#   ('본', 'O'),
#   (' ', 'O'),
#   ('적', 'O'),
#   (' ', 'O'),
#   ('없다"라며', 'O'),
#   (' ', 'O'),
#   ('단호하고', 'O'),
#   (' ', 'O'),
#   ('짧은', 'O'),
#   (' ', 'O'),
#   ('소감으로', 'O'),
#   (' ', 'O'),
#   ('재계약', 'O'),
#   (' ', 'O'),
#   ('이유를', 'O'),
#   (' ', 'O'),
#   ('밝혔다', 'O')],
#  [('악뮤', 'O'),
#   (' ', 'O'),
#   ('YG', 'ORGANIZATION'),
#   ('와', 'O'),
#   (' ', 'O'),
#   ('재계약…', 'O'),
#   (' ', 'O'),
#   ('"은퇴하면', 'O'),
#   (' ', 'O'),
#   ('했지', 'O'),
#   (' ', 'O'),
#   ('떠날', 'O'),
#   (' ', 'O'),
#   ('생각', 'O'),
#   (' ', 'O'),
#   ('없어"', 'O')],
#  [('7년간', 'DATE'),
#   (' ', 'O'),
#   ('단', 'O'),
#   (' ', 'O'),
#   ('한 번', 'QUANTITY'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('작은', 'O'),
#   (' ', 'O'),
#   ('마찰이나', 'O'),
#   (' ', 'O'),
#   ('의견', 'O'),
#   (' ', 'O'),
#   ('대립', 'O'),
#   (' ', 'O'),
#   ('없이', 'O'),
#   (' ', 'O'),
#   ('우리가', 'O'),
#   (' ', 'O'),
#   ('나아가자', 'O'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('방향으로', 'O'),
#   (' ', 'O'),
#   ('든든하게', 'O'),
#   (' ', 'O'),
#   ('지원해주고', 'O'),
#   (' ', 'O'),
#   ('어린', 'O'),
#   (' ', 'O'),
#   ('우리들을', 'O'),
#   (' ', 'O'),
#   ('잘', 'O'),
#   (' ', 'O'),
#   ('이끌어준', 'O'),
#   (' ', 'O'),
#   ('회사"라며', 'O'),
#   (' ', 'O'),
#   ('YG', 'ORGANIZATION'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('대한', 'O'),
#   (' ', 'O'),
#   ('무한', 'O'),
#   (' ', 'O'),
#   ('신뢰를', 'O'),
#   (' ', 'O'),
#   ('표현했다', 'O')],
#  [('AKMU', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('이수현', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('"우리는', 'O'),
#   (' ', 'O'),
#   ('은퇴를', 'O'),
#   (' ', 'O'),
#   ('하면', 'O'),
#   (' ', 'O'),
#   ('했지', 'O'),
#   (' ', 'O'),
#   ('YG', 'ORGANIZATION'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('떠날', 'O'),
#   (' ', 'O'),
#   ('생각을', 'O'),
#   (' ', 'O'),
#   ('단', 'O'),
#   (' ', 'O'),
#   ('한 번', 'QUANTITY'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('해', 'O'),
#   (' ', 'O'),
#   ('본', 'O'),
#   (' ', 'O'),
#   ('적', 'O'),
#   (' ', 'O'),
#   ('없다"라며', 'O'),
#   (' ', 'O'),
#   ('단호하고', 'O'),
#   (' ', 'O'),
#   ('짧은', 'O'),
#   (' ', 'O'),
#   ('소감으로', 'O'),
#   (' ', 'O'),
#   ('재계약', 'O'),
#   (' ', 'O'),
#   ('이유를', 'O'),
#   (' ', 'O'),
#   ('밝혔다', 'O')],
#  [('YG', 'ORGANIZATION'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('AKMU', 'PERSON'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('대해', 'O'),
#   (' ', 'O'),
#   ('"아직', 'O'),
#   (' ', 'O'),
#   ('나이가', 'O'),
#   (' ', 'O'),
#   ('어린', 'O'),
#   (' ', 'O'),
#   ('친구', 'CIVILIZATION'),
#   ('들이지만', 'O'),
#   (' ', 'O'),
#   ('생각이', 'O'),
#   (' ', 'O'),
#   ('깊고', 'O'),
#   (' ', 'O'),
#   ('굉장히', 'O'),
#   (' ', 'O'),
#   ('어른스러운', 'O'),
#   (' ', 'O'),
#   ('면이', 'O'),
#   (' ', 'O'),
#   ('있는', 'O'),
#   (' ', 'O'),
#   ('친구', 'CIVILIZATION'),
#   ('들이다', 'O')],
#  [('트와이스', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('컴백과', 'O'),
#   (' ', 'O'),
#   ('동시에', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('레이더', 'O'),
#   (' ', 'O'),
#   ('차트', 'O'),
#   (' ', 'O'),
#   ('1위', 'QUANTITY')],
#  [('걸그룹', 'O'),
#   (' ', 'O'),
#   ('트와이스', 'PERSON'),
#   ('(', 'O'),
#   ('TWICE', 'PERSON'),
#   (')가', 'O'),
#   (' ', 'O'),
#   ('신곡', 'O'),
#   (' ', 'O'),
#   ('‘', 'O'),
#   ('SCIENTIST', 'ARTIFACT'),
#   ('’로', 'O'),
#   (' ', 'O'),
#   ('컴백과', 'O'),
#   (' ', 'O'),
#   ('동시에', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('레이더', 'O'),
#   (' ', 'O'),
#   ('차트', 'O'),
#   (' ', 'O'),
#   ('1위', 'QUANTITY'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('차지했다', 'O')],
#  [('트와이스', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('신곡', 'O'),
#   (' ', 'O'),
#   ('‘', 'O'),
#   ('SCIENTIST', 'ARTIFACT'),
#   ('’', 'O'),
#   (' ', 'O'),
#   ('뮤직비디오는', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('레이더', 'O'),
#   (' ', 'O'),
#   ('46주차', 'DATE'),
#   (' ', 'O'),
#   ('집계', 'O'),
#   (' ', 'O'),
#   ('기간(', 'O'),
#   ('11월 7일~11월 13일', 'DATE'),
#   (')', 'O'),
#   (' ', 'O'),
#   ('동안', 'O'),
#   (' ', 'O'),
#   ('2,465만 뷰', 'QUANTITY'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('조회수를', 'O'),
#   (' ', 'O'),
#   ('발생시켰다', 'O')],
#  [('실제', 'O'),
#   (' ', 'O'),
#   ('‘', 'O'),
#   ('SCIENTIST', 'ARTIFACT'),
#   ('’', 'O'),
#   (' ', 'O'),
#   ('뮤직비디오는', 'O'),
#   (' ', 'O'),
#   ('공개', 'O'),
#   (' ', 'O'),
#   ('후', 'O'),
#   (' ', 'O'),
#   ('약 6시간 만', 'TIME'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('500만', 'QUANTITY'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('약 19시간 만', 'TIME'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('1,000만', 'QUANTITY'),
#   (' ', 'O'),
#   ('조회수를', 'O'),
#   (' ', 'O'),
#   ('기록하며', 'O'),
#   (' ', 'O'),
#   ('여전한', 'O'),
#   (' ', 'O'),
#   ('인기를', 'O'),
#   (' ', 'O'),
#   ('자랑했다', 'O')],
#  [('실제', 'O'),
#   (' ', 'O'),
#   ('‘', 'O'),
#   ('SCIENTIST', 'ARTIFACT'),
#   ('’', 'O'),
#   (' ', 'O'),
#   ('뮤직비디오는', 'O'),
#   (' ', 'O'),
#   ('공개', 'O'),
#   (' ', 'O'),
#   ('후', 'O'),
#   (' ', 'O'),
#   ('약 6시간 만', 'TIME'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('500만', 'QUANTITY'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('약 19시간 만', 'TIME'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('1,000만', 'QUANTITY'),
#   (' ', 'O'),
#   ('조회수를', 'O'),
#   (' ', 'O'),
#   ('기록하며', 'O'),
#   (' ', 'O'),
#   ('여전한', 'O'),
#   (' ', 'O'),
#   ('인기를', 'O'),
#   (' ', 'O'),
#   ('자랑했다', 'O')],
#  [('케이팝 레이더', 'ORGANIZATION'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('분석한', 'O'),
#   (' ', 'O'),
#   ('트와이스', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('국가별', 'O'),
#   (' ', 'O'),
#   ('유튜브', 'TERM'),
#   (' ', 'O'),
#   ('조회수에', 'O'),
#   (' ', 'O'),
#   ('따르면,', 'O'),
#   (' ', 'O'),
#   ('지난 일주일 동안', 'DATE'),
#   (' ', 'O'),
#   ('트와이스', 'PERSON'),
#   ('에게는', 'O'),
#   (' ', 'O'),
#   ('약 1억 1900만 건', 'QUANTITY'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('조회수가', 'O'),
#   (' ', 'O'),
#   ('발생했다', 'O')],
#  [('5%', 'QUANTITY'),
#   ('로', 'O'),
#   (' ', 'O'),
#   ('가장', 'O'),
#   (' ', 'O'),
#   ('높은', 'O'),
#   (' ', 'O'),
#   ('비중을', 'O'),
#   (' ', 'O'),
#   ('차지했고,', 'O'),
#   (' ', 'O'),
#   ('필리핀', 'COUNTRY'),
#   (' ', 'O'),
#   ('10', 'QUANTITY')],
#  [('9%', 'QUANTITY'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('조회수', 'O'),
#   (' ', 'O'),
#   ('비중을', 'O'),
#   (' ', 'O'),
#   ('차지한', 'O'),
#   (' ', 'O'),
#   ('것으로', 'O'),
#   (' ', 'O'),
#   ('분석되었다', 'O')],
#  [('이에', 'O'),
#   (' ', 'O'),
#   ('케이팝 레이더', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('측은', 'O'),
#   (' ', 'O'),
#   ('“', 'O'),
#   ('트와이스', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('대한민국', 'COUNTRY'),
#   ('을', 'O'),
#   (' ', 'O'),
#   ('대표하는', 'O'),
#   (' ', 'O'),
#   ('글로벌', 'O'),
#   (' ', 'O'),
#   ('탑', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('아티스트', 'CIVILIZATION'),
#   ('”라며', 'O'),
#   (' ', 'O'),
#   ('"높은', 'O'),
#   (' ', 'O'),
#   ('연차에도', 'O'),
#   (' ', 'O'),
#   ('여전한', 'O'),
#   (' ', 'O'),
#   ('국내외', 'O'),
#   (' ', 'O'),
#   ('인기가', 'O'),
#   (' ', 'O'),
#   ('놀랍다"고', 'O'),
#   (' ', 'O'),
#   ('전했다', 'O')],
#  [('또한', 'O'),
#   (' ', 'O'),
#   ('이번주', 'DATE'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('레이더', 'O'),
#   (' ', 'O'),
#   ('주간', 'O'),
#   (' ', 'O'),
#   ('차트에서는', 'O'),
#   (' ', 'O'),
#   ('원어스', 'PERSON'),
#   ('(ONEUS)의', 'O'),
#   (' ', 'O'),
#   ('‘', 'O'),
#   ('월하미인', 'ARTIFACT'),
#   (' ', 'O'),
#   ('(月下美人', 'O'),
#   (' ', 'O'),
#   (':', 'O'),
#   (' ', 'O'),
#   ('LUNA)’', 'O'),
#   (' ', 'O'),
#   ('뮤직비디오가', 'O'),
#   (' ', 'O'),
#   ('1,516만 뷰', 'QUANTITY'),
#   ('로', 'O'),
#   (' ', 'O'),
#   ('2위', 'QUANTITY'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('진입했으며,', 'O'),
#   (' ', 'O'),
#   ('TO1', 'PERSON'),
#   ('(', 'O'),
#   ('티오원', 'PERSON'),
#   (')의', 'O'),
#   (' ', 'O'),
#   ('‘', 'O'),
#   ('No More X', 'ARTIFACT'),
#   ('’가', 'O'),
#   (' ', 'O'),
#   ('1,045만 뷰', 'QUANTITY'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('추가해', 'O'),
#   (' ', 'O'),
#   ('무려', 'O'),
#   (' ', 'O'),
#   ('85계단', 'QUANTITY'),
#   ('을', 'O'),
#   (' ', 'O'),
#   ('상승한', 'O'),
#   (' ', 'O'),
#   ('5위', 'QUANTITY'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('이름을', 'O'),
#   (' ', 'O'),
#   ('올렸다', 'O')],
#  [('케이팝 레이더', 'TERM'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('기존', 'O'),
#   (' ', 'O'),
#   ('‘뮤직비디오', 'O'),
#   (' ', 'O'),
#   ('주간', 'DATE'),
#   (' ', 'O'),
#   ('차트’에', 'O'),
#   (' ', 'O'),
#   ('이어,', 'O'),
#   (' ', 'O'),
#   ('‘', 'O'),
#   ('주', 'DATE'),
#   ('간', 'O'),
#   (' ', 'O'),
#   ('팬덤', 'O'),
#   (' ', 'O'),
#   ('차트’를', 'O'),
#   (' ', 'O'),
#   ('공개해', 'O'),
#   (' ', 'O'),
#   ('규모', 'O'),
#   (' ', 'O'),
#   ('있는', 'O'),
#   (' ', 'O'),
#   ('팬덤', 'O'),
#   (' ', 'O'),
#   ('확장을', 'O'),
#   (' ', 'O'),
#   ('기록한', 'O'),
#   (' ', 'O'),
#   ('아티스트', 'CIVILIZATION'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('공개할', 'O'),
#   (' ', 'O'),
#   ('예정이다', 'O')],
#  [('이번', 'O'),
#   (' ', 'O'),
#   ('46주차', 'DATE'),
#   (' ', 'O'),
#   ('주간', 'O'),
#   (' ', 'O'),
#   ('팬덤', 'O'),
#   (' ', 'O'),
#   ('차트에서는', 'O'),
#   (' ', 'O'),
#   ('‘', 'O'),
#   ('걸스플래닛 999 : 소녀대전', 'ARTIFACT'),
#   ('’을', 'O'),
#   (' ', 'O'),
#   ('통해', 'O'),
#   (' ', 'O'),
#   ('결성된', 'O'),
#   (' ', 'O'),
#   ('신인', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('걸그룹', 'O'),
#   (' ', 'O'),
#   ('Kep1er', 'PERSON'),
#   ('(', 'O'),
#   ('케플러', 'PERSON'),
#   (')가', 'O'),
#   (' ', 'O'),
#   ('뜨거운', 'O'),
#   (' ', 'O'),
#   ('관심을', 'O'),
#   (' ', 'O'),
#   ('이어가며', 'O'),
#   (' ', 'O'),
#   ('트위터', 'TERM'),
#   (' ', 'O'),
#   ('차트', 'O'),
#   (' ', 'O'),
#   ('5위', 'QUANTITY'),
#   (' ', 'O'),
#   ('자리를', 'O'),
#   (' ', 'O'),
#   ('지켰고,', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('레이더', 'TERM'),
#   (' ', 'O'),
#   ('차트', 'O'),
#   (' ', 'O'),
#   ('1위', 'QUANTITY'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('오른', 'O'),
#   (' ', 'O'),
#   ('트와이스', 'PERSON'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('인스타그램', 'TERM'),
#   (' ', 'O'),
#   ('차트에서도', 'O'),
#   (' ', 'O'),
#   ('3계단', 'QUANTITY'),
#   (' ', 'O'),
#   ('상승하며', 'O'),
#   (' ', 'O'),
#   ('9위', 'QUANTITY'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('진입하였다', 'O')],
#  [('스포티파', 'TERM'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('차트에서는', 'O'),
#   (' ', 'O'),
#   ('BTS', 'PERSON'),
#   ('(', 'O'),
#   ('방탄소년단', 'PERSON'),
#   (')의', 'O'),
#   (' ', 'O'),
#   ('멤버', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('V', 'PERSON'),
#   ('(', 'O'),
#   ('뷔', 'PERSON'),
#   (')가', 'O'),
#   (' ', 'O'),
#   ('61,083명', 'QUANTITY'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('팔로워', 'CIVILIZATION'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('추가하며', 'O'),
#   (' ', 'O'),
#   ('9위', 'QUANTITY'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('올랐다', 'O')],
#  [("'", 'O'),
#   ('6주년', 'DATE'),
#   ("'", 'O'),
#   (' ', 'O'),
#   ('트와이스', 'PERSON'),
#   (' ', 'O'),
#   ('"', 'O'),
#   ('원스', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('어떤', 'O'),
#   (' ', 'O'),
#   ('순간에도', 'O'),
#   (' ', 'O'),
#   ('힘이', 'O'),
#   (' ', 'O'),
#   ('돼주는', 'O'),
#   (' ', 'O'),
#   ('존재"[일문일답]', 'O')],
#  [('컴백', 'O'),
#   (' ', 'O'),
#   ('앨범으로', 'O'),
#   (' ', 'O'),
#   ('돌아온', 'O'),
#   (' ', 'O'),
#   ('걸그룹', 'O'),
#   (' ', 'O'),
#   ('트와이스', 'PERSON'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('데뷔', 'O'),
#   (' ', 'O'),
#   ('6주년', 'DATE'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('대한', 'O'),
#   (' ', 'O'),
#   ('남다른', 'O'),
#   (' ', 'O'),
#   ('생각을', 'O'),
#   (' ', 'O'),
#   ('전했다', 'O')],
#  [('트와이스', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('지난 12일', 'DATE'),
#   (' ', 'O'),
#   ('정규', 'O'),
#   (' ', 'O'),
#   ('3집', 'QUANTITY'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('Formula of Love: O+T=<3', 'ARTIFACT'),
#   ("'(", 'O'),
#   ('포뮬러 오브 러브: O+T=<3', 'ARTIFACT'),
#   (')와', 'O'),
#   (' ', 'O'),
#   ('타이틀', 'O'),
#   (' ', 'O'),
#   ('곡', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('SCIENTIST', 'ARTIFACT'),
#   ("'(", 'O'),
#   ('사이언티스트', 'ARTIFACT'),
#   (')를', 'O'),
#   (' ', 'O'),
#   ('발매하고', 'O'),
#   (' ', 'O'),
#   ('컴백했다', 'O')],
#  [('해당', 'O'),
#   (' ', 'O'),
#   ('신보는', 'O'),
#   (' ', 'O'),
#   ('10일', 'DATE'),
#   (' ', 'O'),
#   ('기준', 'O'),
#   (' ', 'O'),
#   ('선주문량', 'O'),
#   (' ', 'O'),
#   ('70만 장', 'QUANTITY'),
#   ('을', 'O'),
#   (' ', 'O'),
#   ('돌파해', 'O'),
#   (' ', 'O'),
#   ('전작인', 'O'),
#   (' ', 'O'),
#   ('미니', 'O'),
#   (' ', 'O'),
#   ('10집', 'QUANTITY'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('Taste of Love', 'ARTIFACT'),
#   ("'(", 'O'),
#   ('테이스트 오브 러브', 'ARTIFACT'),
#   (')보다', 'O'),
#   (' ', 'O'),
#   ('20만 장 이상', 'QUANTITY'),
#   (' ', 'O'),
#   ('증가한', 'O'),
#   (' ', 'O'),
#   ('수치로', 'O'),
#   (' ', 'O'),
#   ('자체', 'O'),
#   (' ', 'O'),
#   ('최고', 'O'),
#   (' ', 'O'),
#   ('기록을', 'O'),
#   (' ', 'O'),
#   ('새로', 'O'),
#   (' ', 'O'),
#   ('썼으며', 'O'),
#   (' ', 'O'),
#   ('12일', 'DATE'),
#   (' ', 'O'),
#   ('기준', 'O'),
#   (' ', 'O'),
#   ('한터차트', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('음반', 'O'),
#   (' ', 'O'),
#   ('일간', 'O'),
#   (' ', 'O'),
#   ('차트와', 'O'),
#   (' ', 'O'),
#   ('가온차트', 'ORGANIZATION'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('리테일', 'O'),
#   (' ', 'O'),
#   ('앨범', 'O'),
#   (' ', 'O'),
#   ('일간', 'O'),
#   (' ', 'O'),
#   ('차트', 'O'),
#   (' ', 'O'),
#   ('모두', 'O'),
#   (' ', 'O'),
#   ('정상에', 'O'),
#   (' ', 'O'),
#   ('올랐고,', 'O'),
#   (' ', 'O'),
#   ('13일', 'DATE'),
#   (' ', 'O'),
#   ('자에도', 'O'),
#   (' ', 'O'),
#   ('해당', 'O'),
#   (' ', 'O'),
#   ('차트', 'O'),
#   (' ', 'O'),
#   ('1위', 'QUANTITY'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('차지했다', 'O')],
#  [('해당', 'O'),
#   (' ', 'O'),
#   ('신보는', 'O'),
#   (' ', 'O'),
#   ('10일', 'DATE'),
#   (' ', 'O'),
#   ('기준', 'O'),
#   (' ', 'O'),
#   ('선주문량', 'O'),
#   (' ', 'O'),
#   ('70만 장', 'QUANTITY'),
#   ('을', 'O'),
#   (' ', 'O'),
#   ('돌파해', 'O'),
#   (' ', 'O'),
#   ('전작인', 'O'),
#   (' ', 'O'),
#   ('미니', 'O'),
#   (' ', 'O'),
#   ('10집', 'QUANTITY'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('Taste of Love', 'ARTIFACT'),
#   ("'(", 'O'),
#   ('테이스트 오브 러브', 'ARTIFACT'),
#   (')보다', 'O'),
#   (' ', 'O'),
#   ('20만 장 이상', 'QUANTITY'),
#   (' ', 'O'),
#   ('증가한', 'O'),
#   (' ', 'O'),
#   ('수치로', 'O'),
#   (' ', 'O'),
#   ('자체', 'O'),
#   (' ', 'O'),
#   ('최고', 'O'),
#   (' ', 'O'),
#   ('기록을', 'O'),
#   (' ', 'O'),
#   ('새로', 'O'),
#   (' ', 'O'),
#   ('썼으며', 'O'),
#   (' ', 'O'),
#   ('12일', 'DATE'),
#   (' ', 'O'),
#   ('기준', 'O'),
#   (' ', 'O'),
#   ('한터차트', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('음반', 'O'),
#   (' ', 'O'),
#   ('일간', 'O'),
#   (' ', 'O'),
#   ('차트와', 'O'),
#   (' ', 'O'),
#   ('가온차트', 'ORGANIZATION'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('리테일', 'O'),
#   (' ', 'O'),
#   ('앨범', 'O'),
#   (' ', 'O'),
#   ('일간', 'O'),
#   (' ', 'O'),
#   ('차트', 'O'),
#   (' ', 'O'),
#   ('모두', 'O'),
#   (' ', 'O'),
#   ('정상에', 'O'),
#   (' ', 'O'),
#   ('올랐고,', 'O'),
#   (' ', 'O'),
#   ('13일', 'DATE'),
#   (' ', 'O'),
#   ('자에도', 'O'),
#   (' ', 'O'),
#   ('해당', 'O'),
#   (' ', 'O'),
#   ('차트', 'O'),
#   (' ', 'O'),
#   ('1위', 'QUANTITY'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('차지했다', 'O')],
#  [('이와', 'O'),
#   (' ', 'O'),
#   ('함께', 'O'),
#   (' ', 'O'),
#   ('트와이스', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('12일', 'DATE'),
#   (' ', 'O'),
#   ('스포티파이', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('톱', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('아티스트', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('글로벌', 'O'),
#   (' ', 'O'),
#   ('차트', 'O'),
#   (' ', 'O'),
#   ('32위', 'QUANTITY'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('랭크됐고', 'O'),
#   (' ', 'O'),
#   ('신곡', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('SCIENTIST', 'ARTIFACT'),
#   ("'", 'O'),
#   (' ', 'O'),
#   ('뮤직비디오는', 'O'),
#   (' ', 'O'),
#   ('13일', 'DATE'),
#   (' ', 'O'),
#   ('유튜브', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('뮤직비디오', 'O'),
#   (' ', 'O'),
#   ('트렌딩', 'O'),
#   (' ', 'O'),
#   ('월드와이드', 'O'),
#   (' ', 'O'),
#   ('1위', 'QUANTITY'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('기록했다', 'O')],
#  [('▶', 'O'),
#   ('지효', 'PERSON'),
#   ('=저는', 'O'),
#   (' ', 'O'),
#   ('듣자마자', 'O'),
#   (' ', 'O'),
#   ("'엉뚱하고", 'O'),
#   (' ', 'O'),
#   ("귀엽다'는", 'O'),
#   (' ', 'O'),
#   ('생각이', 'O'),
#   (' ', 'O'),
#   ('들었어요', 'O')],
#  [('이', 'O'),
#   (' ', 'O'),
#   ('노래를', 'O'),
#   (' ', 'O'),
#   ('듣는', 'O'),
#   (' ', 'O'),
#   ('여러분들에게', 'O'),
#   (' ', 'O'),
#   ('위안이', 'O'),
#   (' ', 'O'),
#   ('된다면', 'O'),
#   (' ', 'O'),
#   ('그리고', 'O'),
#   (' ', 'O'),
#   ('감상', 'O'),
#   (' ', 'O'),
#   ('후기를', 'O'),
#   (' ', 'O'),
#   ('보게', 'O'),
#   (' ', 'O'),
#   ('된다면', 'O'),
#   (' ', 'O'),
#   ('정말', 'O'),
#   (' ', 'O'),
#   ('벅차고', 'O'),
#   (' ', 'O'),
#   ('기쁠', 'O'),
#   (' ', 'O'),
#   ('것', 'O'),
#   (' ', 'O'),
#   ('같아요', 'O')],
#  [('▶', 'O'),
#   ('지효', 'PERSON'),
#   ('=혼자서', 'O'),
#   (' ', 'O'),
#   ('작곡을', 'O'),
#   (' ', 'O'),
#   ('해본', 'O'),
#   (' ', 'O'),
#   ('첫', 'O'),
#   (' ', 'O'),
#   ('노래인데,', 'O'),
#   (' ', 'O'),
#   ('이렇게', 'O'),
#   (' ', 'O'),
#   ('트와이스', 'PERSON'),
#   (' ', 'O'),
#   ('앨범에', 'O'),
#   (' ', 'O'),
#   ('올릴', 'O'),
#   (' ', 'O'),
#   ('수', 'O'),
#   (' ', 'O'),
#   ('있어서', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('기쁩니다', 'O')],
#  [('제가', 'O'),
#   (' ', 'O'),
#   ('키우던', 'O'),
#   (' ', 'O'),
#   ('선인장', 'PLANT'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('말라가는', 'O'),
#   (' ', 'O'),
#   ('모습을', 'O'),
#   (' ', 'O'),
#   ('보고', 'O'),
#   (' ', 'O'),
#   ('영감을', 'O'),
#   (' ', 'O'),
#   ('얻어', 'O'),
#   (' ', 'O'),
#   ('만들게', 'O'),
#   (' ', 'O'),
#   ('됐습니다', 'O')],
#  [('▶', 'O'),
#   ('나연', 'PERSON'),
#   ('=제', 'O'),
#   (' ', 'O'),
#   ('마음속', 'O'),
#   (' ', 'O'),
#   ('사랑', 'O'),
#   (' ', 'O'),
#   ('공식은', 'O'),
#   (' ', 'O'),
#   ('바로', 'O'),
#   (' ', 'O'),
#   ('"O+T=<3"입니다', 'O')],
#  [('원스', 'PERSON'),
#   ('와', 'O'),
#   (' ', 'O'),
#   ('트와이스', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('서로를', 'O'),
#   (' ', 'O'),
#   ('향한', 'O'),
#   (' ', 'O'),
#   ('마음을', 'O'),
#   (' ', 'O'),
#   ('더하면', 'O'),
#   (' ', 'O'),
#   ('사랑이', 'O'),
#   (' ', 'O'),
#   ('탄생하기', 'O'),
#   (' ', 'O'),
#   ('때문이지요', 'O')],
#  [('▶', 'O'),
#   ('미나', 'PERSON'),
#   ("='", 'O'),
#   ('TWICE LOVE LAB', 'ORGANIZATION'),
#   ("'의", 'O'),
#   (' ', 'O'),
#   ('연구소', 'O'),
#   (' ', 'O'),
#   ('구성원으로서', 'O'),
#   (' ', 'O'),
#   ('사랑에', 'O'),
#   (' ', 'O'),
#   ('대해', 'O'),
#   (' ', 'O'),
#   ('열심히', 'O'),
#   (' ', 'O'),
#   ('연구해서', 'O'),
#   (' ', 'O'),
#   ('얻은', 'O'),
#   (' ', 'O'),
#   ('결론인', 'O'),
#   (' ', 'O'),
#   ('만큼,', 'O'),
#   (' ', 'O'),
#   ('원스', 'PERSON'),
#   ('와', 'O'),
#   (' ', 'O'),
#   ('트와이스', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('사랑보다', 'O'),
#   (' ', 'O'),
#   ('큰', 'O'),
#   (' ', 'O'),
#   ('사랑은', 'O'),
#   (' ', 'O'),
#   ('없지요', 'O')],
#  [('▶', 'O'),
#   ('채영', 'PERSON'),
#   ('=사랑', 'O'),
#   (' ', 'O'),
#   ('공식이란,', 'O'),
#   (' ', 'O'),
#   ('마음이', 'O'),
#   (' ', 'O'),
#   ('가는', 'O'),
#   (' ', 'O'),
#   ('대로', 'O'),
#   (' ', 'O'),
#   ('사랑하는', 'O'),
#   (' ', 'O'),
#   ('것이', 'O'),
#   (' ', 'O'),
#   ('사랑', 'O'),
#   (' ', 'O'),
#   ('공식이라고', 'O'),
#   (' ', 'O'),
#   ('생각해요', 'O')],
#  [('강아지', 'ANIMAL'),
#   ('와', 'O'),
#   (' ', 'O'),
#   ('대화를', 'O'),
#   (' ', 'O'),
#   ('나눌', 'O'),
#   (' ', 'O'),
#   ('수가', 'O'),
#   (' ', 'O'),
#   ('없어서', 'O'),
#   (' ', 'O'),
#   ('어떤', 'O'),
#   (' ', 'O'),
#   ('생각을', 'O'),
#   (' ', 'O'),
#   ('하고', 'O'),
#   (' ', 'O'),
#   ('있는지', 'O'),
#   (' ', 'O'),
#   ('정말', 'O'),
#   (' ', 'O'),
#   ('궁금해요', 'O')],
#  [('article_split', 'O'),
#   (' ', 'O'),
#   ('◆', 'O'),
#   ('트와이스', 'PERSON'),
#   (' ', 'O'),
#   ('정규', 'O'),
#   (' ', 'O'),
#   ('3집', 'QUANTITY'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('Formula of Love: O+T=', 'ARTIFACT'),
#   ('<3', 'ARTIFACT'),
#   ("'", 'O'),
#   (' ', 'O'),
#   ('일문일답', 'O'),
#   (' ', 'O'),
#   ('Q', 'O')],
#  [('해외', 'O'),
#   (' ', 'O'),
#   ('여러', 'O'),
#   (' ', 'O'),
#   ('아티스트', 'CIVILIZATION'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('히트곡을', 'O'),
#   (' ', 'O'),
#   ('프로듀싱', 'O'),
#   (' ', 'O'),
#   ('한', 'O'),
#   (' ', 'O'),
#   ('토미 브라운', 'PERSON'),
#   ('(Tommy', 'O'),
#   (' ', 'O'),
#   ('Brown),', 'O'),
#   (' ', 'O'),
#   ('영국', 'COUNTRY'),
#   (' ', 'O'),
#   ('싱어송라이터', 'OCCUPATION'),
#   ('이자', 'O'),
#   (' ', 'O'),
#   ('팝스타인', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('앤 마리', 'PERSON'),
#   ('(Anne', 'O'),
#   (' ', 'O'),
#   ('Marie)', 'O'),
#   (' ', 'O'),
#   ('등', 'O'),
#   (' ', 'O'),
#   ('타이틀곡', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('SCIENTIST', 'ARTIFACT'),
#   ("'를", 'O'),
#   (' ', 'O'),
#   ('작업한', 'O'),
#   (' ', 'O'),
#   ('작가진이', 'O'),
#   (' ', 'O'),
#   ('화려하다', 'O')],
#  [('곡을', 'O'),
#   (' ', 'O'),
#   ('처음', 'O'),
#   (' ', 'O'),
#   ('들었을', 'O'),
#   (' ', 'O'),
#   ('때의', 'O'),
#   (' ', 'O'),
#   ('느낌을', 'O'),
#   (' ', 'O'),
#   ('한 단어', 'QUANTITY'),
#   ('로', 'O'),
#   (' ', 'O'),
#   ('표현한다면?', 'O'),
#   (' ', 'O'),
#   ('Q', 'O')],
#  [("'", 'O'),
#   ('KNOCK KNOCK', 'ARTIFACT'),
#   ("',", 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('YES or YES', 'ARTIFACT'),
#   ("',", 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ("I CAN'T STOP ME", 'ARTIFACT'),
#   ("'", 'O'),
#   (' ', 'O'),
#   ('등', 'O'),
#   (' ', 'O'),
#   ('트와이스', 'PERSON'),
#   (' ', 'O'),
#   ('히트곡을', 'O'),
#   (' ', 'O'),
#   ('함께', 'O'),
#   (' ', 'O'),
#   ('해온', 'O'),
#   (' ', 'O'),
#   ('심은지', 'PERSON'),
#   (' ', 'O'),
#   ('작가', 'OCCUPATION'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('작사했다', 'O')],
#  [('심은지', 'PERSON'),
#   (' ', 'O'),
#   ('작가', 'OCCUPATION'),
#   ('와의', 'O'),
#   (' ', 'O'),
#   ('케미스트리를', 'O'),
#   (' ', 'O'),
#   ('자랑하자면?', 'O'),
#   (' ', 'O'),
#   ('Q', 'O')],
#  [('가장', 'O'),
#   (' ', 'O'),
#   ('기억에', 'O'),
#   (' ', 'O'),
#   ('남는', 'O'),
#   (' ', 'O'),
#   ('게', 'O'),
#   (' ', 'O'),
#   ('있다면', 'O'),
#   (' ', 'O'),
#   ('무엇인지,', 'O'),
#   (' ', 'O'),
#   ('또', 'O'),
#   (' ', 'O'),
#   ('지금까지', 'O'),
#   (' ', 'O'),
#   ('함께해', 'O'),
#   (' ', 'O'),
#   ('준', 'O'),
#   (' ', 'O'),
#   ('팬', 'OCCUPATION'),
#   ('들에게', 'O'),
#   (' ', 'O'),
#   ('해주고', 'O'),
#   (' ', 'O'),
#   ('싶은', 'O'),
#   (' ', 'O'),
#   ('게', 'O'),
#   (' ', 'O'),
#   ('있다면?', 'O'),
#   (' ', 'O'),
#   ('Q', 'O')],
#  [("'", 'O'),
#   ('TWICE LOVE LAB', 'ARTIFACT'),
#   ("'의", 'O'),
#   (' ', 'O'),
#   ('연구원', 'OCCUPATION'),
#   (' ', 'O'),
#   ('트와이스', 'PERSON'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('생각하는', 'O'),
#   (' ', 'O'),
#   ("'사랑", 'O'),
#   (' ', 'O'),
#   ("공식'이란?", 'O'),
#   (' ', 'O'),
#   ('Q', 'O')],
#  [('트와이스', 'PERSON'),
#   (' ', 'O'),
#   ('멤버', 'CIVILIZATION'),
#   ('들이', 'O'),
#   (' ', 'O'),
#   ('한 분야', 'QUANTITY'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('전문가', 'OCCUPATION'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('될', 'O'),
#   (' ', 'O'),
#   ('수', 'O'),
#   (' ', 'O'),
#   ('있다면', 'O'),
#   (' ', 'O'),
#   ('각자', 'O'),
#   (' ', 'O'),
#   ('어떤', 'O'),
#   (' ', 'O'),
#   ('내용을', 'O'),
#   (' ', 'O'),
#   ('연구하고', 'O'),
#   (' ', 'O'),
#   ('싶은지', 'O')],
#  [('AKMU', 'ORGANIZATION'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('YG', 'ORGANIZATION'),
#   ('와', 'O'),
#   (' ', 'O'),
#   ('5년', 'DATE'),
#   (' ', 'O'),
#   ('재계약', 'O'),
#   (' ', 'O'),
#   ('"다른', 'O'),
#   (' ', 'O'),
#   ('회사', 'O'),
#   (' ', 'O'),
#   ('갈', 'O'),
#   (' ', 'O'),
#   ('생각', 'O'),
#   (' ', 'O'),
#   ('해본', 'O'),
#   (' ', 'O'),
#   ('적', 'O'),
#   (' ', 'O'),
#   ('없다"', 'O')],
#  [('7년간', 'DATE'),
#   (' ', 'O'),
#   ('단', 'O'),
#   (' ', 'O'),
#   ('한 번', 'QUANTITY'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('작은', 'O'),
#   (' ', 'O'),
#   ('마찰이나', 'O'),
#   (' ', 'O'),
#   ('의견', 'O'),
#   (' ', 'O'),
#   ('대립', 'O'),
#   (' ', 'O'),
#   ('없이', 'O'),
#   (' ', 'O'),
#   ('우리가', 'O'),
#   (' ', 'O'),
#   ('나아가자', 'O'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('방향으로', 'O'),
#   (' ', 'O'),
#   ('든든하게', 'O'),
#   (' ', 'O'),
#   ('지원해주고', 'O'),
#   (' ', 'O'),
#   ('어린', 'O'),
#   (' ', 'O'),
#   ('우리들을', 'O'),
#   (' ', 'O'),
#   ('잘', 'O'),
#   (' ', 'O'),
#   ('이끌어준', 'O'),
#   (' ', 'O'),
#   ('회사"라며', 'O'),
#   (' ', 'O'),
#   ('YG', 'ORGANIZATION'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('대한', 'O'),
#   (' ', 'O'),
#   ('무한', 'O'),
#   (' ', 'O'),
#   ('신뢰를', 'O'),
#   (' ', 'O'),
#   ('표현했다', 'O')],
#  [('특히', 'O'),
#   (' ', 'O'),
#   ('AKMU', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('이수현', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('소감이', 'O'),
#   (' ', 'O'),
#   ('눈길을', 'O'),
#   (' ', 'O'),
#   ('끈다', 'O')],
#  [('이수현', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('"우리는', 'O'),
#   (' ', 'O'),
#   ('은퇴를', 'O'),
#   (' ', 'O'),
#   ('하면', 'O'),
#   (' ', 'O'),
#   ('했지', 'O'),
#   (' ', 'O'),
#   ('YG', 'ORGANIZATION'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('떠날', 'O'),
#   (' ', 'O'),
#   ('생각을', 'O'),
#   (' ', 'O'),
#   ('단', 'O'),
#   (' ', 'O'),
#   ('한 번', 'QUANTITY'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('해', 'O'),
#   (' ', 'O'),
#   ('본', 'O'),
#   (' ', 'O'),
#   ('적', 'O'),
#   (' ', 'O'),
# ...
#   ('"', 'O'),
#   ('7~80년대', 'DATE'),
#   (' ', 'O'),
#   ('느낌으로', 'O'),
#   (' ', 'O'),
#   ('꾸며', 'O'),
#   (' ', 'O'),
#   ('입고', 'O'),
#   (' ', 'O'),
#   ('유선 마이크', 'TERM'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('사용했다"며', 'O'),
#   (' ', 'O'),
#   ('"\'', 'O'),
#   ('토요일 토요일이 즐거워', 'ARTIFACT'),
#   ("'를", 'O'),
#   (' ', 'O'),
#   ('연상케', 'O'),
#   (' ', 'O'),
#   ('한다"고', 'O'),
#   (' ', 'O'),
#   ('전했다', 'O')],
#  [('신년', 'DATE'),
#   ('에도', 'O'),
#   (' ', 'O'),
#   ('저만', 'O'),
#   (' ', 'O'),
#   ('잘', 'O'),
#   (' ', 'O'),
#   ('됐으면', 'O'),
#   (' ', 'O'),
#   ('좋겠다"며', 'O'),
#   (' ', 'O'),
#   ('농담을', 'O'),
#   (' ', 'O'),
#   ('했다', 'O')],
#  [('수상을', 'O'),
#   (' ', 'O'),
#   ('하기', 'O'),
#   (' ', 'O'),
#   ('전', 'O'),
#   (' ', 'O'),
#   ('아이유', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('오마이걸', 'PERSON'),
#   ("'의", 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('던던댄스', 'ARTIFACT'),
#   ("'를", 'O'),
#   (' ', 'O'),
#   ('흥얼거렸다', 'O')],
#  [('그는', 'O'),
#   (' ', 'O'),
#   ('"', 'O'),
#   ('작년', 'DATE'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('찌들었던', 'O'),
#   (' ', 'O'),
#   ('기운이', 'O'),
#   (' ', 'O'),
#   ('날아간', 'O'),
#   (' ', 'O'),
#   ('거', 'O'),
#   (' ', 'O'),
#   ('같다"고', 'O'),
#   (' ', 'O'),
#   ('밝혔다', 'O')],
#  [('그는', 'O'),
#   (' ', 'O'),
#   ('"', 'O'),
#   ('작년', 'DATE'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('찌들었던', 'O'),
#   (' ', 'O'),
#   ('기운이', 'O'),
#   (' ', 'O'),
#   ('날아간', 'O'),
#   (' ', 'O'),
#   ('거', 'O'),
#   (' ', 'O'),
#   ('같다"고', 'O'),
#   (' ', 'O'),
#   ('밝혔다', 'O')],
#  [('수상을', 'O'),
#   (' ', 'O'),
#   ('하고', 'O'),
#   (' ', 'O'),
#   ('대기실로', 'O'),
#   (' ', 'O'),
#   ('돌아온', 'O'),
#   (' ', 'O'),
#   ('아이유', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('"소감', 'O'),
#   (' ', 'O'),
#   ('말할', 'O'),
#   (' ', 'O'),
#   ('시간이', 'O'),
#   (' ', 'O'),
#   ('부족해', 'O'),
#   (' ', 'O'),
#   ('아쉬웠다"며', 'O'),
#   (' ', 'O'),
#   ('"', 'O'),
#   ('앞', 'TERM'),
#   ('에서', 'O'),
#   (' ', 'O'),
#   ('빨간불이', 'O'),
#   (' ', 'O'),
#   ('깜빡깜빡', 'O'),
#   (' ', 'O'),
#   ('거려', 'O'),
#   (' ', 'O'),
#   ('수상', 'O'),
#   (' ', 'O'),
#   ('소감을', 'O'),
#   (' ', 'O'),
#   ('급마무리', 'O'),
#   (' ', 'O'),
#   ('했다"고', 'O'),
#   (' ', 'O'),
#   ('전했다', 'O')],
#  [('아이유', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('"', 'O'),
#   ('1월 2일쯤', 'DATE'),
#   (' ', 'O'),
#   ('꿈을', 'O'),
#   (' ', 'O'),
#   ('꿨다"고', 'O'),
#   (' ', 'O'),
#   ('밝혔다', 'O')],
#  [('"무슨', 'O'),
#   (' ', 'O'),
#   ('꿈을', 'O'),
#   (' ', 'O'),
#   ('꿨냐"는', 'O'),
#   (' ', 'O'),
#   ('PD', 'CIVILIZATION'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('질문에', 'O'),
#   (' ', 'O'),
#   ('그는', 'O'),
#   (' ', 'O'),
#   ('"꿈의', 'O'),
#   (' ', 'O'),
#   ('내용을', 'O'),
#   (' ', 'O'),
#   ('공개하면', 'O'),
#   (' ', 'O'),
#   ('꿈의', 'O'),
#   (' ', 'O'),
#   ('효력이', 'O'),
#   (' ', 'O'),
#   ('떨어진다"며', 'O'),
#   (' ', 'O'),
#   ('"그', 'O'),
#   (' ', 'O'),
#   ('꿈이', 'O'),
#   (' ', 'O'),
#   ('맞았다고', 'O'),
#   (' ', 'O'),
#   ('밝혀지면', 'O'),
#   (' ', 'O'),
#   ('말해주겠다"고', 'O'),
#   (' ', 'O'),
#   ('답했다', 'O')],
#  [('"무슨', 'O'),
#   (' ', 'O'),
#   ('꿈을', 'O'),
#   (' ', 'O'),
#   ('꿨냐"는', 'O'),
#   (' ', 'O'),
#   ('PD', 'CIVILIZATION'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('질문에', 'O'),
#   (' ', 'O'),
#   ('그는', 'O'),
#   (' ', 'O'),
#   ('"꿈의', 'O'),
#   (' ', 'O'),
#   ('내용을', 'O'),
#   (' ', 'O'),
#   ('공개하면', 'O'),
#   (' ', 'O'),
#   ('꿈의', 'O'),
#   (' ', 'O'),
#   ('효력이', 'O'),
#   (' ', 'O'),
#   ('떨어진다"며', 'O'),
#   (' ', 'O'),
#   ('"그', 'O'),
#   (' ', 'O'),
#   ('꿈이', 'O'),
#   (' ', 'O'),
#   ('맞았다고', 'O'),
#   (' ', 'O'),
#   ('밝혀지면', 'O'),
#   (' ', 'O'),
#   ('말해주겠다"고', 'O'),
#   (' ', 'O'),
#   ('답했다', 'O')],
#  [('디지털', 'O'),
#   (' ', 'O'),
#   ('음원', 'O'),
#   (' ', 'O'),
#   ('부문', 'O'),
#   (' ', 'O'),
#   ('대상', 'CIVILIZATION'),
#   ('을', 'O'),
#   (' ', 'O'),
#   ('수상한', 'O'),
#   (' ', 'O'),
#   ('아이유', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('"', 'O'),
#   ('MC', 'OCCUPATION'),
#   (' ', 'O'),
#   ('세 분', 'QUANTITY'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('내', 'O'),
#   (' ', 'O'),
#   ('옆으로', 'O'),
#   (' ', 'O'),
#   ('와서', 'O'),
#   (' ', 'O'),
#   ('민망했다"며', 'O'),
#   (' ', 'O'),
#   ('"수상', 'O'),
#   (' ', 'O'),
#   ('소감을', 'O'),
#   (' ', 'O'),
#   ('최초로', 'O'),
#   (' ', 'O'),
#   ('포기할', 'O'),
#   (' ', 'O'),
#   ('뻔', 'O'),
#   (' ', 'O'),
#   ('했다"고', 'O'),
#   (' ', 'O'),
#   ('말해', 'O'),
#   (' ', 'O'),
#   ('웃음을', 'O'),
#   (' ', 'O'),
#   ('안겼다', 'O')],
#  [('아이유', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('"뒤에', 'O'),
#   (' ', 'O'),
#   ('일정이', 'O'),
#   (' ', 'O'),
#   ('있어', 'O'),
#   (' ', 'O'),
#   ('가보도록', 'O'),
#   (' ', 'O'),
#   ('하겠다며"', 'O'),
#   (' ', 'O'),
#   ('영상을', 'O'),
#   (' ', 'O'),
#   ('마무리했다', 'O')],
#  [('스타일리스트', 'CIVILIZATION'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('손', 'ANIMAL'),
#   ('을', 'O'),
#   (' ', 'O'),
#   ('잡고', 'O'),
#   (' ', 'O'),
#   ('흔드는', 'O'),
#   (' ', 'O'),
#   ('깨발랄한', 'O'),
#   (' ', 'O'),
#   ('모습이다', 'O')],
#  [('‘워맨스’', 'O'),
#   (' ', 'O'),
#   ('배우', 'OCCUPATION'),
#   (' ', 'O'),
#   ('정이랑', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('훈남', 'O'),
#   (' ', 'O'),
#   ('남편', 'CIVILIZATION'),
#   ('+', 'O'),
#   ('두 아이', 'QUANTITY'),
#   (' ', 'O'),
#   ('공개', 'O'),
#   (' ', 'O'),
#   ('“너무', 'O'),
#   (' ', 'O'),
#   ('멋있어”', 'O'),
#   (' ', 'O'),
#   ('장도연', 'PERSON'),
#   (' ', 'O'),
#   ('감탄', 'O')],
#  [('뉴스엔', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('유경상', 'PERSON'),
#   (' ', 'O'),
#   ('yooks@', 'O'),
#   (' ', 'O'),
#   ('배우', 'OCCUPATION'),
#   (' ', 'O'),
#   ('최정윤', 'PERSON'),
#   (' ', 'O'),
#   ('절친', 'CIVILIZATION'),
#   ('으로', 'O'),
#   (' ', 'O'),
#   ('배우', 'OCCUPATION'),
#   (' ', 'O'),
#   ('정이랑', 'PERSON'),
#   ('과', 'O'),
#   (' ', 'O'),
#   ('배우', 'OCCUPATION'),
#   (' ', 'O'),
#   ('진선미', 'PERSON'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('출연했다', 'O')],
#  [('12월 9일', 'DATE'),
#   (' ', 'O'),
#   ('방송된', 'O'),
#   (' ', 'O'),
#   ('SBS', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('‘', 'O'),
#   ('워맨스가 필요해', 'ARTIFACT'),
#   ('’에서', 'O'),
#   (' ', 'O'),
#   ('배우', 'OCCUPATION'),
#   (' ', 'O'),
#   ('최정윤', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('절친', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('정이랑', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('진선미', 'PERSON'),
#   ('와', 'O'),
#   (' ', 'O'),
#   ('여행을', 'O'),
#   (' ', 'O'),
#   ('떠났다', 'O')],
#  [('이날', 'DATE'),
#   (' ', 'O'),
#   ('방송에서', 'O'),
#   (' ', 'O'),
#   ('배우', 'OCCUPATION'),
#   (' ', 'O'),
#   ('최정윤', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('절친', 'CIVILIZATION'),
#   ('들을', 'O'),
#   (' ', 'O'),
#   ('만나자', 'O'),
#   (' ', 'O'),
#   ('장도연', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('“', 'O'),
#   ('한 분', 'QUANTITY'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('굉장히', 'O'),
#   (' ', 'O'),
#   ('낯익다”고', 'O'),
#   (' ', 'O'),
#   ('말했고,', 'O'),
#   (' ', 'O'),
#   ('신동엽', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('“이랑이잖아', 'O')],
#  [('그와', 'O'),
#   (' ', 'O'),
#   ('함께', 'O'),
#   (' ', 'O'),
#   ('정이랑', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('두 아이', 'QUANTITY'),
#   ('와', 'O'),
#   (' ', 'O'),
#   ('훈남', 'O'),
#   (' ', 'O'),
#   ('남편', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('사진이', 'O'),
#   (' ', 'O'),
#   ('공개됐고,', 'O'),
#   (' ', 'O'),
#   ('장도연', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('“너무', 'O'),
#   (' ', 'O'),
#   ('멋있다', 'O')],
#  [('진선미', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('“저는', 'O'),
#   (' ', 'O'),
#   ('최정윤', 'PERSON'),
#   (' ', 'O'),
#   ('친구', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('배우', 'OCCUPATION'),
#   (' ', 'O'),
#   ('진선미', 'PERSON'),
#   ('다”며', 'O'),
#   (' ', 'O'),
#   ('자기', 'O'),
#   (' ', 'O'),
#   ('소개했다', 'O')],
#  [('진선미', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('촬영감독', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('남편', 'CIVILIZATION'),
#   ('과', 'O'),
#   (' ', 'O'),
#   ('결혼', 'O'),
#   (' ', 'O'),
#   ('7년차', 'QUANTITY')],
#  [('진선미', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('“', 'O'),
#   ('2017년', 'DATE'),
#   (' ', 'O'),
#   ('‘', 'O'),
#   ('감쪽같은 그녀', 'ARTIFACT'),
#   ('’', 'O'),
#   (' ', 'O'),
#   ('영화에서', 'O'),
#   (' ', 'O'),
#   ('정윤이', 'PERSON'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('사투리가', 'O'),
#   (' ', 'O'),
#   ('필요해', 'O'),
#   (' ', 'O'),
#   ('제가', 'O'),
#   (' ', 'O'),
#   ('사투리를', 'O'),
#   (' ', 'O'),
#   ('가르쳐주면서', 'O'),
#   (' ', 'O'),
#   ('만나게', 'O'),
#   (' ', 'O'),
#   ('됐다', 'O')],
#  [('둘', 'QUANTITY'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('사투리를', 'O'),
#   (' ', 'O'),
#   ('배우면서', 'O'),
#   (' ', 'O'),
#   ('친해졌다”고', 'O'),
#   (' ', 'O'),
#   ('말했다', 'O')],
#  [('둘', 'QUANTITY'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('사투리를', 'O'),
#   (' ', 'O'),
#   ('배우면서', 'O'),
#   (' ', 'O'),
#   ('친해졌다”고', 'O'),
#   (' ', 'O'),
#   ('말했다', 'O')],
#  [('최정윤', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('“제가', 'O'),
#   (' ', 'O'),
#   ('그', 'O'),
#   (' ', 'O'),
#   ('작품을', 'O'),
#   (' ', 'O'),
#   ('하면서', 'O'),
#   (' ', 'O'),
#   ('제', 'O'),
#   (' ', 'O'),
#   ('상황이', 'O'),
#   (' ', 'O'),
#   ('힘들었고', 'O'),
#   (' ', 'O'),
#   ('의지할', 'O'),
#   (' ', 'O'),
#   ('곳이', 'O'),
#   (' ', 'O'),
#   ('필요했는데', 'O'),
#   (' ', 'O'),
#   ('그게', 'O'),
#   (' ', 'O'),
#   ('선미', 'PERSON'),
#   ('였던', 'O'),
#   (' ', 'O'),
#   ('것', 'O'),
#   (' ', 'O'),
#   ('같다”며', 'O'),
#   (' ', 'O'),
#   ('친구', 'CIVILIZATION'),
#   ('들에게', 'O'),
#   (' ', 'O'),
#   ('고마워했다', 'O')],
#  [('(사진=', 'O'),
#   ('SBS', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('‘', 'O'),
#   ('워맨스가 필요해', 'ARTIFACT'),
#   ('’', 'O'),
#   (' ', 'O'),
#   ('캡처)', 'O')],
#  [('[팝업★]', 'O'),
#   ('아이유', 'PERSON'),
#   (' ', 'O'),
#   ('"\'', 'O'),
#   ('골든디스크', 'EVENT'),
#   ("'", 'O'),
#   (' ', 'O'),
#   ('대상', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('당시', 'O'),
#   (' ', 'O'),
#   ('MC', 'OCCUPATION'),
#   ('들에', 'O'),
#   (' ', 'O'),
#   ('당황..소감', 'O'),
#   (' ', 'O'),
#   ('포기할', 'O'),
#   (' ', 'O'),
#   ('뻔"(', 'O'),
#   ('이지금', 'PERSON'),
#   (')', 'O')],
#  [('아이유', 'PERSON'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('골든디스크', 'CIVILIZATION'),
#   ("'", 'O'),
#   (' ', 'O'),
#   ('비하인드를', 'O'),
#   (' ', 'O'),
#   ('공개했다', 'O')],
#  [('21일', 'DATE'),
#   (' ', 'O'),
#   ('오후', 'TIME'),
#   (' ', 'O'),
#   ('아이유', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('유튜브', 'TERM'),
#   (' ', 'O'),
#   ('채널', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('이지금', 'TERM'),
#   (' ', 'O'),
#   ('[IU Official', 'TERM'),
#   ("]'에는", 'O'),
#   (' ', 'O'),
#   ("'[", 'O'),
#   ('IU TV', 'ARTIFACT'),
#   (']', 'O'),
#   (' ', 'O'),
#   ('토요일 토요일은', 'ARTIFACT'),
#   (' ', 'O'),
#   ('아이유', 'PERSON'),
#   ("'라는", 'O'),
#   (' ', 'O'),
#   ('제목의', 'O'),
#   (' ', 'O'),
#   ('영상이', 'O'),
#   (' ', 'O'),
#   ('게재됐다', 'O')],
#  [('공개된', 'O'),
#   (' ', 'O'),
#   ('영상', 'O'),
#   (' ', 'O'),
#   ('속에서', 'O'),
#   (' ', 'O'),
#   ('아이유', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('셀러브리티', 'ARTIFACT'),
#   ("'에", 'O'),
#   (' ', 'O'),
#   ('대해', 'O'),
#   (' ', 'O'),
#   ('"\'', 'O'),
#   ('골든디스크', 'EVENT'),
#   ("'를", 'O'),
#   (' ', 'O'),
#   ('위해', 'O'),
#   (' ', 'O'),
#   ('아껴뒀던', 'O'),
#   (' ', 'O'),
#   ('편곡을', 'O'),
#   (' ', 'O'),
#   ('공개했고,', 'O'),
#   (' ', 'O'),
#   ('올', 'O'),
#   (' ', 'O'),
#   ('밴드로', 'O'),
#   (' ', 'O'),
#   ('진행했다', 'O')],
#  [("'", 'O'),
#   ('셀러브리티', 'ARTIFACT'),
#   ("'도", 'O'),
#   (' ', 'O'),
#   (";셀러브리티'인데", 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('라일락', 'ARTIFACT'),
#   ("'도", 'O'),
#   (' ', 'O'),
#   ('뭔가', 'O'),
#   (' ', 'O'),
#   ('7080', 'DATE'),
#   (' ', 'O'),
#   ('느낌으로', 'O'),
#   (' ', 'O'),
#   ('꾸며서', 'O'),
#   (' ', 'O'),
#   ('입고', 'O'),
#   (' ', 'O'),
#   ('저도', 'O'),
#   (' ', 'O'),
#   ('유선', 'O'),
#   (' ', 'O'),
#   ('마이크', 'TERM'),
#   ('로', 'O'),
#   (' ', 'O'),
#   ('했다"며', 'O'),
#   (' ', 'O'),
#   ('가요무대', 'O'),
#   (' ', 'O'),
#   ('스타일이라고', 'O'),
#   (' ', 'O'),
#   ('설명했다', 'O')],
#  [("'", 'O'),
#   ('셀러브리티', 'ARTIFACT'),
#   ("'도", 'O'),
#   (' ', 'O'),
#   (";셀러브리티'인데", 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('라일락', 'ARTIFACT'),
#   ("'도", 'O'),
#   (' ', 'O'),
#   ('뭔가', 'O'),
#   (' ', 'O'),
#   ('7080', 'DATE'),
#   (' ', 'O'),
#   ('느낌으로', 'O'),
#   (' ', 'O'),
#   ('꾸며서', 'O'),
#   (' ', 'O'),
#   ('입고', 'O'),
#   (' ', 'O'),
#   ('저도', 'O'),
#   (' ', 'O'),
#   ('유선', 'O'),
#   (' ', 'O'),
#   ('마이크', 'TERM'),
#   ('로', 'O'),
#   (' ', 'O'),
#   ('했다"며', 'O'),
#   (' ', 'O'),
#   ('가요무대', 'O'),
#   (' ', 'O'),
#   ('스타일이라고', 'O'),
#   (' ', 'O'),
#   ('설명했다', 'O')],
#  [('아이유', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('"너무', 'O'),
#   (' ', 'O'),
#   ('재밌다!하면서', 'O'),
#   (' ', 'O'),
#   ('했다', 'O')],
#  [('골디', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('관계자', 'CIVILIZATION'),
#   ('분이', 'O'),
#   (' ', 'O'),
#   ('내려와서', 'O'),
#   (' ', 'O'),
#   ('편집할', 'O'),
#   (' ', 'O'),
#   ('때', 'O'),
#   (' ', 'O'),
#   ('반응', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('좋았다고', 'O'),
#   (' ', 'O'),
#   ('해주셨다"고', 'O'),
#   (' ', 'O'),
#   ('뿌듯하게', 'O'),
#   (' ', 'O'),
#   ('웃었다', 'O')],
#  [('골디', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('관계자', 'CIVILIZATION'),
#   ('분이', 'O'),
#   (' ', 'O'),
#   ('내려와서', 'O'),
#   (' ', 'O'),
#   ('편집할', 'O'),
#   (' ', 'O'),
#   ('때', 'O'),
#   (' ', 'O'),
#   ('반응', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('좋았다고', 'O'),
#   (' ', 'O'),
#   ('해주셨다"고', 'O'),
#   (' ', 'O'),
#   ('뿌듯하게', 'O'),
#   (' ', 'O'),
#   ('웃었다', 'O')],
#  [('스태프', 'CIVILIZATION'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('"어떤', 'O'),
#   (' ', 'O'),
#   ('상을', 'O'),
#   (' ', 'O'),
#   ('원하시냐"는', 'O'),
#   (' ', 'O'),
#   ('질문에', 'O'),
#   (' ', 'O'),
#   ('아이유', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('"상을', 'O'),
#   (' ', 'O'),
#   ('뭘', 'O'),
#   (' ', 'O'),
#   ('제가', 'O'),
#   (' ', 'O'),
#   ('가립니까', 'O')],
#  [('상이면', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('좋죠"라고', 'O'),
#   (' ', 'O'),
#   ('답했다', 'O')],
#  [('상이면', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('좋죠"라고', 'O'),
#   (' ', 'O'),
#   ('답했다', 'O')],
#  [('스태프', 'CIVILIZATION'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ("'상상", 'O'),
#   (' ', 'O'),
#   ('이상', 'O'),
#   (' ', 'O'),
#   ("상'", 'O'),
#   (' ', 'O'),
#   ('어떠냐며', 'O'),
#   (' ', 'O'),
#   ('아이유', 'PERSON'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('2021년', 'DATE'),
#   (' ', 'O'),
#   ('이뤄낸', 'O'),
#   (' ', 'O'),
#   ('업적들을', 'O'),
#   (' ', 'O'),
#   ('읊었다', 'O')],
#  [('그러자', 'O'),
#   (' ', 'O'),
#   ('아이유', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('"그만큼', 'O'),
#   (' ', 'O'),
#   ('고생을', 'O'),
#   (' ', 'O'),
#   ('해야지만', 'O'),
#   (' ', 'O'),
#   ('이룰', 'O'),
#   (' ', 'O'),
#   ('수', 'O'),
#   (' ', 'O'),
#   ('있는', 'O'),
#   (' ', 'O'),
#   ('상이군요', 'O')],
#  [('상상', 'O'),
#   (' ', 'O'),
#   ('이상으로', 'O'),
#   (' ', 'O'),
#   ('일을', 'O'),
#   (' ', 'O'),
#   ('해서', 'O'),
#   (' ', 'O'),
#   ('상상', 'O'),
#   (' ', 'O'),
#   ('이상의', 'O'),
#   (' ', 'O'),
#   ('결과물과', 'O'),
#   (' ', 'O'),
#   ('상상', 'O'),
#   (' ', 'O'),
#   ('이상의', 'O'),
#   (' ', 'O'),
#   ('행복을', 'O'),
#   (' ', 'O'),
#   ('드릴', 'O'),
#   (' ', 'O'),
#   ('수', 'O'),
#   (' ', 'O'),
#   ('있도록', 'O'),
#   (' ', 'O'),
#   ('상상', 'O'),
#   (' ', 'O'),
#   ('이상으로', 'O'),
#   (' ', 'O'),
#   ('열심히', 'O'),
#   (' ', 'O'),
#   ('하겠다', 'O')],
#  [('뭔가', 'O'),
#   (' ', 'O'),
#   ('작년', 'DATE'),
#   ('과', 'O'),
#   (' ', 'O'),
#   ('함께', 'O'),
#   (' ', 'O'),
#   ('찌들었던', 'O'),
#   (' ', 'O'),
#   ('기운들이', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('날아간', 'O'),
#   (' ', 'O'),
#   ('것', 'O'),
#   (' ', 'O'),
#   ('같다"고', 'O'),
#   (' ', 'O'),
#   ('말했다', 'O')],
#  [('상을', 'O'),
#   (' ', 'O'),
#   ('두 개', 'QUANTITY'),
#   (' ', 'O'),
#   ('받고', 'O'),
#   (' ', 'O'),
#   ('마지막', 'O'),
#   (' ', 'O'),
#   ('상', 'O'),
#   (' ', 'O'),
#   ('받기', 'O'),
#   (' ', 'O'),
#   ('전', 'O'),
#   (' ', 'O'),
#   ('대기하던', 'O'),
#   (' ', 'O'),
#   ('아이유', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('"사실', 'O'),
#   (' ', 'O'),
#   ('이거', 'O'),
#   (' ', 'O'),
#   ('지금', 'O'),
#   (' ', 'O'),
#   ('아이유티비', 'ORGANIZATION'),
#   ('에만', 'O'),
#   (' ', 'O'),
#   ('얘기하는건데', 'O'),
#   (' ', 'O'),
#   ('꿈을', 'O'),
#   (' ', 'O'),
#   ('꿨다', 'O')],
#  [('1월 2일 쯤', 'DATE'),
#   ('이었나', 'O'),
#   (' ', 'O'),
#   ('연초', 'DATE'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('꿈을', 'O'),
#   (' ', 'O'),
#   ('꿨는데', 'O'),
#   (' ', 'O'),
#   ('장난', 'O'),
#   (' ', 'O'),
#   ('아닌', 'O'),
#   (' ', 'O'),
#   ('꿈을', 'O'),
#   (' ', 'O'),
#   ('꿨다', 'O')],
#  [('꿈이', 'O'),
#   (' ', 'O'),
#   ('맞았다고', 'O'),
#   (' ', 'O'),
#   ('밝혀지면', 'O'),
#   (' ', 'O'),
#   ('그', 'O'),
#   (' ', 'O'),
#   ('때', 'O'),
#   (' ', 'O'),
#   ('무슨', 'O'),
#   (' ', 'O'),
#   ('꿈인지', 'O'),
#   (' ', 'O'),
#   ('얘기하겠다"고', 'O'),
#   (' ', 'O'),
#   ('해', 'O'),
#   (' ', 'O'),
#   ('궁금증을', 'O'),
#   (' ', 'O'),
#   ('자아내기도', 'O')],
#  [('대상', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('수상까지,', 'O'),
#   (' ', 'O'),
#   ("'", 'O'),
#   ('골든디스크', 'EVENT'),
#   ("'에서", 'O'),
#   (' ', 'O'),
#   ('상을', 'O'),
#   (' ', 'O'),
#   ('세 개', 'QUANTITY'),
#   ('나', 'O'),
#   (' ', 'O'),
#   ('수상한', 'O'),
#   (' ', 'O'),
#   ('아이유', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('"이번에', 'O'),
#   (' ', 'O'),
#   ('(', 'O'),
#   ('골든디스크 상', 'CIVILIZATION'),
#   ('이)분명', 'O'),
#   (' ', 'O'),
#   ('무거워진게', 'O'),
#   (' ', 'O'),
#   ('맞다', 'O')],
#  [('다른', 'O'),
#   (' ', 'O'),
#   ('가', 'CIVILIZATION'),
#   ('수분들에게도', 'O'),
#   (' ', 'O'),
#   ('설문조사를', 'O'),
#   (' ', 'O'),
#   ('하고', 'O'),
#   (' ', 'O'),
#   ('싶다', 'O')],
#  [('윤서령', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('청하', 'PERSON'),
#   (' ', 'O'),
#   ('‘', 'O'),
#   ('Bicycle', 'ARTIFACT'),
#   ('’', 'O'),
#   (' ', 'O'),
#   ('안무', 'O'),
#   (' ', 'O'),
#   ('커버', 'O'),
#   (' ', 'O'),
#   ('영상', 'O'),
#   (' ', 'O'),
#   ('공개…‘압도적', 'O'),
#   (' ', 'O'),
#   ('파워풀', 'O'),
#   (' ', 'O'),
#   ('댄스’', 'O')]]

# %%
review_results=[]
for i in tqdm_notebook(body_news):
  result = review(i)
  review_results.append(result)
review_results
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/200 [00:00<?, ?it/s]
# [4.93,
#  3.81,
#  4.92,
#  4.53,
#  4.0,
#  4.91,
#  3.97,
#  4.83,
#  4.85,
#  4.8,
#  4.93,
#  4.9,
#  4.79,
#  4.79,
#  4.68,
#  3.78,
#  3.78,
#  1.46,
#  4.97,
#  1.31,
#  2.38,
#  1.49,
#  1.24,
#  4.8,
#  4.8,
#  4.72,
#  4.82,
#  4.91,
#  3.69,
#  4.84,
#  4.28,
#  4.56,
#  4.61,
#  4.87,
#  4.62,
#  4.1,
#  4.59,
#  1.74,
#  4.28,
#  2.2,
#  4.08,
#  4.59,
#  3.53,
#  4.74,
#  4.82,
#  4.79,
#  4.94,
#  4.67,
#  4.77,
#  5.01,
#  5.02,
#  4.88,
#  3.57,
#  4.05,
#  5.01,
#  4.68,
#  4.5,
#  4.16,
#  5.01,
#  4.62,
#  4.48,
#  4.52,
#  4.79,
#  4.44,
#  4.31,
#  4.31,
#  3.28,
#  3.19,
#  2.64,
#  4.85,
#  3.64,
#  4.4,
#  4.33,
#  3.62,
#  4.96,
#  4.55,
#  4.6,
#  4.79,
#  4.79,
#  4.7,
#  4.61,
#  4.57,
#  4.98,
#  4.57,
#  4.82,
#  4.8,
#  4.85,
#  4.76,
#  3.55,
#  4.62,
#  4.99,
#  4.48,
#  4.29,
#  4.76,
#  4.55,
#  4.76,
#  4.44,
#  4.92,
#  5.01,
#  4.68,
#  4.5,
#  4.9,
#  4.94,
#  4.7,
#  4.31,
#  4.31,
#  3.28,
#  3.19,
#  2.64,
#  4.86,
#  4.27,
#  4.98,
#  4.6,
#  4.21,
#  4.86,
#  4.59,
#  4.87,
#  4.59,
#  4.74,
#  4.51,
#  1.76,
#  5.01,
#  4.68,
#  4.5,
#  4.77,
#  4.76,
#  4.78,
#  4.94,
#  4.76,
#  4.78,
#  5.01,
#  5.01,
#  3.12,
#  2.43,
#  4.63,
#  4.51,
#  4.53,
#  4.45,
#  4.46,
#  3.79,
#  4.79,
#  4.13,
#  4.71,
#  4.18,
#  3.92,
#  4.66,
#  3.09,
#  4.57,
#  4.58,
#  4.5,
#  4.45,
#  4.94,
#  4.94,
#  4.76,
#  4.08,
#  4.05,
#  4.62,
#  4.66,
#  4.66,
#  4.5,
#  4.14,
#  2.71,
#  2.71,
#  4.58,
#  3.54,
#  4.51,
#  5.02,
#  4.83,
#  4.34,
#  4.51,
#  4.97,
#  4.76,
#  4.73,
#  4.71,
#  4.52,
#  4.52,
#  4.91,
#  4.46,
#  4.31,
#  4.09,
#  4.63,
#  4.91,
#  3.42,
#  3.42,
#  4.88,
#  4.82,
#  4.82,
#  3.59,
#  4.1,
#  4.1,
#  4.58,
#  4.67,
#  4.92,
#  4.3,
#  4.61,
#  3.45,
#  3.64,
#  4.25,
#  3.32,
#  4.77]

# %%
ner_results=[]
for i in tqdm_notebook(body_twitter):
  result = ner(i)
  ner_results.append(result)
ner_results
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/200 [00:00<?, ?it/s]
# [[('아이브', 'PERSON'),
#   (' ', 'O'),
#   ('너무너무키여운거.', 'O'),
#   (' ', 'O'),
#   ('ㅇㅇ즈', 'O'),
#   (' ', 'O'),
#   ('이름이', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('커플즈', 'O'),
#   (' ', 'O'),
#   ('공주즈', 'O'),
#   (' ', 'O'),
#   ('우당탕즈', 'O'),
#   (' ', 'O'),
#   ('감성즈', 'O'),
#   (' ', 'O'),
#   ('이런거임', 'O'),
#   (' ', 'O'),
#   ('호감너무심해', 'O'),
#   (' ', 'O'),
#   ('공주', 'CIVILIZATION'),
#   ('님들', 'O'),
#   (' ', 'O'),
#   ('모임이야', 'O'),
#   (' ', 'O'),
#   ('완전', 'O'),
#   (' ', 'O'),
#   ('나는', 'O'),
#   (' ', 'O'),
#   ('그사이에낀', 'O'),
#   (' ', 'O'),
#   ('난쟁이', 'ANIMAL'),
#   ('똥자루', 'ANIMAL'),
#   ('1마리', 'QUANTITY'),
#   ('고', 'O')],
#  [('식물한테', 'O'),
#   (' ', 'O'),
#   ('사랑해', 'O'),
#   (' ', 'O'),
#   ('고마워', 'O'),
#   (' ', 'O'),
#   ('하면', 'O'),
#   (' ', 'O'),
#   ('쓱쑥', 'PLANT'),
#   (' ', 'O'),
#   ('자라잔냐..', 'O'),
#   (' ', 'O'),
#   ('난', 'O'),
#   (' ', 'O'),
#   ('이때까지', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   ('을', 'O'),
#   (' ', 'O'),
#   ('식물에게', 'O'),
#   (' ', 'O'),
#   ('사랑주는인간처럼', 'O'),
#   (' ', 'O'),
#   ('해왓는데', 'O'),
#   (' ', 'O'),
#   ('균', 'O'),
#   (' ', 'O'),
#   ('좋아하고', 'O'),
#   (' ', 'O'),
#   ('반대가됨.', 'O'),
#   (' ', 'O'),
#   ('띠발나균', 'ANIMAL'),
#   ('의사랑먹고쑥쑥자라고있음..', 'O')],
#  [('스트레이키즈', 'ORGANIZATION'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('화가', 'OCCUPATION'),
#   ('있고', 'O'),
#   (' ', 'O'),
#   ('사진작가', 'OCCUPATION'),
#   ('있고', 'O'),
#   (' ', 'O'),
#   ('셰프', 'OCCUPATION'),
#   ('있고', 'O'),
#   (' ', 'O'),
#   ('헬스트레이너', 'CIVILIZATION'),
#   ('있고', 'O')],
#  [('아니', 'O'),
#   (' ', 'O'),
#   ('그래서', 'O'),
#   (' ', 'O'),
#   ('설강화', 'PERSON'),
#   (' ', 'O'),
#   ('역사왜곡', 'O'),
#   (' ', 'O'),
#   ('맞아?', 'O'),
#   (' ', 'O'),
#   ('아니라는', 'O'),
#   (' ', 'O'),
#   ('사람들이', 'O'),
#   (' ', 'O'),
#   ('갑자기', 'O'),
#   (' ', 'O'),
#   ('왤케', 'O'),
#   (' ', 'O'),
#   ('늘어난', 'O'),
#   (' ', 'O'),
#   ('거야', 'O')],
#  [('잘', 'O'),
#   (' ', 'O'),
#   ('지내는', 'O'),
#   (' ', 'O'),
#   ('걸', 'O'),
#   (' ', 'O'),
#   ('지켜보고', 'O'),
#   (' ', 'O'),
#   ('싶다는', 'O'),
#   (' ', 'O'),
#   ('생각이', 'O'),
#   (' ', 'O'),
#   ('아예', 'O'),
#   (' ', 'O'),
#   ('없는', 'O'),
#   (' ', 'O'),
#   ('것도', 'O'),
#   (' ', 'O'),
#   ('아니고,', 'O'),
#   (' ', 'O'),
#   ('종종', 'O'),
#   (' ', 'O'),
#   ('블라디미르', 'PERSON'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('이야기해준', 'O'),
#   (' ', 'O'),
#   ('지구', 'LOCATION'),
#   (' ', 'O'),
#   ('이야기를', 'O'),
#   (' ', 'O'),
#   ('들을', 'O'),
#   (' ', 'O'),
#   ('때마다', 'O'),
#   (' ', 'O'),
#   ('같이', 'O'),
#   (' ', 'O'),
#   ('가보고', 'O'),
#   (' ', 'O'),
#   ('싶다는', 'O'),
#   (' ', 'O'),
#   ('생각도', 'O'),
#   (' ', 'O'),
#   ('하지만..', 'O'),
#   (' ', 'O'),
#   ('HL', 'O'),
#   (' ', 'O'),
#   ('밖으로', 'O'),
#   (' ', 'O'),
#   ('못', 'O'),
#   (' ', 'O'),
#   ('나가는', 'O'),
#   (' ', 'O'),
#   ('처지라', 'O'),
#   (' ', 'O'),
#   ('그런', 'O'),
#   (' ', 'O'),
#   ('이야기를', 'O'),
#   (' ', 'O'),
#   ('하면', 'O'),
#   (' ', 'O'),
#   ('블라디미르', 'PERSON'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('좀', 'O'),
#   (' ', 'O'),
#   ('멋쩍어', 'O'),
#   (' ', 'O'),
#   ('할까봐', 'O'),
#   (' ', 'O'),
#   ('참고', 'O'),
#   (' ', 'O'),
#   ('있어요.', 'O'),
#   (' ', 'O'),
#   ('전반적으로', 'O'),
#   (' ', 'O'),
#   ('큰', 'O'),
#   (' ', 'O'),
#   ('걱정은', 'O'),
#   (' ', 'O'),
#   ('하지', 'O'),
#   (' ', 'O'),
#   ('않지만..', 'O')],
#  [('케이팝', 'STUDY_FIELD'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('저주.', 'O'),
#   (' ', 'O'),
#   ('어떤', 'O'),
#   (' ', 'O'),
#   ('남자의', 'O'),
#   (' ', 'O'),
#   ('1세부터', 'QUANTITY'),
#   (' ', 'O'),
#   ('오천살', 'QUANTITY'),
#   ('까지의', 'O'),
#   (' ', 'O'),
#   ('모습을', 'O'),
#   (' ', 'O'),
#   ('볼', 'O'),
#   (' ', 'O'),
#   ('수', 'O'),
#   (' ', 'O'),
#   ('잇지만', 'O'),
#   (' ', 'O'),
#   ('어쩐지', 'O'),
#   (' ', 'O'),
#   ('30살', 'QUANTITY'),
#   (' ', 'O'),
#   ('31살', 'QUANTITY'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('알', 'O'),
#   (' ', 'O'),
#   ('수가', 'O'),
#   (' ', 'O'),
#   ('업음', 'O')],
#  [('씰스티커믹스', 'ARTIFACT'),
#   (' ', 'O'),
#   ('중고', 'O'),
#   (' ', 'O'),
#   ('믹스', 'O'),
#   (' ', 'O'),
#   ('일괄로', 'O'),
#   (' ', 'O'),
#   ('판매해요', 'O'),
#   (' ', 'O'),
#   ('1번째', 'QUANTITY'),
#   (' ', 'O'),
#   ('19', 'QUANTITY'),
#   (' ', 'O'),
#   ('2번째', 'QUANTITY'),
#   (' ', 'O'),
#   ('새거도', 'O'),
#   (' ', 'O'),
#   ('있음', 'O'),
#   (' ', 'O'),
#   ('16', 'QUANTITY'),
#   (' ', 'O'),
#   ('엄청', 'O'),
#   (' ', 'O'),
#   ('싸게팔아요.', 'O'),
#   (' ', 'O'),
#   ('접어서.', 'O'),
#   ('각9000원', 'QUANTITY'),
#   ('임', 'O'),
#   (' ', 'O'),
#   ('폴라로이드', 'O'),
#   (' ', 'O'),
#   ('폴꾸', 'ARTIFACT'),
#   (' ', 'O'),
#   ('다이어리', 'O'),
#   (' ', 'O'),
#   ('다꾸', 'O'),
#   (' ', 'O'),
#   ('스꾸', 'O'),
#   (' ', 'O'),
#   ('탑로', 'ARTIFACT'),
#   ('더', 'O'),
#   (' ', 'O'),
#   ('탑꾸', 'O'),
#   (' ', 'O'),
#   ('방탄소년단', 'PERSON'),
#   (' ', 'O'),
#   ('세븐틴', 'PERSON'),
#   (' ', 'O'),
#   ('엔시티', 'PERSON'),
#   (' ', 'O'),
#   ('127', 'PERSON'),
#   (' ', 'O'),
#   ('드림', 'PERSON'),
#   (' ', 'O'),
#   ('엑소', 'PERSON'),
#   (' ', 'O'),
#   ('스키즈', 'PERSON'),
#   (' ', 'O'),
#   ('더보이즈', 'PERSON'),
#   (' ', 'O'),
#   ('블랙핑크', 'PERSON'),
#   (' ', 'O'),
#   ('아이브', 'PERSON'),
#   (' ', 'O'),
#   ('트와이스', 'PERSON'),
#   (' ', 'O'),
#   ('있지', 'O'),
#   (' ', 'O'),
#   ('어버블크러쉬 소다', 'ARTIFACT'),
#   (' ', 'O'),
#   ('A7', 'ARTIFACT'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('전소연', 'PERSON'),
#   (' ', 'O'),
#   ('삠삠', 'O'),
#   (' ', 'O'),
#   ('앨범', 'O'),
#   (' ', 'O'),
#   ('0.4', 'QUANTITY'),
#   (' ', 'O'),
#   ('양도합니다', 'O'),
#   (' ', 'O'),
#   ('두개', 'QUANTITY'),
#   ('있어요', 'O'),
#   (' ', 'O'),
#   ('구성품은', 'O'),
#   (' ', 'O'),
#   ('사진', 'O'),
#   (' ', 'O'),
#   ('참고해주세요', 'O'),
#   (' ', 'O'),
#   ('디엠주세요', 'O'),
#   (' ', 'O'),
#   ('여자아이들', 'O'),
#   (' ', 'O'),
#   ('아이들', 'O'),
#   (' ', 'O'),
#   ('소연', 'PERSON'),
#   (' ', 'O'),
#   ('윈디', 'PERSON'),
#   (' ', 'O'),
#   ('방과후설렘', 'O'),
#   (' ', 'O'),
#   ('방설', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('술', 'CIVILIZATION'),
#   ('은..', 'O'),
#   (' ', 'O'),
#   ('술', 'CIVILIZATION'),
#   ('은..', 'O'),
#   (' ', 'O'),
#   ('정말', 'O'),
#   (' ', 'O'),
#   ('괜찮은', 'O'),
#   (' ', 'O'),
#   ('건가?', 'O'),
#   (' ', 'O'),
#   ('속으로', 'O'),
#   (' ', 'O'),
#   ('싶어하긴', 'O'),
#   (' ', 'O'),
#   ('합니다.', 'O'),
#   (' ', 'O'),
#   ('반', 'QUANTITY'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('인간인데?', 'O'),
#   (' ', 'O'),
#   ('그', 'O'),
#   (' ', 'O'),
#   ('일', 'O'),
#   (' ', 'O'),
#   ('나가기', 'O'),
#   (' ', 'O'),
#   ('전에', 'O'),
#   (' ', 'O'),
#   ('두 병', 'QUANTITY'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('가뿐하게', 'O'),
#   (' ', 'O'),
#   ('마셔도', 'O'),
#   (' ', 'O'),
#   ('되는', 'O'),
#   (' ', 'O'),
#   ('건가?', 'O'),
#   (' ', 'O'),
#   ('하긴', 'O'),
#   (' ', 'O'),
#   ('하지만..', 'O'),
#   (' ', 'O'),
#   ('모든', 'O'),
#   (' ', 'O'),
#   ('종에', 'O'),
#   (' ', 'O'),
#   ('대해', 'O'),
#   (' ', 'O'),
#   ('아이브', 'PERSON'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('아는', 'O'),
#   (' ', 'O'),
#   ('건', 'O'),
#   (' ', 'O'),
#   ('아니라', 'O'),
#   (' ', 'O'),
#   ('괜찮은가', 'O'),
#   (' ', 'O'),
#   ('보다..', 'O'),
#   (' ', 'O'),
#   ('하고', 'O'),
#   (' ', 'O'),
#   ('지내고', 'O'),
#   (' ', 'O'),
#   ('있어요.', 'O'),
#   (' ', 'O'),
#   ('진실을', 'O'),
#   (' ', 'O'),
#   ('알게', 'O'),
#   (' ', 'O'),
#   ('되면', 'O'),
#   (' ', 'O'),
#   ('아이고', 'O'),
#   (' ', 'O'),
#   ('두야', 'O'),
#   (' ', 'O'),
#   ('할', 'O'),
#   (' ', 'O'),
#   ('겁니다.', 'O')],
#  [('스엠', 'PERSON'), (' ', 'O'), ('겨울', 'DATE'), (' ', 'O'), ('앨범이용!', 'O')],
#  [('참고로..', 'O'),
#   (' ', 'O'),
#   ('아이브', 'PERSON'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('죽을지도', 'O'),
#   (' ', 'O'),
#   ('모른다', 'O'),
#   (' ', 'O'),
#   ('확신하게', 'O'),
#   (' ', 'O'),
#   ('된', 'O'),
#   (' ', 'O'),
#   ('계기는', 'O'),
#   (' ', 'O'),
#   ('라이브', 'PERSON'),
#   ('라', 'O'),
#   (' ', 'O'),
#   ('후계', 'O'),
#   (' ', 'O'),
#   ('세울', 'O'),
#   (' ', 'O'),
#   ('이야기는', 'O'),
#   (' ', 'O'),
#   ('확고하게', 'O'),
#   (' ', 'O'),
#   ('계획이', 'O'),
#   (' ', 'O'),
#   ('있는', 'O'),
#   (' ', 'O'),
#   ('사람이', 'O'),
#   (' ', 'O'),
#   ('그', 'O'),
#   (' ', 'O'),
#   ('이후에', 'O'),
#   (' ', 'O'),
#   ('말로는', 'O'),
#   (' ', 'O'),
#   ('여행', 'O'),
#   (' ', 'O'),
#   ('가겠다고', 'O'),
#   (' ', 'O'),
#   ('하는데,', 'O'),
#   (' ', 'O'),
#   ('어디', 'O'),
#   (' ', 'O'),
#   ('가겠다는', 'O'),
#   (' ', 'O'),
#   ('말도', 'O'),
#   (' ', 'O'),
#   ('어떤', 'O'),
#   (' ', 'O'),
#   ('준비를', 'O'),
#   (' ', 'O'),
#   ('하는지도', 'O'),
#   (' ', 'O'),
#   ('안', 'O'),
#   (' ', 'O'),
#   ('말해서', 'O'),
#   (' ', 'O'),
#   ('아..', 'O'),
#   (' ', 'O'),
#   ('했습니다.', 'O')],
#  [('솔직히', 'O'),
#   (' ', 'O'),
#   ('드데', 'PERSON'),
#   ('가훨신좋지만', 'O'),
#   (' ', 'O'),
#   ('미루', 'PERSON'),
#   ('배', 'O'),
#   ('2021', 'DATE'),
#   ('케이팝소', 'EVENT'),
#   ('트', 'O'),
#   ('1위', 'QUANTITY'),
#   (' ', 'O'),
#   ('눈떠보니', 'O'),
#   (' ', 'O'),
#   ('템데입뜨억됨', 'O')],
#  [('랜덤', 'O'),
#   (' ', 'O'),
#   ('씰스티커', 'O'),
#   (' ', 'O'),
#   ('판매해요', 'O'),
#   (' ', 'O'),
#   ('3장', 'QUANTITY'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('5000원', 'QUANTITY'),
#   ('입니다', 'O'),
#   (' ', 'O'),
#   ('폴라로이드', 'O'),
#   (' ', 'O'),
#   ('폴꾸', 'O'),
#   (' ', 'O'),
#   ('다이어리', 'O'),
#   (' ', 'O'),
#   ('다꾸', 'O'),
#   (' ', 'O'),
#   ('스꾸', 'O'),
#   (' ', 'O'),
#   ('탑로더', 'O'),
#   (' ', 'O'),
#   ('탑꾸', 'O'),
#   (' ', 'O'),
#   ('방탄소년단', 'PERSON'),
#   (' ', 'O'),
#   ('세븐틴', 'PERSON'),
#   (' ', 'O'),
#   ('엔시티', 'PERSON'),
#   (' ', 'O'),
#   ('127', 'PERSON'),
#   (' ', 'O'),
#   ('드림', 'PERSON'),
#   (' ', 'O'),
#   ('엑소', 'PERSON'),
#   (' ', 'O'),
#   ('스키즈', 'PERSON'),
#   (' ', 'O'),
#   ('더보이즈', 'PERSON'),
#   (' ', 'O'),
#   ('블랙핑크', 'PERSON'),
#   (' ', 'O'),
#   ('아이브', 'PERSON'),
#   (' ', 'O'),
#   ('트와이스', 'PERSON'),
#   (' ', 'O'),
#   ('있지', 'O'),
#   (' ', 'O'),
#   ('어버블크러쉬 소다 A7', 'ARTIFACT'),
#   (' ', 'O'),
#   ('레드프린팅', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('스엠', 'PERSON'),
#   (' ', 'O'),
#   ('윈터앨범', 'O'),
#   (' ', 'O'),
#   ('단체버전', 'O'),
#   ('이영', 'PERSON'),
#   ('!', 'O')],
#  [('4', 'QUANTITY'),
#   (' ', 'O'),
#   ('어떤', 'O'),
#   (' ', 'O'),
#   ('장르를', 'O'),
#   (' ', 'O'),
#   ('많이', 'O'),
#   (' ', 'O'),
#   ('듣는지', 'O'),
#   (' ', 'O'),
#   ('RB', 'STUDY_FIELD'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('팝', 'STUDY_FIELD'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('인디', 'STUDY_FIELD'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('등등', 'O'),
#   (' ', 'O'),
#   ('좋아해요!', 'O')],
#  [('아파치', 'TERM'),
#   (' ', 'O'),
#   ('로그', 'O'),
#   (' ', 'O'),
#   ('Ubuntu', 'TERM'),
#   (' ', 'O'),
#   ('internal', 'O'),
#   (' ', 'O'),
#   ('dummy', 'O'),
#   (' ', 'O'),
#   ('connection', 'O'),
#   (' ', 'O'),
#   ('해결방법', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('방과후', 'O'),
#   (' ', 'O'),
#   ('설렘', 'O'),
#   (' ', 'O'),
#   ('리원', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('폴라로이드', 'TERM'),
#   (' ', 'O'),
#   ('삽니다', 'O')],
#  [('몬스타엑스레이', 'PERSON'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('몬엑레', 'PERSON'),
#   ('라고', 'O'),
#   (' ', 'O'),
#   ('하는구낭', 'O')],
#  [('HQ', 'O'),
#   (' ', 'O'),
#   ('pics', 'O'),
#   (' ', 'O'),
#   ('INSIDE', 'O'),
#   (' ', 'O'),
#   ('SEVENTEEN', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS 가요대축제', 'EVENT'),
#   (' ', 'O'),
#   ('안무', 'O'),
#   (' ', 'O'),
#   ('연습', 'O'),
#   (' ', 'O'),
#   ('비하인드', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS Song Fest', 'EVENT'),
#   ('iv', 'EVENT'),
#   ('al', 'O'),
#   (' ', 'O'),
#   ('DANCE', 'O'),
#   (' ', 'O'),
#   ('PRACTICE', 'O'),
#   (' ', 'O'),
#   ('BEHIND', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('티', 'O'),
#   (' ', 'O'),
#   ('좀', 'O'),
#   (' ', 'O'),
#   ('내보려고', 'O'),
#   (' ', 'O'),
#   ('트Y스', 'ARTIFACT'),
#   (' ', 'O'),
#   ('Si', 'ARTIFACT'),
#   ('그널을', 'O'),
#   (' ', 'O'),
#   ('부름', 'O'),
#   (' ', 'O'),
#   ('언제부턴가', 'O'),
#   (' ', 'O'),
#   ('난', 'O'),
#   (' ', 'O'),
#   ('네가', 'O'),
#   (' ', 'O'),
#   ('좋아', 'O'),
#   (' ', 'O'),
#   ('지기', 'O'),
#   (' ', 'O'),
#   ('시작했어', 'O'),
#   (' ', 'O'),
#   ('바보야', 'O'),
#   (' ', 'O'),
#   ('왜', 'O'),
#   (' ', 'O'),
#   ('이렇게도', 'O'),
#   (' ', 'O'),
#   ('내', 'O'),
#   (' ', 'O'),
#   ('맘을', 'O'),
#   (' ', 'O'),
#   ('몰라', 'O'),
#   (' ', 'O'),
#   ('언제까지', 'O'),
#   (' ', 'O'),
#   ('이렇게', 'O'),
#   (' ', 'O'),
#   ('둔하게', 'O'),
#   (' ', 'O'),
#   ('나를', 'O'),
#   (' ', 'O'),
#   ('친구', 'CIVILIZATION'),
#   ('로만', 'O'),
#   (' ', 'O'),
#   ('대할래', 'O'),
#   (' ', 'O'),
#   ('차니', 'PERSON'),
#   (' ', 'O'),
#   ('뚫어지게', 'O'),
#   (' ', 'O'),
#   ('보면서', 'O'),
#   (' ', 'O'),
#   ('부르는데', 'O'),
#   (' ', 'O'),
#   ('차니', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('또', 'O'),
#   (' ', 'O'),
#   ('전혀', 'O'),
#   (' ', 'O'),
#   ('눈치', 'O'),
#   (' ', 'O'),
#   ('못', 'O'),
#   (' ', 'O'),
#   ('챔.', 'O'),
#   (' ', 'O'),
#   ('사실', 'O'),
#   (' ', 'O'),
#   ('당연한', 'O'),
#   (' ', 'O'),
#   ('일임.', 'O'),
#   (' ', 'O'),
#   ('과니', 'PERSON'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('괜히', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('박사', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('소리를', 'O'),
#   (' ', 'O'),
#   ('듣는', 'O'),
#   (' ', 'O'),
#   ('게', 'O'),
#   (' ', 'O'),
#   ('아님..', 'O')],
#  [('요네즈 켄시', 'PERSON'),
#   (' ', 'O'),
#   ('노래듣는데', 'O'),
#   (' ', 'O'),
#   ('orion', 'O'),
#   (' ', 'O'),
#   ('되게', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   ('같다는', 'O'),
#   (' ', 'O'),
#   ('생각을', 'O'),
#   (' ', 'O'),
#   ('했음', 'O')],
#  [('들어보면', 'O'),
#   (' ', 'O'),
#   ('생각보다', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   ('같음', 'O')],
#  [('나', 'O'),
#   (' ', 'O'),
#   ('팬미팅.', 'O'),
#   (' ', 'O'),
#   ('콘서트.', 'O'),
#   (' ', 'O'),
#   ('좋아하는데.', 'O'),
#   (' ', 'O'),
#   ('잠실', 'LOCATION'),
#   (' ', 'O'),
#   ('실체.?', 'O'),
#   (' ', 'O'),
#   ('오히려', 'O'),
#   (' ', 'O'),
#   ('좋아.', 'O'),
#   (' ', 'O'),
#   ('제발', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('콘서트', 'O'),
#   (' ', 'O'),
#   ('열어줘ㅠㅠ', 'O')],
#  [('HQ', 'O'),
#   (' ', 'O'),
#   ('pics', 'O'),
#   (' ', 'O'),
#   ('INSIDE', 'O'),
#   (' ', 'O'),
#   ('SEVENTEEN', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS 가요대축제', 'EVENT'),
#   (' ', 'O'),
#   ('안무', 'O'),
#   (' ', 'O'),
#   ('연습', 'O'),
#   (' ', 'O'),
#   ('비하인드', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS Song Fest', 'EVENT'),
#   ('iv', 'EVENT'),
#   ('al', 'O'),
#   (' ', 'O'),
#   ('DANCE', 'O'),
#   (' ', 'O'),
#   ('PRACTICE', 'O'),
#   (' ', 'O'),
#   ('BEHIND', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('10', 'QUANTITY'),
#   ('.', 'O'),
#   (' ', 'O'),
#   ('헨리', 'PERSON'),
#   (' ', 'O'),
#   ('초반에는', 'O'),
#   (' ', 'O'),
#   ('솔직해서', 'O'),
#   (' ', 'O'),
#   ('좋아했습니다.', 'O'),
#   (' ', 'O'),
#   ('돌직구', 'O'),
#   (' ', 'O'),
#   ('본인의', 'O'),
#   (' ', 'O'),
#   ('눈', 'ANIMAL'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('욕망이', 'O'),
#   (' ', 'O'),
#   ('보이는', 'O'),
#   (' ', 'O'),
#   ('사람을', 'O'),
#   (' ', 'O'),
#   ('아이브', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('편하게', 'O'),
#   (' ', 'O'),
#   ('여기니..', 'O'),
#   (' ', 'O'),
#   ('아무래도', 'O'),
#   (' ', 'O'),
#   ('그', 'O'),
#   (' ', 'O'),
#   ('욕망이', 'O'),
#   (' ', 'O'),
#   ('설령', 'O'),
#   (' ', 'O'),
#   ('자신에게', 'O'),
#   (' ', 'O'),
#   ('호감이', 'O'),
#   (' ', 'O'),
#   ('아니라', 'O'),
#   (' ', 'O'),
#   ('헤로', 'O'),
#   (' ', 'O'),
#   ('작용할', 'O'),
#   (' ', 'O'),
#   ('수', 'O'),
#   (' ', 'O'),
#   ('있다는', 'O'),
#   (' ', 'O'),
#   ('걸', 'O'),
#   (' ', 'O'),
#   ('알면서도', 'O'),
#   (' ', 'O'),
#   ('편하게', 'O'),
#   (' ', 'O'),
#   ('적당히', 'O'),
#   (' ', 'O'),
#   ('그것만', 'O'),
#   (' ', 'O'),
#   ('채워주면', 'O'),
#   (' ', 'O'),
#   ('황금알', 'O'),
#   (' ', 'O'),
#   ('낳는', 'O'),
#   (' ', 'O'),
#   ('오리', 'ANIMAL'),
#   (' ', 'O'),
#   ('보는', 'O'),
#   (' ', 'O'),
#   ('느낌으로', 'O'),
#   (' ', 'O'),
#   ('딱', 'O'),
#   (' ', 'O'),
#   ('어느', 'O'),
#   (' ', 'O'),
#   ('수준까지만', 'O'),
#   (' ', 'O'),
#   ('자길', 'O')],
#  [('너무', 'O'),
#   (' ', 'O'),
#   ('신빙성잇엇다고요', 'O'),
#   (' ', 'O'),
#   ('ㄹㅇ', 'O'),
#   (' ', 'O'),
#   ('연습생', 'CIVILIZATION'),
#   ('같음', 'O'),
#   (' ', 'O'),
#   ('어느날', 'O'),
#   (' ', 'O'),
#   ('계폭하고', 'O'),
#   (' ', 'O'),
#   ('스엠', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('이갈앗다!', 'O'),
#   (' ', 'O'),
#   ('하고', 'O'),
#   (' ', 'O'),
#   ('공개한', 'O'),
#   (' ', 'O'),
#   ('신인', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('여돌', 'O'),
#   (' ', 'O'),
#   ('같앗음.', 'O')],
#  [('절절끓는', 'O'),
#   (' ', 'O'),
#   ('한남', 'LOCATION'),
#   ('보컬', 'CIVILIZATION'),
#   ('x', 'O'),
#   (' ', 'O'),
#   ('그렇다고', 'O'),
#   (' ', 'O'),
#   ('막.', 'O'),
#   (' ', 'O'),
#   ('바이브', 'PERSON'),
#   ('미치는', 'O'),
#   (' ', 'O'),
#   ('양', 'PERSON'),
#   ('놈', 'O'),
#   (' ', 'O'),
#   ('노래도x..', 'O'),
#   (' ', 'O'),
#   ('나는', 'O'),
#   ('우지', 'PERSON'),
#   ('가부르는', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('워먼', 'ARTIFACT'),
#   (' ', 'O'),
#   ('선배', 'CIVILIZATION'),
#   ('님들', 'O'),
#   (' ', 'O'),
#   ('노래가', 'O'),
#   (' ', 'O'),
#   ('젤', 'O'),
#   (' ', 'O'),
#   ('조흠', 'O'),
#   (' ', 'O'),
#   ('진짜그감성이.', 'O'),
#   (' ', 'O'),
#   ('맞닿아있다고', 'O'),
#   (' ', 'O'),
#   ('그래서늘성별을', 'O'),
#   (' ', 'O'),
#   ('의심하는,,', 'O')],
#  [('HQ', 'O'),
#   (' ', 'O'),
#   ('pics', 'O'),
#   (' ', 'O'),
#   ('INSIDE', 'O'),
#   (' ', 'O'),
#   ('SEVENTEEN', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS 가요대축제', 'EVENT'),
#   (' ', 'O'),
#   ('안무', 'O'),
#   (' ', 'O'),
#   ('연습', 'O'),
#   (' ', 'O'),
#   ('비하인드', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS Song Fest', 'EVENT'),
#   ('iv', 'EVENT'),
#   ('al', 'O'),
#   (' ', 'O'),
#   ('DANCE', 'O'),
#   (' ', 'O'),
#   ('PRACTICE', 'O'),
#   (' ', 'O'),
#   ('BEHIND', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('LIVE', 'O'),
#   (' ', 'O'),
#   ('IVE', 'O'),
#   (' ', 'O'),
#   ('아이브', 'PERSON'),
#   (' ', 'O'),
#   ('ELEVEN 두시탈출 컬투쇼', 'ARTIFACT'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('설강화', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('지수', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('정해인', 'PERSON'),
#   (' ', 'O'),
#   ('인스타그램', 'TERM'),
#   (' ', 'O'),
#   ('사진', 'O'),
#   (' ', 'O'),
#   ('공유', 'O'),
#   (' ', 'O'),
#   ('출처', 'O')],
#  [('훅', 'PERSON'),
#   (' ', 'O'),
#   ('아이키', 'PERSON'),
#   (' ', 'O'),
#   ('라치카', 'PERSON'),
#   (' ', 'O'),
#   ('시미즈 프라우드먼', 'PERSON'),
#   (' ', 'O'),
#   ('케이데이', 'PERSON'),
#   (' ', 'O'),
#   ('코카앤버커', 'PERSON'),
#   (' ', 'O'),
#   ('리헤이', 'PERSON'),
#   (' ', 'O'),
#   ('원트', 'PERSON'),
#   (' ', 'O'),
#   ('엠마 웨이비', 'PERSON'),
#   (' ', 'O'),
#   ('노제', 'PERSON'),
#   (' ', 'O'),
#   ('홀리뱅', 'PERSON'),
#   (' ', 'O'),
#   ('제인', 'PERSON'),
#   (' ', 'O'),
#   ('와이지엑스', 'PERSON'),
#   (' ', 'O'),
#   ('리정', 'PERSON')],
#  [('스트레이키즈', 'PERSON'),
#   (' ', 'O'),
#   ('현진', 'PERSON'),
#   (' ', 'O'),
#   ('황현진', 'PERSON'),
#   (' ', 'O'),
#   ('포카', 'ARTIFACT'),
#   (' ', 'O'),
#   ('양도', 'O'),
#   (' ', 'O'),
#   ('사웨', 'O'),
#   (' ', 'O'),
#   ('위드드라마', 'O'),
#   (' ', 'O'),
#   ('크리', 'DATE'),
#   ('스마', 'DATE'),
#   ('스이블', 'O'),
#   (' ', 'O'),
#   ('럭드', 'O'),
#   (' ', 'O'),
#   ('도미노', 'O'),
#   (' ', 'O'),
#   ('무스탕', 'O'),
#   (' ', 'O'),
#   ('소니', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('특전', 'O'),
#   (' ', 'O'),
#   ('인생', 'O'),
#   (' ', 'O'),
#   ('마뮤테', 'O'),
#   (' ', 'O'),
#   ('노이지', 'O'),
#   (' ', 'O'),
#   ('메씨마', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('메씨마', 'ORGANIZATION'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('컨포', 'O'),
#   (' ', 'O'),
#   ('셀포', 'O'),
#   (' ', 'O'),
#   ('합친가격', 'O'),
#   (' ', 'O'),
#   ('준등비', 'O'),
#   (' ', 'O'),
#   ('0.18', 'QUANTITY'),
#   (' ', 'O'),
#   ('탑로더', 'O'),
#   (' ', 'O'),
#   ('뽁뽁이포장', 'O'),
#   (' ', 'O'),
#   ('쿨거즉입', 'O'),
#   (' ', 'O'),
#   ('적힌가격', 'O'),
#   (' ', 'O'),
#   ('0.1', 'QUANTITY'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('오늘', 'DATE'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('평테이', 'O'),
#   (' ', 'O'),
#   ('다짐합니다', 'O')],
#  [('스트레이키즈 스키즈', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('방찬', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('창빈 포카', 'ARTIFACT'),
#   (' ', 'O'),
#   ('25장', 'QUANTITY'),
#   (' ', 'O'),
#   ('일괄', 'O'),
#   (' ', 'O'),
#   ('준미포 2', 'ORGANIZATION'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('양도합니다', 'O'),
#   (' ', 'O'),
#   ('디엠', 'O'),
#   (' ', 'O'),
#   ('주세요!', 'O'),
#   (' ', 'O'),
#   ('소리꾼', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('노이지 차일드후드', 'PERSON'),
#   (' ', 'O'),
#   ('양면포카', 'ARTIFACT'),
#   (' ', 'O'),
#   ('앨범', 'O'),
#   (' ', 'O'),
#   ('앨포', 'O'),
#   (' ', 'O'),
#   ('한정반', 'O'),
#   (' ', 'O'),
#   ('아기방찬', 'O'),
#   (' ', 'O'),
#   ('포토카드', 'O'),
#   (' ', 'O'),
#   ('판매', 'O'),
#   (' ', 'O'),
#   ('Straykid', 'ARTIFACT'),
#   ('s', 'O'),
#   (' ', 'O'),
#   ('skz', 'O'),
#   (' ', 'O'),
#   ('bangchan', 'O'),
#   (' ', 'O'),
#   ('changbin', 'O'),
#   (' ', 'O'),
#   ('noeasy', 'O'),
#   (' ', 'O'),
#   ('childhood', 'O'),
#   (' ', 'O'),
#   ('poca', 'O'),
#   (' ', 'O'),
#   ('photocard', 'O'),
#   (' ', 'O'),
#   ('wts', 'O'),
#   (' ', 'O'),
#   ('sell', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('220116', 'DATE'),
#   (' ', 'O'),
#   ('두바이', 'CITY'),
#   (' ', 'O'),
#   ('방찬', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('211202', 'QUANTITY'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('아시아 아티스트 어워즈', 'EVENT'),
#   (' ', 'O'),
#   ('AAA', 'EVENT'),
#   (' ', 'O'),
#   ('인터뷰', 'O'),
#   (' ', 'O'),
#   ('가수', 'CIVILIZATION'),
#   ('석', 'O'),
#   (' ', 'O'),
#   ('Cut', 'O'),
#   (' ', 'O'),
#   ('TS', 'O'),
#   (' ', 'O'),
#   ('메일', 'O'),
#   (' ', 'O'),
#   ('기차', 'ARTIFACT'),
#   (' ', 'O'),
#   ('URL', 'O'),
#   (' ', 'O'),
#   ('URL', 'O'),
#   (' ', 'O'),
#   ('URL', 'O'),
#   (' ', 'O'),
#   ('URL', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('건드릴', 'O'),
#   (' ', 'O'),
#   ('걸', 'O'),
#   (' ', 'O'),
#   ('알아서..', 'O'),
#   (' ', 'O'),
#   ('그랬다네요.', 'O'),
#   (' ', 'O'),
#   ('근데', 'O'),
#   (' ', 'O'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('인식이', 'O'),
#   (' ', 'O'),
#   ('나중에', 'O'),
#   (' ', 'O'),
#   ('정작', 'O'),
#   (' ', 'O'),
#   ('원하던', 'O'),
#   (' ', 'O'),
#   ('귀금속을', 'O'),
#   (' ', 'O'),
#   ('준', 'O'),
#   (' ', 'O'),
#   ('뒤에', 'O'),
#   (' ', 'O'),
#   ('헨리', 'PERSON'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('태도가', 'O'),
#   (' ', 'O'),
#   ('달라져서', 'O'),
#   (' ', 'O'),
#   ('좀', 'O'),
#   (' ', 'O'),
#   ('바뀌었다고', 'O'),
#   (' ', 'O'),
#   ('합니다.', 'O'),
#   (' ', 'O'),
#   ('아이브', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('정말', 'O'),
#   (' ', 'O'),
#   ('가지고', 'O'),
#   (' ', 'O'),
#   ('왔다가..', 'O'),
#   (' ', 'O'),
#   ('자기', 'O'),
#   (' ', 'O'),
#   ('유품이', 'O'),
#   (' ', 'O'),
#   ('되느니', 'O'),
#   (' ', 'O'),
#   ('적정한', 'O'),
#   (' ', 'O'),
#   ('사람에게', 'O'),
#   (' ', 'O'),
#   ('가는', 'O'),
#   (' ', 'O'),
#   ('편이', 'O'),
#   (' ', 'O'),
#   ('좋기도', 'O'),
#   (' ', 'O'),
#   ('하고,', 'O'),
#   (' ', 'O'),
#   ('받는', 'O'),
#   (' ', 'O'),
#   ('당사자', 'CIVILIZATION'),
#   ('에게는', 'O'),
#   (' ', 'O'),
#   ('다르게', 'O'),
#   (' ', 'O'),
#   ('느껴질', 'O'),
#   (' ', 'O'),
#   ('걸', 'O'),
#   (' ', 'O'),
#   ('아니,', 'O'),
#   (' ', 'O'),
#   ('죽기', 'O'),
#   (' ', 'O'),
#   ('전에', 'O'),
#   (' ', 'O'),
#   ('그래도', 'O')],
#  [('HQ', 'O'),
#   (' ', 'O'),
#   ('pics', 'O'),
#   (' ', 'O'),
#   ('INSIDE', 'O'),
#   (' ', 'O'),
#   ('SEVENTEEN', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS 가요대축제', 'EVENT'),
#   (' ', 'O'),
#   ('안무', 'O'),
#   (' ', 'O'),
#   ('연습', 'O'),
#   (' ', 'O'),
#   ('비하인드', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS Song Fest', 'EVENT'),
#   ('iv', 'EVENT'),
#   ('al', 'O'),
#   (' ', 'O'),
#   ('DANCE', 'O'),
#   (' ', 'O'),
#   ('PRACTICE', 'O'),
#   (' ', 'O'),
#   ('BEHIND', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('바이미나', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('설강화', 'O'),
#   (' ', 'O'),
#   ('블랙핑크', 'PERSON'),
#   (' ', 'O'),
#   ('지수', 'O'),
#   (' ', 'O'),
#   ('메리제인', 'PERSON'),
#   (' ', 'O'),
#   ('구두', 'O'),
#   (' ', 'O'),
#   ('패션', 'O'),
#   (' ', 'O'),
#   ('출처', 'O')],
#  [('남에게', 'O'),
#   (' ', 'O'),
#   ('호감을', 'O'),
#   (' ', 'O'),
#   ('얻어볼까..', 'O'),
#   (' ', 'O'),
#   ('같은', 'O'),
#   (' ', 'O'),
#   ('느낌이었는데,', 'O'),
#   (' ', 'O'),
#   ('생각보다', 'O'),
#   (' ', 'O'),
#   ('더', 'O'),
#   (' ', 'O'),
#   ('좋게', 'O'),
#   (' ', 'O'),
#   ('일이', 'O'),
#   (' ', 'O'),
#   ('풀려서', 'O'),
#   (' ', 'O'),
#   ('좀', 'O'),
#   (' ', 'O'),
#   ('기뻤다고', 'O'),
#   (' ', 'O'),
#   ('합니다.', 'O'),
#   (' ', 'O'),
#   ('결과론적으로', 'O'),
#   (' ', 'O'),
#   ('라이브라에', 'O'),
#   (' ', 'O'),
#   ('들어온', 'O'),
#   (' ', 'O'),
#   ('걸', 'O'),
#   (' ', 'O'),
#   ('보면', 'O'),
#   (' ', 'O'),
#   ('썩', 'O'),
#   (' ', 'O'),
#   ('성향이', 'O'),
#   (' ', 'O'),
#   ('나쁜', 'O'),
#   (' ', 'O'),
#   ('것', 'O'),
#   (' ', 'O'),
#   ('같지도', 'O'),
#   (' ', 'O'),
#   ('않고,', 'O'),
#   (' ', 'O'),
#   ('자길', 'O'),
#   (' ', 'O'),
#   ('꽤', 'O'),
#   (' ', 'O'),
#   ('나쁘지', 'O'),
#   (' ', 'O'),
#   ('않게', 'O'),
#   (' ', 'O'),
#   ('여기게', 'O'),
#   (' ', 'O'),
#   ('된', 'O'),
#   (' ', 'O'),
#   ('계기가', 'O'),
#   (' ', 'O'),
#   ('생긴', 'O'),
#   (' ', 'O'),
#   ('거', 'O'),
#   (' ', 'O'),
#   ('같아서,', 'O'),
#   (' ', 'O'),
#   ('앞으로', 'O'),
#   (' ', 'O'),
#   ('관계가', 'O'),
#   (' ', 'O'),
#   ('어떻게', 'O'),
#   (' ', 'O'),
#   ('될지', 'O'),
#   (' ', 'O'),
#   ('나름', 'O'),
#   (' ', 'O'),
#   ('기대되는', 'O'),
#   (' ', 'O'),
#   ('사람입니다.', 'O')],
#  [('2개', 'QUANTITY'),
#   (' ', 'O'),
#   ('토니모리', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('이지터치 케익', 'ARTIFACT'),
#   (' ', 'O'),
#   ('아이브로우 백젤 라이너', 'ARTIFACT'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('01', 'QUANTITY'),
#   ('.', 'O'),
#   ('이지터치', 'ARTIFACT'),
#   (' ', 'O'),
#   ('케익', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('아이브로우', 'ARTIFACT'),
#   (' ', 'O'),
#   ('내추럴브라운', 'ARTIFACT'),
#   (' ', 'O'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('02', 'QUANTITY'),
#   ('.', 'O'),
#   ('이지터치', 'ARTIFACT'),
#   (' ', 'O'),
#   ('케익', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('아이브로우', 'ARTIFACT'),
#   (' ', 'O'),
#   ('그레이브라운', 'ARTIFACT'),
#   (' ', 'O'),
#   ('URL', 'O'),
#   (' ', 'O'),
#   ('파트너스', 'O'),
#   (' ', 'O'),
#   ('활동으로', 'O'),
#   (' ', 'O'),
#   ('수수료를', 'O'),
#   (' ', 'O'),
#   ('받을수', 'O'),
#   (' ', 'O'),
#   ('있어요', 'O'),
#   (' ', 'O'),
#   ('95', 'QUANTITY'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('재화룡품을', 'O'),
#   (' ', 'O'),
#   ('줍는', 'O'),
#   (' ', 'O'),
#   ('정도로', 'O'),
#   (' ', 'O'),
#   ('생각하시면', 'O'),
#   (' ', 'O'),
#   ('됩니다.', 'O'),
#   (' ', 'O'),
#   ('예전에는', 'O'),
#   (' ', 'O'),
#   ('리어카', 'ARTIFACT'),
#   (' ', 'O'),
#   ('운반이', 'O'),
#   (' ', 'O'),
#   ('상용화', 'O'),
#   (' ', 'O'),
#   ('되기', 'O'),
#   (' ', 'O'),
#   ('이전에,', 'O'),
#   (' ', 'O'),
#   ('사람이', 'O'),
#   (' ', 'O'),
#   ('대나무', 'PLANT'),
#   (' ', 'O'),
#   ('바구니를', 'O'),
#   (' ', 'O'),
#   ('이용해서', 'O'),
#   (' ', 'O'),
#   ('집게로', 'O'),
#   (' ', 'O'),
#   ('수집하여', 'O'),
#   (' ', 'O'),
#   ('판매했던', 'O'),
#   (' ', 'O'),
#   ('것', 'O'),
#   (' ', 'O'),
#   ('같습니다.', 'O')],
#  [('케이팝', 'STUDY_FIELD'),
#   ('할때마다', 'O'),
#   (' ', 'O'),
#   ('게임', 'O'),
#   (' ', 'O'),
#   ('접음', 'O'),
#   (' ', 'O'),
#   ('순기능', 'O'),
#   (' ', 'O'),
#   ('?', 'O')],
#  [('HQ', 'O'),
#   (' ', 'O'),
#   ('pics', 'O'),
#   (' ', 'O'),
#   ('INSIDE', 'O'),
#   (' ', 'O'),
#   ('SEVENTEEN', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS 가요대축제', 'EVENT'),
#   (' ', 'O'),
#   ('안무', 'O'),
#   (' ', 'O'),
#   ('연습', 'O'),
#   (' ', 'O'),
#   ('비하인드', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS Song Fest', 'EVENT'),
#   ('iv', 'EVENT'),
#   ('al', 'O'),
#   (' ', 'O'),
#   ('DANCE', 'O'),
#   (' ', 'O'),
#   ('PRACTICE', 'O'),
#   (' ', 'O'),
#   ('BEHIND', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('당디', 'PERSON'),
#   ('랑', 'O'),
#   (' ', 'O'),
#   ('학창시절', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   ('흑역사', 'O'),
#   (' ', 'O'),
#   ('쭉풀엇는데씨발존나요란하고', 'O'),
#   (' ', 'O'),
#   ('존나쪽팔림', 'O')],
#  [('스엠', 'ARTIFACT'),
#   (' ', 'O'),
#   ('윈터앨범', 'O'),
#   (' ', 'O'),
#   ('단체', 'O'),
#   (' ', 'O'),
#   ('버전이요!', 'O')],
#  [('나', 'O'),
#   (' ', 'O'),
#   ('지금', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   ('얘기하다가', 'O'),
#   (' ', 'O'),
#   ('너무신나서', 'O'),
#   (' ', 'O'),
#   ('머글한테', 'O'),
#   (' ', 'O'),
#   ('트위터', 'TERM'),
#   ('말투로', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   ('얘기', 'O'),
#   (' ', 'O'),
#   ('겁나', 'O'),
#   (' ', 'O'),
#   ('함', 'O'),
#   (' ', 'O'),
#   ('얘', 'O'),
#   (' ', 'O'),
#   ('벅차하늗', 'O'),
#   (' ', 'O'),
#   ('것같은데', 'O'),
#   (' ', 'O'),
#   ('어카지', 'O'),
#   (' ', 'O'),
#   ('멈출', 'O'),
#   (' ', 'O'),
#   ('생각', 'O'),
#   (' ', 'O'),
#   ('X', 'O')],
#  [('HQ', 'O'),
#   (' ', 'O'),
#   ('pics', 'O'),
#   (' ', 'O'),
#   ('INSIDE', 'O'),
#   (' ', 'O'),
#   ('SEVENTEEN', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS 가요대축제', 'EVENT'),
#   (' ', 'O'),
#   ('안무', 'O'),
#   (' ', 'O'),
#   ('연습', 'O'),
#   (' ', 'O'),
#   ('비하인드', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS Song Fest', 'EVENT'),
#   ('iv', 'EVENT'),
#   ('al', 'O'),
#   (' ', 'O'),
#   ('DANCE', 'O'),
#   (' ', 'O'),
#   ('PRACTICE', 'O'),
#   (' ', 'O'),
#   ('BEHIND', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('HQ', 'O'),
#   (' ', 'O'),
#   ('pics', 'O'),
#   (' ', 'O'),
#   ('INSIDE', 'O'),
#   (' ', 'O'),
#   ('SEVENTEEN', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS 가요대축제', 'EVENT'),
#   (' ', 'O'),
#   ('안무', 'O'),
#   (' ', 'O'),
#   ('연습', 'O'),
#   (' ', 'O'),
#   ('비하인드', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS Song Fest', 'EVENT'),
#   ('iv', 'EVENT'),
#   ('al', 'O'),
#   (' ', 'O'),
#   ('DANCE', 'O'),
#   (' ', 'O'),
#   ('PRACTICE', 'O'),
#   (' ', 'O'),
#   ('BEHIND', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('그것도,', 'O'),
#   (' ', 'O'),
#   ('욕설', 'O'),
#   (' ', 'O'),
#   ('파문', 'O'),
#   (' ', 'O'),
#   ('사죄후', 'O'),
#   (' ', 'O'),
#   ('바로', 'O'),
#   (' ', 'O'),
#   ('ㅎ', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('필릭스', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('탄생화', 'PLANT'),
#   (' ', 'O'),
#   ('달리아', 'PLANT'),
#   (' ', 'O'),
#   ('꽃말', 'O'),
#   (' ', 'O'),
#   ('화려함', 'O'),
#   (' ', 'O'),
#   ('승민', 'PERSON'),
#   (' ', 'O'),
#   ('탄생화', 'O'),
#   (' ', 'O'),
#   ('방울새풀', 'PLANT'),
#   (' ', 'O'),
#   ('꽃말', 'O'),
#   (' ', 'O'),
#   ('들뜬', 'O'),
#   (' ', 'O'),
#   ('마음', 'O'),
#   (' ', 'O'),
#   ('아이엔', 'O'),
#   (' ', 'O'),
#   ('탄생화', 'PLANT'),
#   (' ', 'O'),
#   ('범의귀', 'PLANT'),
#   (' ', 'O'),
#   ('꽃말', 'O'),
#   (' ', 'O'),
#   ('절실한', 'O'),
#   (' ', 'O'),
#   ('애정', 'O'),
#   (' ', 'O'),
#   ('스트레이키즈', 'PLANT'),
#   (' ', 'O'),
#   ('탄생화', 'O'),
#   (' ', 'O'),
#   ('덩굴성', 'O'),
#   (' ', 'O'),
#   ('식물', 'O'),
#   (' ', 'O'),
#   ('꽃말', 'O'),
#   (' ', 'O'),
#   ('아름다움', 'O'),
#   (' ', 'O'),
#   ('스테이', 'O'),
#   (' ', 'O'),
#   ('탄생화', 'PLANT'),
#   (' ', 'O'),
#   ('양귀비', 'PLANT'),
#   (' ', 'O'),
#   ('꽃말', 'O'),
#   (' ', 'O'),
#   ('위로,', 'O'),
#   (' ', 'O'),
#   ('위안,', 'O'),
#   (' ', 'O'),
#   ('몽상', 'O')],
#  [('난', 'O'),
#   (' ', 'O'),
#   ('게임할때마다', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('접음', 'O'),
#   (' ', 'O'),
#   ('ㅋㅋ', 'O')],
#  [('HQ', 'O'),
#   (' ', 'O'),
#   ('pics', 'O'),
#   (' ', 'O'),
#   ('INSIDE', 'O'),
#   (' ', 'O'),
#   ('SEVENTEEN', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS 가요대축제', 'EVENT'),
#   (' ', 'O'),
#   ('안무', 'O'),
#   (' ', 'O'),
#   ('연습', 'O'),
#   (' ', 'O'),
#   ('비하인드', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS Song Fest', 'EVENT'),
#   ('iv', 'EVENT'),
#   ('al', 'O'),
#   (' ', 'O'),
#   ('DANCE', 'O'),
#   (' ', 'O'),
#   ('PRACTICE', 'O'),
#   (' ', 'O'),
#   ('BEHIND', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('근데.', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('너무깊게만파고들지만않으면', 'O'),
#   (' ', 'O'),
#   ('가성비대비좋게누릴수도있는', 'O'),
#   (' ', 'O'),
#   ('취미생활이기는', 'O'),
#   (' ', 'O'),
#   ('해', 'DATE'),
#   (' ', 'O'),
#   ('근데이제너무깊게파고들어서문제지', 'O')],
#  [('HQ', 'O'),
#   (' ', 'O'),
#   ('pics', 'O'),
#   (' ', 'O'),
#   ('INSIDE', 'O'),
#   (' ', 'O'),
#   ('SEVENTEEN', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS 가요대축제', 'EVENT'),
#   (' ', 'O'),
#   ('안무', 'O'),
#   (' ', 'O'),
#   ('연습', 'O'),
#   (' ', 'O'),
#   ('비하인드', 'O'),
#   (' ', 'O'),
#   ('2021', 'DATE'),
#   (' ', 'O'),
#   ('KBS Song Fest', 'EVENT'),
#   ('iv', 'EVENT'),
#   ('al', 'O'),
#   (' ', 'O'),
#   ('DANCE', 'O'),
#   (' ', 'O'),
#   ('PRACTICE', 'O'),
#   (' ', 'O'),
#   ('BEHIND', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('내가', 'O'),
#   (' ', 'O'),
#   ('정말', 'O'),
#   (' ', 'O'),
#   ('멋있는', 'O'),
#   (' ', 'O'),
#   ('사람을', 'O'),
#   (' ', 'O'),
#   ('덕질하고있구나', 'O'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('생각..', 'O'),
#   (' ', 'O'),
#   ('이런', 'O'),
#   (' ', 'O'),
#   ('사람을', 'O'),
#   (' ', 'O'),
#   ('덕질하길', 'O'),
#   (' ', 'O'),
#   ('잘했다는', 'O'),
#   (' ', 'O'),
#   ('생각..', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('11', 'QUANTITY'),
#   ('.', 'O'),
#   (' ', 'O'),
#   ('식스 식스', 'ARTIFACT'),
#   ('는..', 'O'),
#   (' ', 'O'),
#   ('기본적으로', 'O'),
#   (' ', 'O'),
#   ('쾌활하다는', 'O'),
#   (' ', 'O'),
#   ('인상이', 'O'),
#   (' ', 'O'),
#   ('강하네요.', 'O'),
#   (' ', 'O'),
#   ('쾌활하고,', 'O'),
#   (' ', 'O'),
#   ('까칠하고,', 'O'),
#   (' ', 'O'),
#   ('여러모로', 'O'),
#   (' ', 'O'),
#   ('아직', 'O'),
#   (' ', 'O'),
#   ('어린', 'O'),
#   (' ', 'O'),
#   ('친구', 'CIVILIZATION'),
#   ('지만,', 'O'),
#   (' ', 'O'),
#   ('살고자', 'O'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('목표가', 'O'),
#   (' ', 'O'),
#   ('단단하게', 'O'),
#   (' ', 'O'),
#   ('세워진', 'O'),
#   (' ', 'O'),
#   ('채라', 'O'),
#   (' ', 'O'),
#   ('어떤', 'O'),
#   (' ', 'O'),
#   ('일이', 'O'),
#   (' ', 'O'),
#   ('있더라도', 'O'),
#   (' ', 'O'),
#   ('굳건하게', 'O'),
#   (' ', 'O'),
#   ('살아가지', 'O'),
#   (' ', 'O'),
#   ('않을까', 'O'),
#   (' ', 'O'),
#   ('싶어합니다.', 'O'),
#   (' ', 'O'),
#   ('30', 'QUANTITY'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('되기', 'O'),
#   (' ', 'O'),
#   ('전에', 'O'),
#   (' ', 'O'),
#   ('저주를', 'O'),
#   (' ', 'O'),
#   ('풀겠다고', 'O'),
#   (' ', 'O'),
#   ('했으니,', 'O'),
#   (' ', 'O'),
#   ('그걸', 'O'),
#   (' ', 'O'),
#   ('기대하고', 'O'),
#   (' ', 'O'),
#   ('있어요.', 'O'),
#   (' ', 'O'),
#   ('그렇게,', 'O'),
#   (' ', 'O'),
#   ('몸', 'ANIMAL'),
#   ('이', 'O')],
#  [('건강한', 'O'),
#   (' ', 'O'),
#   ('채로', 'O'),
#   (' ', 'O'),
#   ('풀어서,', 'O'),
#   (' ', 'O'),
#   ('살아가는', 'O'),
#   (' ', 'O'),
#   ('걸', 'O'),
#   (' ', 'O'),
#   ('보면..', 'O'),
#   (' ', 'O'),
#   ('그것대로', 'O'),
#   (' ', 'O'),
#   ('희망을', 'O'),
#   (' ', 'O'),
#   ('누군가에게', 'O'),
#   (' ', 'O'),
#   ('주지', 'O'),
#   (' ', 'O'),
#   ('않을까,', 'O'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('느낌이네요.', 'O'),
#   (' ', 'O'),
#   ('여러모로', 'O'),
#   (' ', 'O'),
#   ('성격은', 'O'),
#   (' ', 'O'),
#   ('썩', 'O'),
#   (' ', 'O'),
#   ('좋지만은', 'O'),
#   (' ', 'O'),
#   ('않다고', 'O'),
#   (' ', 'O'),
#   ('생각하지만,', 'O'),
#   (' ', 'O'),
#   ('크게', 'O'),
#   (' ', 'O'),
#   ('악의가', 'O'),
#   (' ', 'O'),
#   ('있기보다는', 'O'),
#   (' ', 'O'),
#   ('그냥', 'O'),
#   (' ', 'O'),
#   ('좀', 'O'),
#   (' ', 'O'),
#   ('사정이', 'O'),
#   (' ', 'O'),
#   ('있는만큼', 'O'),
#   (' ', 'O'),
#   ('날이', 'O'),
#   (' ', 'O'),
#   ('서', 'O'),
#   (' ', 'O'),
#   ('있다는', 'O'),
#   (' ', 'O'),
#   ('생각을', 'O'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('편입니다.', 'O'),
#   (' ', 'O'),
#   ('그리고', 'O'),
#   (' ', 'O'),
#   ('달링', 'PERSON'),
#   ('을', 'O'),
#   (' ', 'O'),
#   ('왜', 'O'),
#   (' ', 'O'),
#   ('이렇게', 'O'),
#   (' ', 'O'),
#   ('싫어하는지', 'O'),
#   (' ', 'O'),
#   ('좀', 'O')],
#  [('스트레이키즈', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('안좋아하면', 'O'),
#   (' ', 'O'),
#   ('손해', 'O')],
#  [('궁금해하는', 'O'),
#   (' ', 'O'),
#   ('중이긴', 'O'),
#   (' ', 'O'),
#   ('한데..', 'O'),
#   (' ', 'O'),
#   ('뭐', 'O'),
#   (' ', 'O'),
#   ('이유가', 'O'),
#   (' ', 'O'),
#   ('있겠거니', 'O'),
#   (' ', 'O'),
#   ('하고', 'O'),
#   (' ', 'O'),
#   ('있어요.', 'O'),
#   (' ', 'O'),
#   ('월급으로', 'O'),
#   (' ', 'O'),
#   ('매일', 'O'),
#   (' ', 'O'),
#   ('라디오', 'TERM'),
#   (' ', 'O'),
#   ('값을', 'O'),
#   (' ', 'O'),
#   ('차감하는', 'O'),
#   (' ', 'O'),
#   ('걸', 'O'),
#   (' ', 'O'),
#   ('보면', 'O'),
#   (' ', 'O'),
#   ('사정이라도', 'O'),
#   (' ', 'O'),
#   ('있겠다..', 'O'),
#   (' ', 'O'),
#   ('싶은..', 'O'),
#   (' ', 'O'),
#   ('그리고', 'O'),
#   (' ', 'O'),
#   ('동시에', 'O'),
#   (' ', 'O'),
#   ('저', 'O'),
#   (' ', 'O'),
#   ('나이에', 'O'),
#   (' ', 'O'),
#   ('돈이', 'O'),
#   (' ', 'O'),
#   ('많은', 'O'),
#   (' ', 'O'),
#   ('편인', 'O'),
#   (' ', 'O'),
#   ('걸', 'O'),
#   (' ', 'O'),
#   ('보면,', 'O'),
#   (' ', 'O'),
#   ('과거에', 'O'),
#   (' ', 'O'),
#   ('꽤', 'O'),
#   (' ', 'O'),
#   ('돈을', 'O'),
#   (' ', 'O'),
#   ('많이', 'O'),
#   (' ', 'O'),
#   ('벌만한', 'O'),
#   (' ', 'O'),
#   ('직업을', 'O'),
#   (' ', 'O'),
#   ('가지고', 'O'),
#   (' ', 'O'),
#   ('있었나?', 'O'),
#   (' ', 'O'),
#   ('싶어합니다.', 'O'),
#   (' ', 'O'),
#   ('부모', 'CIVILIZATION'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('많았더라면', 'O'),
#   (' ', 'O'),
#   ('라이브라에', 'O')],
#  [('심야', 'O'),
#   ('아이돌', 'OCCUPATION'),
#   (' ', 'O'),
#   ('창균', 'PERSON'),
#   ('이가', 'O'),
#   (' ', 'O'),
#   ('사랑하는', 'O'),
#   (' ', 'O'),
#   ('모든사람들이', 'O'),
#   (' ', 'O'),
#   ('행복하길', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('윤정한', 'PERSON'),
#   (' ', 'O'),
#   ('포카', 'ARTIFACT'),
#   (' ', 'O'),
#   ('양도받아요', 'O'),
#   (' ', 'O'),
#   ('이거', 'O'),
#   (' ', 'O'),
#   ('이외에도', 'O'),
#   (' ', 'O'),
#   ('받음!', 'O'),
#   (' ', 'O'),
#   ('헹가레', 'O'),
#   (' ', 'O'),
#   ('포카', 'TERM'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('필요하더라고', 'O'),
#   (' ', 'O'),
#   ('라는', 'O'),
#   (' ', 'O'),
#   ('말이', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('아프다', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('들어와서', 'O'),
#   (' ', 'O'),
#   ('이런', 'O'),
#   (' ', 'O'),
#   ('위험한', 'O'),
#   (' ', 'O'),
#   ('일을', 'O'),
#   (' ', 'O'),
#   ('하긴', 'O'),
#   (' ', 'O'),
#   ('어려웠을', 'O'),
#   (' ', 'O'),
#   ('거라', 'O'),
#   (' ', 'O'),
#   ('생각을', 'O'),
#   (' ', 'O'),
#   ('좀', 'O'),
#   (' ', 'O'),
#   ('하기도', 'O'),
#   (' ', 'O'),
#   ('했거든요..', 'O'),
#   (' ', 'O'),
#   ('보통', 'O'),
#   (' ', 'O'),
#   ('부자집', 'O'),
#   (' ', 'O'),
#   ('자식', 'CIVILIZATION'),
#   ('이면', 'O'),
#   (' ', 'O'),
#   ('그렇게', 'O'),
#   (' ', 'O'),
#   ('여러가지', 'O'),
#   (' ', 'O'),
#   ('이유로', 'O'),
#   (' ', 'O'),
#   ('안', 'O'),
#   (' ', 'O'),
#   ('내본다는', 'O'),
#   (' ', 'O'),
#   ('지구', 'LOCATION'),
#   ('에서', 'O'),
#   (' ', 'O'),
#   ('얻어낸', 'O'),
#   (' ', 'O'),
#   ('편견이', 'O'),
#   (' ', 'O'),
#   ('있어서요.', 'O'),
#   (' ', 'O'),
#   ('이건', 'O'),
#   (' ', 'O'),
#   ('논외인데..', 'O'),
#   (' ', 'O'),
#   ('영양제', 'O'),
#   (' ', 'O'),
#   ('먹는', 'O'),
#   (' ', 'O'),
#   ('거', 'O'),
#   (' ', 'O'),
#   ('보고', 'O'),
#   (' ', 'O'),
#   ('밥', 'CIVILIZATION'),
#   ('을', 'O'),
#   (' ', 'O'),
#   ('잘', 'O'),
#   (' ', 'O'),
#   ('먹이고', 'O'),
#   (' ', 'O'),
#   ('싶다는', 'O'),
#   (' ', 'O'),
#   ('생각을', 'O'),
#   (' ', 'O'),
#   ('합니다.', 'O')],
#  [('sell', 'O'),
#   (' ', 'O'),
#   ('방탄소년단', 'PERSON'),
#   (' ', 'O'),
#   ('맵오브더소울', 'PERSON'),
#   (' ', 'O'),
#   ('앨범', 'O'),
#   (' ', 'O'),
#   ('양도', 'O'),
#   (' ', 'O'),
#   ('맵솔앨범', 'O'),
#   (' ', 'O'),
#   ('양도', 'O'),
#   (' ', 'O'),
#   ('합니다!', 'O'),
#   (' ', 'O'),
#   ('일괄', 'O'),
#   (' ', 'O'),
#   ('4만원', 'QUANTITY'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('양도하고', 'O'),
#   (' ', 'O'),
#   ('포카', 'ARTIFACT'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('버전별로', 'O'),
#   (' ', 'O'),
#   ('원하시는', 'O'),
#   (' ', 'O'),
#   ('포카', 'ARTIFACT'),
#   ('로', 'O'),
#   (' ', 'O'),
#   ('골라가시면', 'O'),
#   (' ', 'O'),
#   ('됩니다!', 'O'),
#   (' ', 'O'),
#   ('전부', 'O'),
#   (' ', 'O'),
#   ('풀셋이고', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('상태', 'O'),
#   (' ', 'O'),
#   ('좋아요!', 'O'),
#   (' ', 'O'),
#   ('버전', 'O'),
#   (' ', 'O'),
#   ('1,2,3', 'QUANTITY'),
#   (' ', 'O'),
#   ('구매하시면', 'O'),
#   (' ', 'O'),
#   ('버전 4', 'QUANTITY'),
#   (' ', 'O'),
#   ('앨범은', 'O'),
#   (' ', 'O'),
#   ('포카x', 'TERM'),
#   (' ', 'O'),
#   ('그냥', 'O'),
#   (' ', 'O'),
#   ('드릴게요!', 'O'),
#   (' ', 'O'),
#   ('MOTS', 'O'),
#   (' ', 'O'),
#   ('bts', 'O'),
#   (' ', 'O'),
#   ('mapofthesoul', 'O'),
#   (' ', 'O'),
#   ('taehyung', 'O'),
#   (' ', 'O'),
#   ('namjoon', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('유혹이요?', 'O'),
#   (' ', 'O'),
#   ('어쩐지', 'O'),
#   (' ', 'O'),
#   ('한천지되기', 'O'),
#   (' ', 'O'),
#   ('순식간이더라', 'O')],
#  [('2개', 'QUANTITY'),
#   (' ', 'O'),
#   ('토니모리', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('이지터치 케익', 'ARTIFACT'),
#   (' ', 'O'),
#   ('아이브로우 백젤 라이너', 'ARTIFACT'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('03', 'QUANTITY'),
#   ('.', 'O'),
#   ('백젤 아이라이너', 'ARTIFACT'),
#   (' ', 'O'),
#   ('블랙', 'TERM'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('03', 'QUANTITY'),
#   ('.', 'O'),
#   ('백젤 아이라이너', 'ARTIFACT'),
#   (' ', 'O'),
#   ('블랙', 'TERM'),
#   (' ', 'O'),
#   ('URL', 'O'),
#   (' ', 'O'),
#   ('파트너스', 'O'),
#   (' ', 'O'),
#   ('활동으로', 'O'),
#   (' ', 'O'),
#   ('수수료를', 'O'),
#   (' ', 'O'),
#   ('받을수', 'O'),
#   (' ', 'O'),
#   ('있어요', 'O'),
#   (' ', 'O'),
#   ('13', 'QUANTITY'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('저기', 'O'),
#   (' ', 'O'),
#   ('스마일리', 'O'),
#   (' ', 'O'),
#   ('설마', 'O'),
#   (' ', 'O'),
#   ('없겠지만', 'O'),
#   (' ', 'O'),
#   ('혹시', 'O'),
#   (' ', 'O'),
#   ('아직', 'O'),
#   (' ', 'O'),
#   ('안들어보신', 'O'),
#   (' ', 'O'),
#   ('분', 'O'),
#   (' ', 'O'),
#   ('계시다면', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('꼭', 'O'),
#   (' ', 'O'),
#   ('들어보시고', 'O'),
#   (' ', 'O'),
#   ('뮤비도', 'O'),
#   (' ', 'O'),
#   ('꼭', 'O'),
#   (' ', 'O'),
#   ('봐보세요..', 'O'),
#   (' ', 'O'),
#   ('진차', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('좋은데', 'O'),
#   (' ', 'O'),
#   ('하루종일', 'DATE'),
#   (' ', 'O'),
#   ('아네버워너크라이크라이', 'O'),
#   (' ', 'O'),
#   ('이래서', 'O'),
#   (' ', 'O'),
#   ('미치겠슴니다', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('좋고', 'O'),
#   (' ', 'O'),
#   ('중독성', 'O'),
#   (' ', 'O'),
#   ('쩔고', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('최예나', 'PERSON'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('찢었어요', 'O')],
#  [('아이브 시그', 'ARTIFACT'),
#   (' ', 'O'),
#   ('본품', 'O'),
#   (' ', 'O'),
#   ('분철', 'ARTIFACT'),
#   (' ', 'O'),
#   ('아이브', 'ARTIFACT'),
#   (' ', 'O'),
#   ('분철', 'ARTIFACT'),
#   (' ', 'O'),
#   ('유진', 'ARTIFACT'),
#   (' ', 'O'),
#   ('가을', 'DATE'),
#   (' ', 'O'),
#   ('0.4 3', 'QUANTITY'),
#   (' ', 'O'),
#   ('원영', 'PERSON'),
#   (' ', 'O'),
#   ('0.5 2', 'QUANTITY'),
#   (' ', 'O'),
#   ('리즈', 'PERSON'),
#   (' ', 'O'),
#   ('0.5 1 개당', 'QUANTITY'),
#   (' ', 'O'),
#   ('가격이에요', 'O'),
#   (' ', 'O'),
#   ('편하게', 'O'),
#   (' ', 'O'),
#   ('디엠', 'O'),
#   (' ', 'O'),
#   ('주세요', 'O'),
#   (' ', 'O'),
#   ('특전', 'O'),
#   (' ', 'O'),
#   ('포함', 'O'),
#   (' ', 'O'),
#   ('x', 'O'),
#   (' ', 'O'),
#   ('최대한', 'O'),
#   (' ', 'O'),
#   ('분철할', 'O'),
#   (' ', 'O'),
#   ('수', 'O'),
#   (' ', 'O'),
#   ('있는', 'O'),
#   (' ', 'O'),
#   ('거', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('분철해요', 'O'),
#   (' ', 'O'),
#   ('구매', 'O'),
#   (' ', 'O'),
#   ('인증', 'O'),
#   (' ', 'O'),
#   ('가능', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('그건', 'O'),
#   (' ', 'O'),
#   ('그냥', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('사라져서', 'O'),
#   (' ', 'O'),
#   ('접은거자나ㅡㅡ', 'O')],
#  [('아', 'O'),
#   (' ', 'O'),
#   ('씁', 'O'),
#   (' ', 'O'),
#   ('쓰으으읍', 'O'),
#   (' ', 'O'),
#   ('너무나도', 'O'),
#   (' ', 'O'),
#   ('잘생긴', 'O'),
#   (' ', 'O'),
#   ('부모', 'CIVILIZATION'),
#   ('님을', 'O'),
#   (' ', 'O'),
#   ('보고', 'O'),
#   (' ', 'O'),
#   ('이성', 'O'),
#   (' ', 'O'),
#   ('붙드는', 'O'),
#   (' ', 'O'),
#   ('중', 'O')],
#  [('스트레이키즈', 'PERSON'),
#   (' ', 'O'),
#   ('승민', 'PERSON'),
#   (' ', 'O'),
#   ('아이엔', 'O'),
#   (' ', 'O'),
#   ('포카', 'ARTIFACT'),
#   (' ', 'O'),
#   ('양도합니다', 'O'),
#   (' ', 'O'),
#   ('!', 'O'),
#   (' ', 'O'),
#   ('준미포', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('sell Korea', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('address', 'O'),
#   (' ', 'O'),
#   ('Korean', 'LOCATION'),
#   (' ', 'O'),
#   ('account', 'O'),
#   (' ', 'O'),
#   ('스키즈', 'PERSON'),
#   (' ', 'O'),
#   ('방찬', 'PERSON'),
#   (' ', 'O'),
#   ('리노', 'PERSON'),
#   (' ', 'O'),
#   ('창빈', 'PERSON'),
#   (' ', 'O'),
#   ('현진', 'PERSON'),
#   (' ', 'O'),
#   ('한 필릭스', 'PERSON'),
#   (' ', 'O'),
#   ('용복', 'PERSON'),
#   (' ', 'O'),
#   ('승민', 'PERSON'),
#   (' ', 'O'),
#   ('아이엔', 'PERSON'),
#   (' ', 'O'),
#   ('영통포카', 'PERSON'),
#   (' ', 'O'),
#   ('이즈위', 'PERSON'),
#   (' ', 'O'),
#   ('중국영통', 'PERSON'),
#   (' ', 'O'),
#   ('섭케이', 'PERSON'),
#   (' ', 'O'),
#   ('메씨마', 'PERSON'),
#   (' ', 'O'),
#   ('알라딘', 'PERSON'),
#   (' ', 'O'),
#   ('클리오', 'PERSON'),
#   (' ', 'O'),
#   ('바알', 'PERSON'),
#   (' ', 'O'),
#   ('교복', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('네시픽', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('애플뮤직', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('유닛포카', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('아엠낫', 'PERSON'),
#   (' ', 'O'),
#   ('인생', 'O'),
#   (' ', 'O'),
#   ('고생', 'O'),
#   (' ', 'O'),
#   ('바람', 'O'),
#   (' ', 'O'),
#   ('레반터', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('문재인', 'PERSON'),
#   (' ', 'O'),
#   ('대통령', 'CIVILIZATION'),
#   ('과', 'O'),
#   (' ', 'O'),
#   ('참석자', 'CIVILIZATION'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('기립할', 'O'),
#   (' ', 'O'),
#   ('수', 'O'),
#   (' ', 'O'),
#   ('밖에', 'O'),
#   (' ', 'O'),
#   ('없었다!', 'O'),
#   (' ', 'O'),
#   ('스트레이키즈', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('K 타이거즈', 'PERSON'),
#   (' ', 'O'),
#   ('등이', 'O'),
#   (' ', 'O'),
#   ('두바이', 'CITY'),
#   (' ', 'O'),
#   ('엑스포장', 'LOCATION'),
#   ('에서', 'O'),
#   (' ', 'O'),
#   ('선보인', 'O'),
#   (' ', 'O'),
#   ('문화공연.', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('모든', 'O'),
#   (' ', 'O'),
#   ('왖판에서', 'O'),
#   (' ', 'O'),
#   ('이번엔', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('컴백이다', 'O'),
#   (' ', 'O'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('외치고', 'O'),
#   (' ', 'O'),
#   ('있어서.', 'O'),
#   (' ', 'O'),
#   ('이판들을', 'O'),
#   (' ', 'O'),
#   ('전부', 'O'),
#   (' ', 'O'),
#   ('한', 'O'),
#   (' ', 'O'),
#   ('탐라에서', 'O'),
#   (' ', 'O'),
#   ('보고있는게', 'O'),
#   (' ', 'O'),
#   ('좀', 'O'),
#   (' ', 'O'),
#   ('착잡하달까', 'O'),
#   (' ', 'O'),
#   ('어쨌든', 'O'),
#   (' ', 'O'),
#   ('하나', 'QUANTITY'),
#   ('가', 'O'),
#   (' ', 'O'),
#   ('컴백하면', 'O'),
#   (' ', 'O'),
#   ('하나', 'QUANTITY'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('희망을', 'O'),
#   (' ', 'O'),
#   ('거의', 'O'),
#   (' ', 'O'),
#   ('놓아야', 'O'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('거니까.', 'O'),
#   (' ', 'O'),
#   ('근데', 'O'),
#   (' ', 'O'),
#   ('그거', 'O'),
#   (' ', 'O'),
#   ('아시죠', 'O'),
#   (' ', 'O'),
#   ('2020년', 'DATE'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('2주마다', 'DATE'),
#   (' ', 'O'),
#   ('컴백돌린', 'O'),
#   (' ', 'O'),
#   ('회사가', 'O'),
#   (' ', 'O'),
#   ('와이지', 'ORGANIZATION'),
#   ('라는거', 'O')],
#  [('일상계', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('아마도.', 'O'),
#   (' ', 'O'),
#   ('얘들아', 'O'),
#   (' ', 'O'),
#   ('0명', 'QUANTITY'),
#   (' ', 'O'),
#   ('되도록혼자말함', 'O')],
#  [('ㅅㅊㅇ', 'O'),
#   (' ', 'O'),
#   ('탑로더', 'ARTIFACT'),
#   (' ', 'O'),
#   ('슬리브', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('양도', 'O'),
#   (' ', 'O'),
#   ('판매', 'O'),
#   (' ', 'O'),
#   ('포카', 'ARTIFACT'),
#   (' ', 'O'),
#   ('탑꾸', 'ARTIFACT'),
#   (' ', 'O'),
#   ('레진', 'ARTIFACT'),
#   (' ', 'O'),
#   ('탑꾸', 'ARTIFACT'),
#   (' ', 'O'),
#   ('레진', 'ARTIFACT'),
#   (' ', 'O'),
#   ('탑로더', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('스테이씨', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('데코', 'ORGANIZATION'),
#   ('덴', 'O'),
#   (' ', 'O'),
#   ('투명', 'O'),
#   (' ', 'O'),
#   ('슬', 'CIVILIZATION'),
#   ('리브', 'O'),
#   (' ', 'O'),
#   ('포토카드', 'O'),
#   (' ', 'O'),
#   ('콜렉트북', 'O'),
#   (' ', 'O'),
#   ('투바투', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('세븐틴', 'PERSON'),
#   (' ', 'O'),
#   ('블랙핑크', 'PERSON'),
#   (' ', 'O'),
#   ('우주소녀', 'PERSON'),
#   (' ', 'O'),
#   ('위너', 'PERSON'),
#   (' ', 'O'),
#   ('엔시티', 'PERSON'),
#   (' ', 'O'),
#   ('NCT', 'PERSON'),
#   (' ', 'O'),
#   ('더보이즈', 'PERSON'),
#   (' ', 'O'),
#   ('스트레이키즈', 'PERSON'),
#   (' ', 'O'),
#   ('스키즈', 'PERSON'),
#   (' ', 'O'),
#   ('데이식스', 'PERSON'),
#   (' ', 'O'),
#   ('에스파', 'PERSON'),
#   (' ', 'O'),
#   ('방탄', 'PERSON'),
#   (' ', 'O'),
#   ('몬스타엑스', 'PERSON'),
#   (' ', 'O'),
#   ('엔하이픈', 'PERSON'),
#   (' ', 'O'),
#   ('에이티즈', 'PERSON'),
#   (' ', 'O'),
#   ('커미션', 'O'),
#   (' ', 'O'),
#   ('주문제작', 'O')],
#  [('애들', 'O'),
#   (' ', 'O'),
#   ('영통팬싸', 'ARTIFACT'),
#   (' ', 'O'),
#   ('후기', 'O'),
#   (' ', 'O'),
#   ('보는데', 'O'),
#   (' ', 'O'),
#   ('ㅇㅇ', 'O'),
#   (' ', 'O'),
#   ('죽어줄게', 'O'),
#   (' ', 'O'),
#   ('기절하고싶음', 'O'),
#   (' ', 'O'),
#   ('이해찬', 'PERSON'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('부셨죠?', 'O'),
#   (' ', 'O'),
#   ('였나요?ㅇㅇ', 'O'),
#   (' ', 'O'),
#   ('맞말', 'O')],
#  [('프핑', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('뭐', 'O'),
#   (' ', 'O'),
#   ('하도', 'O'),
#   (' ', 'O'),
#   ('안오시니', 'O'),
#   (' ', 'O'),
#   ('올거', 'O'),
#   (' ', 'O'),
#   ('같지도', 'O'),
#   (' ', 'O'),
#   ('않지만', 'O'),
#   (' ', 'O'),
#   ('이번', 'O'),
#   (' ', 'O'),
#   ('일로', 'O'),
#   (' ', 'O'),
#   ('온다', 'O'),
#   (' ', 'O'),
#   ('해도', 'O'),
#   (' ', 'O'),
#   ('3년동안', 'DATE'),
#   (' ', 'O'),
#   ('그렇게', 'O'),
#   (' ', 'O'),
#   ('단', 'O'),
#   (' ', 'O'),
#   ('한번', 'QUANTITY'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('안', 'O'),
#   (' ', 'O'),
#   ('오던걸', 'O'),
#   (' ', 'O'),
#   ('1', 'QUANTITY'),
#   ('.', 'O'),
#   (' ', 'O'),
#   ('와이지', 'PERSON'),
#   (' ', 'O'),
#   ('갔을', 'O'),
#   (' ', 'O'),
#   ('때', 'O'),
#   (' ', 'O'),
#   ('2', 'QUANTITY'),
#   ('.', 'O'),
#   (' ', 'O'),
#   ('팀활동', 'O'),
#   (' ', 'O'),
#   ('하기', 'O'),
#   (' ', 'O'),
#   ('싫어서', 'O'),
#   (' ', 'O'),
#   ('빠질', 'O'),
#   (' ', 'O'),
#   ('때만', 'O'),
#   (' ', 'O'),
#   ('와서', 'O'),
#   (' ', 'O'),
#   ('글', 'O'),
#   (' ', 'O'),
#   ('남기는', 'O'),
#   (' ', 'O'),
#   ('것도', 'O'),
#   (' ', 'O'),
#   ('ㅈㄴ', 'O'),
#   (' ', 'O'),
#   ('웃기긴', 'O'),
#   (' ', 'O'),
#   ('함', 'O')],
#  [('방과후설렘', 'O'),
#   (' ', 'O'),
#   ('특별판에', 'O'),
#   (' ', 'O'),
#   ('최사랑', 'PERSON'),
#   (' ', 'O'),
#   ('없으면..', 'O'),
#   (' ', 'O'),
#   ('죽어줄게ㅇㅇ', 'O')],
#  [('나진짜태용이좋은가봐', 'O'),
#   (' ', 'O'),
#   ('이거얼마전까지만해도', 'O'),
#   (' ', 'O'),
#   ('웹소와', 'TERM'),
#   ('나', 'TERM'),
#   ('의일상', 'TERM'),
#   ('과약간의', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   ('과', 'O'),
#   (' ', 'O'),
#   ('기타', 'ARTIFACT'),
#   ('등등이짬뽕된', 'O'),
#   (' ', 'O'),
#   ('허공외침혼잣말계정이었는데', 'O'),
#   (' ', 'O'),
#   ('지금은..더보기', 'O')],
#  [('방과후설렘', 'O'), (' ', 'O'), ('엡글곡', 'O'), (' ', 'O'), ('많이하넴', 'O')],
#  [('내', 'O'),
#   (' ', 'O'),
#   ('탐라', 'ARTIFACT'),
#   (' ', 'O'),
#   ('지금', 'O'),
#   (' ', 'O'),
#   ('눈물과', 'O'),
#   (' ', 'O'),
#   ('꽃말로', 'O'),
#   (' ', 'O'),
#   ('대동단결됐음', 'O')],
#  [('방과후', 'O'),
#   (' ', 'O'),
#   ('설렘', 'O'),
#   (' ', 'O'),
#   ('역대급', 'O'),
#   (' ', 'O'),
#   ('퀄리티의', 'O'),
#   (' ', 'O'),
#   ('랩', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('무대', 'O'),
#   (' ', 'O'),
#   ('탄생.!', 'O'),
#   (' ', 'O'),
#   ('BTS MIC Drop', 'EVENT'),
#   (' ', 'O'),
#   ('vs', 'O'),
#   (' ', 'O'),
#   ('Doja Cat Boss Rich', 'PERSON'),
#   (' ', 'O'),
#   ('배틀', 'O'),
#   (' ', 'O'),
#   ('대..', 'O'),
#   (' ', 'O'),
#   ('URL', 'O'),
#   (' ', 'O'),
#   ('via', 'O'),
#   (' ', 'O'),
#   ('전소연', 'PERSON'),
#   (' ', 'O'),
#   ('선생님', 'OCCUPATION'),
#   (' ', 'O'),
#   ('최고!', 'O'),
#   (' ', 'O'),
#   ('ㅠㅠ', 'O'),
#   (' ', 'O'),
#   ('짱', 'O')],
#  [('너란', 'O'),
#   (' ', 'O'),
#   ('감정에', 'O'),
#   (' ', 'O'),
#   ('날', 'O'),
#   (' ', 'O'),
#   ('맡긴', 'O'),
#   (' ', 'O'),
#   ('채', 'O'),
#   (' ', 'O'),
#   ('난기류', 'O'),
#   (' ', 'O'),
#   ('Turbulence', 'O')],
#  [('이거', 'O'),
#   (' ', 'O'),
#   ('뭔', 'O'),
#   (' ', 'O'),
#   ('크로킨', 'PERSON'),
#   ('지', 'O'),
#   (' ', 'O'),
#   ('알면', 'O'),
#   (' ', 'O'),
#   ('당신은', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('고인물입니다', 'O')],
#  [('..악뮤', 'O'),
#   (' ', 'O'),
#   ('항해', 'O'),
#   (' ', 'O'),
#   ('앨범', 'O'),
#   (' ', 'O'),
#   ('듣고있자니', 'O'),
#   (' ', 'O'),
#   ('해군', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('제복', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('입은', 'O'),
#   (' ', 'O'),
#   ('멤버', 'CIVILIZATION'),
#   ('들보고', 'O'),
#   (' ', 'O'),
#   ('싶어..', 'O')],
#  [('내', 'O'),
#   (' ', 'O'),
#   ('탄생화는', 'O'),
#   (' ', 'O'),
#   ('장미', 'PLANT'),
#   ('라', 'O'),
#   (' ', 'O'),
#   ('꽃말이', 'O'),
#   (' ', 'O'),
#   ('사랑,', 'O'),
#   (' ', 'O'),
#   ('존경인데', 'O'),
#   (' ', 'O'),
#   ('이래서', 'O'),
#   (' ', 'O'),
#   ('내가', 'O'),
#   (' ', 'O'),
#   ('숙주', 'O'),
#   (' ', 'O'),
#   ('덕질을', 'O'),
#   (' ', 'O'),
#   ('하나', 'O'),
#   (' ', 'O'),
#   ('싶고', 'O'),
#   (' ', 'O'),
#   ('막이래', 'O')],
#  [('p.s.', 'O'),
#   (' ', 'O'),
#   ('슬슬', 'O'),
#   (' ', 'O'),
#   ('졸려서', 'O'),
#   (' ', 'O'),
#   ('말이', 'O'),
#   (' ', 'O'),
# ...
#   (' ', 'O'),
#   ('양도', 'O'),
#   (' ', 'O'),
#   ('판매', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('근데', 'O'),
#   (' ', 'O'),
#   ('딱히', 'O'),
#   (' ', 'O'),
#   ('인간들이랑', 'O'),
#   (' ', 'O'),
#   ('크게', 'O'),
#   (' ', 'O'),
#   ('소통할', 'O'),
#   (' ', 'O'),
#   ('생각은', 'O'),
#   (' ', 'O'),
#   ('버린지', 'O'),
#   (' ', 'O'),
#   ('오래라서..', 'O'),
#   (' ', 'O'),
#   ('그', 'O'),
#   (' ', 'O'),
#   ('영역', 'O'),
#   (' ', 'O'),
#   ('안으로', 'O'),
#   (' ', 'O'),
#   ('허락', 'O'),
#   (' ', 'O'),
#   ('없이', 'O'),
#   (' ', 'O'),
#   ('들어오는', 'O'),
#   (' ', 'O'),
#   ('해적선', 'ARTIFACT'),
#   ('이랑', 'O'),
#   (' ', 'O'),
#   ('해군선', 'ARTIFACT'),
#   (' ', 'O'),
#   ('가리지', 'O'),
#   (' ', 'O'),
#   ('않고', 'O'),
#   (' ', 'O'),
#   ('죽음의', 'O'),
#   (' ', 'O'),
#   ('바다로', 'O'),
#   (' ', 'O'),
#   ('만들어버리는', 'O'),
#   (' ', 'O'),
#   ('그런', 'O'),
#   (' ', 'O'),
#   ('해적', 'CIVILIZATION'),
#   ('이죠..', 'O'),
#   (' ', 'O'),
#   ('주된', 'O'),
#   (' ', 'O'),
#   ('전투', 'O'),
#   (' ', 'O'),
#   ('방식은', 'O'),
#   (' ', 'O'),
#   ('배', 'ARTIFACT'),
#   (' ', 'O'),
#   ('몰고', 'O'),
#   (' ', 'O'),
#   ('가서', 'O'),
#   (' ', 'O'),
#   ('텅', 'O'),
#   (' ', 'O'),
#   ('빈', 'O'),
#   (' ', 'O'),
#   ('배', 'ARTIFACT'),
#   (' ', 'O'),
#   ('보고', 'O'),
#   (' ', 'O'),
#   ('사람들이', 'O'),
#   (' ', 'O'),
#   ('어라?', 'O'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('사이에', 'O'),
#   (' ', 'O'),
#   ('배', 'ARTIFACT'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('바닥을', 'O'),
#   (' ', 'O'),
#   ('뚫어버립니다', 'O')],
#  [('스트레이키즈 스키즈', 'ARTIFACT'),
#   (' ', 'O'),
#   ('포토카드', 'O'),
#   (' ', 'O'),
#   ('양도', 'O'),
#   (' ', 'O'),
#   ('급처라', 'O'),
#   (' ', 'O'),
#   ('즉입만', 'O'),
#   (' ', 'O'),
#   ('받아요', 'O'),
#   (' ', 'O'),
#   ('1.8 이상', 'QUANTITY'),
#   (' ', 'O'),
#   ('구매시', 'O'),
#   (' ', 'O'),
#   ('배송비', 'O'),
#   (' ', 'O'),
#   ('X', 'O'),
#   (' ', 'O'),
#   ('편하게', 'O'),
#   (' ', 'O'),
#   ('DM', 'O'),
#   (' ', 'O'),
#   ('주세요', 'O'),
#   (' ', 'O'),
#   ('방찬', 'PERSON'),
#   (' ', 'O'),
#   ('서창빈', 'PERSON'),
#   (' ', 'O'),
#   ('한지성', 'PERSON'),
#   (' ', 'O'),
#   ('필릭스', 'PERSON'),
#   (' ', 'O'),
#   ('이용복', 'PERSON'),
#   (' ', 'O'),
#   ('김승민', 'PERSON'),
#   (' ', 'O'),
#   ('아이엔', 'PERSON'),
#   (' ', 'O'),
#   ('양정인', 'PERSON'),
#   (' ', 'O'),
#   ('네시픽', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('2차', 'QUANTITY'),
#   (' ', 'O'),
#   ('6차', 'QUANTITY'),
#   (' ', 'O'),
#   ('노이지', 'PERSON'),
#   (' ', 'O'),
#   ('메씨마', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('스카스', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('폴라 FC', 'ORGANIZATION'),
#   ('특전', 'O'),
#   (' ', 'O'),
#   ('유닛', 'O'),
#   (' ', 'O'),
#   ('호주즈', 'PERSON'),
#   (' ', 'O'),
#   ('사웨', 'PERSON'),
#   (' ', 'O'),
#   ('크리스마스', 'DATE'),
#   ('이블', 'O'),
#   (' ', 'O'),
#   ('럭', 'ARTIFACT'),
#   ('드', 'O'),
#   (' ', 'O'),
#   ('럭키드로', 'ARTIFACT'),
#   ('우', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('에스파 윈터', 'EVENT'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('최고의', 'O'),
#   (' ', 'O'),
#   ('여자', 'O'),
#   (' ', 'O'),
#   ('에스파 윈터', 'EVENT')],
#  [('케이팝스토어', 'TERM'),
#   (' ', 'O'),
#   ('코로나', 'TERM'),
#   ('로', 'O'),
#   (' ', 'O'),
#   ('인한', 'O'),
#   (' ', 'O'),
#   ('불참', 'O'),
#   (' ', 'O'),
#   ('개인', 'O'),
#   (' ', 'O'),
#   ('사유로', 'O'),
#   (' ', 'O'),
#   ('해버리는', 'O'),
#   (' ', 'O'),
#   ('거', 'O'),
#   (' ', 'O'),
#   ('병신같고', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('개짜증나', 'O'),
#   (' ', 'O'),
#   ('못', 'O'),
#   (' ', 'O'),
#   ('가면', 'O'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('소비자원', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('찌를거임ㅗ', 'O'),
#   (' ', 'O'),
#   ('ㅗ', 'O')],
#  [('에스파 윈터', 'EVENT'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('우리는', 'O'),
#   (' ', 'O'),
#   ('항상', 'O'),
#   (' ', 'O'),
#   ('당신을', 'O'),
#   (' ', 'O'),
#   ('자랑스럽게', 'O'),
#   (' ', 'O'),
#   ('생각합니다', 'O'),
#   (' ', 'O'),
#   ('에스파 윈터', 'ARTIFACT')],
#  [('에스파 윈터', 'EVENT'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('우리는', 'O'),
#   (' ', 'O'),
#   ('너를', 'O'),
#   (' ', 'O'),
#   ('너무', 'O'),
#   (' ', 'O'),
#   ('사랑해', 'O'),
#   (' ', 'O'),
#   ('에스파 윈터', 'EVENT')],
#  [('아이브 포카', 'PERSON'),
#   (' ', 'O'),
#   ('양도', 'O'),
#   (' ', 'O'),
#   ('편하게', 'O'),
#   (' ', 'O'),
#   ('연락', 'O'),
#   (' ', 'O'),
#   ('주세요', 'O'),
#   (' ', 'O'),
#   ('가을', 'DATE'),
#   (' ', 'O'),
#   ('유진', 'PERSON'),
#   (' ', 'O'),
#   ('레이', 'PERSON'),
#   (' ', 'O'),
#   ('이서 일레븐', 'ARTIFACT'),
#   (' ', 'O'),
#   ('앨포', 'O'),
#   (' ', 'O'),
#   ('앨범', 'O'),
#   ('포카', 'ARTIFACT'),
#   (' ', 'O'),
#   ('사웨', 'ARTIFACT'),
#   (' ', 'O'),
#   ('사운드웨이브', 'ARTIFACT'),
#   (' ', 'O'),
#   ('럭드', 'ARTIFACT'),
#   (' ', 'O'),
#   ('럭키드로우', 'ARTIFACT'),
#   (' ', 'O'),
#   ('포카', 'ARTIFACT'),
#   (' ', 'O'),
#   ('포토카드', 'O'),
#   (' ', 'O'),
#   ('양도', 'O'),
#   (' ', 'O'),
#   ('교환', 'O'),
#   (' ', 'O'),
#   ('판매', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('그리고', 'O'),
#   (' ', 'O'),
#   ('떨어지는', 'O'),
#   (' ', 'O'),
#   ('사람들은', 'O'),
#   (' ', 'O'),
#   ('물', 'O'),
#   (' ', 'O'),
#   ('속에', 'O'),
#   (' ', 'O'),
#   ('잘', 'O'),
#   (' ', 'O'),
#   ('정리해두고..', 'O'),
#   (' ', 'O'),
#   ('선박', 'ARTIFACT'),
#   (' ', 'O'),
#   ('내부의', 'O'),
#   (' ', 'O'),
#   ('식량이나', 'O'),
#   (' ', 'O'),
#   ('술', 'CIVILIZATION'),
#   ('이나', 'O'),
#   (' ', 'O'),
#   ('그런', 'O'),
#   (' ', 'O'),
#   ('건', 'O'),
#   (' ', 'O'),
#   ('잘', 'O'),
#   (' ', 'O'),
#   ('추려서', 'O'),
#   (' ', 'O'),
#   ('자기네들', 'O'),
#   (' ', 'O'),
#   ('배', 'ARTIFACT'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('올린', 'O'),
#   (' ', 'O'),
#   ('뒤', 'O'),
#   (' ', 'O'),
#   ('돌아가는..', 'O'),
#   (' ', 'O'),
#   ('그런', 'O'),
#   (' ', 'O'),
#   ('걸', 'O'),
#   (' ', 'O'),
#   ('생각했어요.', 'O'),
#   (' ', 'O'),
#   ('대신', 'O'),
#   (' ', 'O'),
#   ('대화하고자', 'O'),
#   (' ', 'O'),
#   ('한다면', 'O'),
#   (' ', 'O'),
#   ('의외로', 'O'),
#   (' ', 'O'),
#   ('말이', 'O'),
#   (' ', 'O'),
#   ('통하는..', 'O'),
#   (' ', 'O'),
#   ('그런', 'O'),
#   (' ', 'O'),
#   ('npc', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('같은', 'O'),
#   (' ', 'O'),
#   ('타입일', 'O'),
#   (' ', 'O'),
#   ('거', 'O'),
#   (' ', 'O'),
#   ('같네요', 'O')],
#  [('에스파 윈터', 'EVENT'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('당신은', 'O'),
#   (' ', 'O'),
#   ('사랑을', 'O'),
#   (' ', 'O'),
#   ('받고', 'O'),
#   (' ', 'O'),
#   ('있습니다', 'O'),
#   (' ', 'O'),
#   ('에스파 윈터', 'ARTIFACT')],
#  [('왐마야근데', 'O'),
#   (' ', 'O'),
#   ('와이지', 'PERSON'),
#   ('왜갑자기이렇게', 'O'),
#   (' ', 'O'),
#   ('애들을', 'O'),
#   ('호로로', 'TERM'),
#   ('로로록터트린대요?', 'O'),
#   (' ', 'O'),
#   ('위너', 'PERSON'),
#   ('계정에서도', 'O'),
#   (' ', 'O'),
#   ('컴백얘기음청해대든데..', 'O'),
#   (' ', 'O'),
#   ('.', 'O'),
#   (' ', 'O'),
#   ('.', 'O'),
#   (' ', 'O'),
#   ('.', 'O')],
#  [('1월19일', 'DATE'),
#   (' ', 'O'),
#   ('응모완료', 'O'),
#   (' ', 'O'),
#   ('진심으로', 'O'),
#   (' ', 'O'),
#   ('가고', 'O'),
#   (' ', 'O'),
#   ('싶어요ㅠㅠ', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('220109', 'QUANTITY'),
#   (' ', 'O'),
#   ('시그니처', 'O'),
#   (' ', 'O'),
#   ('Boyfriend', 'PERSON'),
#   (' ', 'O'),
#   ('단체', 'O'),
#   (' ', 'O'),
#   ('직캠', 'O'),
#   (' ', 'O'),
#   ('4K', 'QUANTITY'),
#   (' ', 'O'),
#   ('cignature', 'O'),
#   (' ', 'O'),
#   ('fancam', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('설강화', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('지수', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('정해인', 'PERSON'),
#   (' ', 'O'),
#   ('인스타그램', 'TERM'),
#   (' ', 'O'),
#   ('사진', 'O'),
#   (' ', 'O'),
#   ('공유', 'O'),
#   (' ', 'O'),
#   ('출처', 'O')],
#  [('너.', 'O'),
#   (' ', 'O'),
#   ('이제', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('찢을', 'O'),
#   (' ', 'O'),
#   ('일만', 'O'),
#   (' ', 'O'),
#   ('남았어', 'O'),
#   (' ', 'O'),
#   ('정신이혼미하네', 'O')],
#  [('220109', 'QUANTITY'),
#   (' ', 'O'),
#   ('시그니처', 'O'),
#   (' ', 'O'),
#   ('cignatre', 'O'),
#   (' ', 'O'),
#   ('채솔', 'PERSON'),
#   (' ', 'O'),
#   ('Boyfriend', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('전..', 'O'),
#   (' ', 'O'),
#   ('롭톰', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('호크', 'PERSON'),
#   ('마요..', 'O'),
#   (' ', 'O'),
#   ('지독하게', 'O'),
#   (' ', 'O'),
#   ('사랑한다', 'O'),
#   (' ', 'O'),
#   ('호크마', 'PERSON')],
#  [('트와이스', 'PERSON'),
#   (' ', 'O'),
#   ('TWICE', 'PERSON'),
#   (' ', 'O'),
#   ('Alcohol', 'O'),
#   (' ', 'O'),
#   ('Free', 'O'),
#   (' ', 'O'),
#   ('알콜', 'MATERIAL'),
#   (' ', 'O'),
#   ('프리', 'O'),
#   (' ', 'O'),
#   ('교차편집', 'O'),
#   (' ', 'O'),
#   ('Stage', 'O'),
#   (' ', 'O'),
#   ('Mix', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('트리거 더 피버', 'ARTIFACT'),
#   (' ', 'O'),
#   ('들으니깐', 'O'),
#   (' ', 'O'),
#   ('죽어있던', 'O'),
#   (' ', 'O'),
#   ('케이팝', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('심장', 'TERM'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('다시', 'O'),
#   (' ', 'O'),
#   ('살아남', 'O')],
#  [('지웅채란', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('스트레이키즈', 'PERSON'),
#   (' ', 'O'),
#   ('승민', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('응원합니다!', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('바이미나', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('설강화', 'O'),
#   (' ', 'O'),
#   ('블랙핑크', 'PERSON'),
#   (' ', 'O'),
#   ('지수', 'O'),
#   (' ', 'O'),
#   ('메리제인', 'PERSON'),
#   (' ', 'O'),
#   ('구두', 'O'),
#   (' ', 'O'),
#   ('패션', 'O'),
#   (' ', 'O'),
#   ('출처', 'O')],
#  [('중국', 'COUNTRY'),
#   ('에서..', 'O'),
#   (' ', 'O'),
#   ('첨', 'O'),
#   (' ', 'O'),
#   ('콜라보', 'O'),
#   (' ', 'O'),
#   ('카페', 'O'),
#   (' ', 'O'),
#   ('롭톰', 'O'),
#   (' ', 'O'),
#   ('열었을', 'O'),
#   (' ', 'O'),
#   ('때', 'O'),
#   (' ', 'O'),
#   ('가서', 'O'),
#   (' ', 'O'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('악물고', 'O'),
#   (' ', 'O'),
#   ('굳즈', 'O'),
#   (' ', 'O'),
#   ('사오', 'O'),
#   (' ', 'O'),
#   ('ㄴ내가', 'O'),
#   (' ', 'O'),
#   ('승리자', 'CIVILIZATION'),
#   ('다', 'O')],
#  [('알고리즘에', 'O'),
#   (' ', 'O'),
#   ('악뮤', 'ARTIFACT'),
#   (' ', 'O'),
#   ('노래가', 'O'),
#   (' ', 'O'),
#   ('떠서', 'O'),
#   (' ', 'O'),
#   ('요즘', 'O'),
#   (' ', 'O'),
#   ('악뮤', 'ARTIFACT'),
#   (' ', 'O'),
#   ('고래', 'ARTIFACT'),
#   (' ', 'O'),
#   ('듣고잇어요', 'O')],
#  [('9개당', 'QUANTITY'),
#   (' ', 'O'),
#   ('다래끼하니까', 'O'),
#   (' ', 'O'),
#   ('생각나는데', 'O'),
#   (' ', 'O'),
#   ('중1', 'QUANTITY'),
#   ('때', 'O'),
#   (' ', 'O'),
#   ('트루디메이크업한다고', 'O'),
#   (' ', 'O'),
#   ('눈', 'ANIMAL'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('아이브로우', 'O'),
#   (' ', 'O'),
#   ('개처바르고', 'O'),
#   (' ', 'O'),
#   ('그다음날', 'DATE'),
#   ('인가', 'O'),
#   (' ', 'O'),
#   ('다래', 'ANIMAL'),
#   ('끼', 'O'),
#   (' ', 'O'),
#   ('걸림', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('만화', 'O'),
#   (' ', 'O'),
#   ('쪽은', 'O'),
#   (' ', 'O'),
#   ('딱히', 'O'),
#   (' ', 'O'),
#   ('판', 'O'),
#   (' ', 'O'),
#   ('게', 'O'),
#   (' ', 'O'),
#   ('없구..', 'O'),
#   (' ', 'O'),
#   ('이제', 'O'),
#   (' ', 'O'),
#   ('영상', 'O'),
#   (' ', 'O'),
#   ('쪽으로', 'O'),
#   (' ', 'O'),
#   ('넘어가야..', 'O'),
#   (' ', 'O'),
#   ('최애들이', 'O'),
#   (' ', 'O'),
#   ('숨쉬네요', 'O'),
#   (' ', 'O'),
#   ('스네이프', 'PERSON'),
#   (' ', 'O'),
#   ('에릭 버키 하치너', 'PERSON'),
#   (' ', 'O'),
#   ('등등등', 'O')],
#  [('IVE', 'EVENT'),
#   (' ', 'O'),
#   ('아이브', 'PERSON'),
#   (' ', 'O'),
#   ('Take', 'O'),
#   (' ', 'O'),
#   ('it', 'O'),
#   (' ', 'O'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('That', 'O'),
#   (' ', 'O'),
#   ('s my Girl K POP CLICK콘서트', 'EVENT'),
#   (' ', 'O'),
#   ('011522', 'QUANTITY'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('로판', 'ARTIFACT'), (' ', 'O'), ('아이데오도', 'O'), (' ', 'O'), ('주세요', 'O')],
#  [('로판', 'PERSON'),
#   ('..', 'O'),
#   (' ', 'O'),
#   ('아이브', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('점쟁이라네요', 'O'),
#   (' ', 'O'),
#   ('근데', 'O'),
#   (' ', 'O'),
#   ('이제', 'O'),
#   (' ', 'O'),
#   ('이계인', 'CIVILIZATION'),
#   ('인.', 'O'),
#   (' ', 'O'),
#   ('?', 'O')],
#  [('와', 'O'),
#   (' ', 'O'),
#   ('ㅆㅂ', 'O'),
#   (' ', 'O'),
#   ('이런', 'O'),
#   (' ', 'O'),
#   ('사진', 'O'),
#   (' ', 'O'),
#   ('존재하면', 'O'),
#   (' ', 'O'),
#   ('안될', 'O'),
#   (' ', 'O'),
#   ('것같은데.?', 'O'),
#   (' ', 'O'),
#   ('와이지', 'ARTIFACT'),
#   (' ', 'O'),
#   ('진짜', 'O'),
#   (' ', 'O'),
#   ('미친놈이었네', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('스트레이키즈', 'ORGANIZATION'),
#   (' ', 'O'),
#   ('양도', 'O'),
#   (' ', 'O'),
#   ('합니다', 'O'),
#   (' ', 'O'),
#   ('거래합니다', 'O'),
#   (' ', 'O'),
#   ('SELL', 'O'),
#   (' ', 'O'),
#   ('분철', 'PERSON'),
#   (' ', 'O'),
#   ('NOEASY', 'O'),
#   (' ', 'O'),
#   ('STRAYKIDS', 'O'),
#   (' ', 'O'),
#   ('방찬', 'PERSON'),
#   (' ', 'O'),
#   ('리노', 'PERSON'),
#   (' ', 'O'),
#   ('창빈', 'PERSON'),
#   (' ', 'O'),
#   ('현진', 'PERSON'),
#   (' ', 'O'),
#   ('한', 'PERSON'),
#   (' ', 'O'),
#   ('지성', 'PERSON'),
#   (' ', 'O'),
#   ('필릭스', 'PERSON'),
#   (' ', 'O'),
#   ('승민', 'PERSON'),
#   (' ', 'O'),
#   ('아이엔', 'PERSON'),
#   (' ', 'O'),
#   ('일반반', 'O'),
#   (' ', 'O'),
#   ('한정반', 'O'),
#   (' ', 'O'),
#   ('bangchan', 'O'),
#   (' ', 'O'),
#   ('Leeknow', 'O'),
#   (' ', 'O'),
#   ('changbin', 'O'),
#   (' ', 'O'),
#   ('hyunjin', 'O'),
#   (' ', 'O'),
#   ('han', 'O'),
#   (' ', 'O'),
#   ('felix', 'O'),
#   (' ', 'O'),
#   ('seungmin', 'O'),
#   (' ', 'O'),
#   ('IN', 'O'),
#   (' ', 'O'),
#   ('특전', 'O'),
#   (' ', 'O'),
#   ('신나라', 'PERSON'),
#   (' ', 'O'),
#   ('사웨', 'PERSON'),
#   (' ', 'O'),
#   ('섭케이', 'PERSON'),
#   (' ', 'O'),
#   ('고생', 'O'),
#   (' ', 'O'),
#   ('인생', 'O'),
#   (' ', 'O'),
#   ('노이지', 'O'),
#   (' ', 'O'),
#   ('급처', 'O'),
#   (' ', 'O'),
#   ('크리스마스', 'DATE'),
#   ('이블', 'O'),
#   (' ', 'O'),
#   ('팬미팅', 'O'),
#   (' ', 'O'),
#   ('skz', 'O'),
#   (' ', 'O'),
#   ('pc', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('독립하면', 'O'),
#   (' ', 'O'),
#   ('주말마다', 'DATE'),
#   (' ', 'O'),
#   ('케이팝댄스', 'STUDY_FIELD'),
#   (' ', 'O'),
#   ('취미반', 'O'),
#   (' ', 'O'),
#   ('나가서', 'O'),
#   (' ', 'O'),
#   ('뒤지게', 'O'),
#   (' ', 'O'),
#   ('춤추는', 'O'),
#   (' ', 'O'),
#   ('대가리', 'ANIMAL'),
#   (' ', 'O'),
#   ('꽃밭으로', 'O'),
#   (' ', 'O'),
#   ('살테야', 'O')],
#  [('스트레이키즈', 'PERSON'),
#   (' ', 'O'),
#   ('세븐틴', 'PERSON'),
#   (' ', 'O'),
#   ('포스터', 'O'),
#   (' ', 'O'),
#   ('각각', 'O'),
#   (' ', 'O'),
#   ('반택비', 'O'),
#   (' ', 'O'),
#   ('0.2만', 'QUANTITY'),
#   (' ', 'O'),
#   ('받고', 'O'),
#   (' ', 'O'),
#   ('무나해요', 'O'),
#   (' ', 'O'),
#   ('지관통이', 'O'),
#   (' ', 'O'),
#   ('처음부터', 'O'),
#   (' ', 'O'),
#   ('없었으며', 'O'),
#   (' ', 'O'),
#   ('접혀있는', 'O'),
#   (' ', 'O'),
#   ('점', 'O'),
#   (' ', 'O'),
#   ('유의해', 'O'),
#   (' ', 'O'),
#   ('주세요!', 'O'),
#   (' ', 'O'),
#   ('준등기', 'O'),
#   (' ', 'O'),
#   ('200', 'QUANTITY'),
#   (' ', 'O'),
#   ('English Korea', 'LOCATION'),
#   (' ', 'O'),
#   ('adress', 'O'),
#   (' ', 'O'),
#   ('세븐틴', 'PERSON'),
#   (' ', 'O'),
#   ('스트레이키즈', 'PERSON'),
#   (' ', 'O'),
#   ('포카', 'O'),
#   (' ', 'O'),
#   ('포스터', 'O'),
#   (' ', 'O'),
#   ('양도', 'O'),
#   (' ', 'O'),
#   ('분철', 'O'),
#   (' ', 'O'),
#   ('나눔', 'O'),
#   (' ', 'O'),
#   ('교환', 'O'),
#   (' ', 'O'),
#   ('앨범', 'O'),
#   (' ', 'O'),
#   ('URL', 'O')],
#  [('ㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('햄버거', 'CIVILIZATION'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('눈', 'ANIMAL'),
#   (' ', 'O'),
#   ('앞에서', 'O'),
#   (' ', 'O'),
#   ('흔들고..', 'O'),
#   (' ', 'O'),
#   ('스테이크', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('하우스', 'O'),
#   (' ', 'O'),
#   ('가자고', 'O'),
#   (' ', 'O'),
#   ('꼬시고..', 'O'),
#   (' ', 'O'),
#   ('단', 'O'),
#   (' ', 'O'),
#   ('거', 'O'),
#   (' ', 'O'),
#   ('들고', 'O'),
#   (' ', 'O'),
#   ('와서', 'O'),
#   (' ', 'O'),
#   ('애들에게', 'O'),
#   (' ', 'O'),
#   ('배포하는', 'O'),
#   (' ', 'O'),
#   ('중이고..', 'O'),
#   (' ', 'O'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('중에서', 'O'),
#   (' ', 'O'),
#   ('햄버거', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('빼고는', 'O'),
#   (' ', 'O'),
#   ('전부', 'O'),
#   (' ', 'O'),
#   ('해봤으니', 'O'),
#   (' ', 'O'),
#   ('캐붕도', 'O'),
#   (' ', 'O'),
#   ('아니네요', 'O'),
#   (' ', 'O'),
#   ('ㅋㅋ', 'O'),
#   (' ', 'O'),
#   ('식스', 'PERSON'),
#   ('는', 'O'),
#   (' ', 'O'),
#   ('햄버거', 'CIVILIZATION'),
#   (' ', 'O'),
#   ('좋아하나요?', 'O')],
#  [('앨범', 'O'),
#   (' ', 'O'),
#   ('포카', 'ARTIFACT'),
#   (' ', 'O'),
#   ('포스터', 'O'),
#   (' ', 'O'),
#   ('양도', 'O'),
#   (' ', 'O'),
#   ('분철', 'O'),
#   (' ', 'O'),
#   ('교환', 'O'),
#   (' ', 'O'),
#   ('나눔', 'O'),
#   (' ', 'O'),
#   ('스트레이키즈', 'PERSON'),
#   (' ', 'O'),
#   ('스키즈', 'PERSON'),
#   (' ', 'O'),
#   ('방찬', 'PERSON'),
#   (' ', 'O'),
#   ('리노', 'PERSON'),
#   (' ', 'O'),
#   ('창빈', 'PERSON'),
#   (' ', 'O'),
#   ('현진', 'PERSON'),
#   (' ', 'O'),
#   ('한 필릭스', 'PERSON'),
#   (' ', 'O'),
#   ('승민', 'PERSON'),
#   (' ', 'O'),
#   ('아이엔 노이지', 'PERSON'),
#   (' ', 'O'),
#   ('stra', 'PERSON'),
#   ('ykids', 'O'),
#   (' ', 'O'),
#   ('세븐틴', 'PERSON'),
#   (' ', 'O'),
#   ('에스쿱스', 'PERSON'),
#   (' ', 'O'),
#   ('정한', 'PERSON'),
#   (' ', 'O'),
#   ('조슈아', 'PERSON'),
#   (' ', 'O'),
#   ('준', 'PERSON'),
#   (' ', 'O'),
#   ('호시', 'PERSON'),
#   (' ', 'O'),
#   ('원우', 'PERSON'),
#   (' ', 'O'),
#   ('우지', 'PERSON'),
#   (' ', 'O'),
#   ('디에잇', 'PERSON'),
#   (' ', 'O'),
#   ('민규', 'PERSON'),
#   (' ', 'O'),
#   ('도겸', 'PERSON'),
#   (' ', 'O'),
#   ('승관', 'PERSON'),
#   (' ', 'O'),
#   ('버논 디노', 'PERSON'),
#   (' ', 'O'),
#   ('굿초이스', 'PERSON'),
#   (' ', 'O'),
#   ('seventeen', 'O'),
#   (' ', 'O'),
#   ('무나', 'PERSON')],
#  [('재현', 'PERSON'),
#   ('이', 'O'),
#   (' ', 'O'),
#   ('얼굴', 'ANIMAL'),
#   (' ', 'O'),
#   ('많이', 'O'),
#   (' ', 'O'),
#   ('봐서', 'O'),
#   (' ', 'O'),
#   ('어제오늘', 'DATE'),
#   (' ', 'O'),
#   ('기분', 'O'),
#   (' ', 'O'),
#   ('좋음', 'O'),
#   (' ', 'O'),
#   ('ㅎㅎ', 'O'),
#   (' ', 'O'),
#   ('그런김에', 'O'),
#   (' ', 'O'),
#   ('이번주', 'DATE'),
#   (' ', 'O'),
#   ('자컨줘', 'O'),
#   (' ', 'O'),
#   ('스엠아', 'PERSON')],
#  [('6년전', 'DATE'),
#   (' ', 'O'),
#   ('오늘', 'DATE'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('미나', 'PERSON'),
#   (' ', 'O'),
#   ('160119', 'QUANTITY'),
#   (' ', 'O'),
#   ('열린음악회', 'ARTIFACT'),
#   (' ', 'O'),
#   ('URL', 'O')]]

# %%
review_results=[]
for i in tqdm_notebook(body_twitter):
  result = review(i)
  review_results.append(result)
review_results
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/200 [00:00<?, ?it/s]
# [1.79,
#  1.54,
#  4.74,
#  1.38,
#  3.94,
#  1.65,
#  2.03,
#  4.64,
#  4.14,
#  4.52,
#  2.81,
#  3.99,
#  4.51,
#  4.81,
#  4.84,
#  3.22,
#  4.78,
#  1.98,
#  3.18,
#  4.12,
#  4.79,
#  4.13,
#  4.89,
#  3.18,
#  4.07,
#  4.69,
#  4.15,
#  3.18,
#  4.68,
#  3.88,
#  4.25,
#  4.8,
#  4.32,
#  4.52,
#  3.85,
#  2.08,
#  3.31,
#  3.18,
#  4.43,
#  4.63,
#  3.86,
#  3.72,
#  1.36,
#  3.18,
#  1.35,
#  4.73,
#  4.9,
#  3.18,
#  3.18,
#  2.75,
#  4.78,
#  1.61,
#  3.18,
#  3.43,
#  3.18,
#  4.92,
#  4.62,
#  3.41,
#  3.98,
#  2.77,
#  4.85,
#  4.47,
#  2.69,
#  4.36,
#  4.96,
#  2.87,
#  4.03,
#  5.0,
#  1.82,
#  2.95,
#  4.88,
#  1.39,
#  4.85,
#  2.41,
#  4.31,
#  2.97,
#  1.93,
#  1.64,
#  4.56,
#  4.08,
#  4.65,
#  4.87,
#  5.01,
#  1.54,
#  2.91,
#  4.78,
#  2.77,
#  3.53,
#  4.81,
#  4.28,
#  4.85,
#  4.78,
#  1.44,
#  1.84,
#  2.48,
#  3.92,
#  2.97,
#  3.1,
#  1.32,
#  2.52,
#  3.78,
#  3.24,
#  4.94,
#  3.82,
#  3.13,
#  1.83,
#  4.31,
#  1.63,
#  1.59,
#  4.85,
#  2.55,
#  4.59,
#  3.43,
#  4.97,
#  3.75,
#  4.83,
#  3.32,
#  4.72,
#  4.9,
#  4.79,
#  3.28,
#  3.41,
#  4.87,
#  4.3,
#  4.13,
#  1.62,
#  4.65,
#  4.91,
#  1.36,
#  4.87,
#  4.27,
#  5.02,
#  4.54,
#  4.33,
#  1.33,
#  3.27,
#  4.1,
#  4.65,
#  4.02,
#  2.72,
#  1.77,
#  1.49,
#  4.23,
#  4.0,
#  4.0,
#  1.92,
#  3.24,
#  3.78,
#  4.74,
#  1.22,
#  4.84,
#  4.01,
#  2.13,
#  4.95,
#  1.47,
#  4.55,
#  1.67,
#  1.57,
#  4.82,
#  1.34,
#  1.85,
#  4.84,
#  3.15,
#  2.99,
#  1.32,
#  4.38,
#  3.42,
#  4.84,
#  1.23,
#  4.91,
#  4.84,
#  3.87,
#  4.04,
#  4.81,
#  3.92,
#  4.83,
#  4.84,
#  3.88,
#  1.83,
#  4.69,
#  4.97,
#  2.46,
#  4.65,
#  4.94,
#  4.43,
#  4.83,
#  4.01,
#  2.38,
#  4.87,
#  4.7,
#  3.73,
#  4.1,
#  1.11,
#  1.84,
#  2.41,
#  2.54,
#  2.31,
#  4.3,
#  4.79,
#  4.43]
