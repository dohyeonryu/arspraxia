# %% [markdown]
# <a href="https://colab.research.google.com/github/dohyeonryu/arspraxia/blob/main/Pororo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file_youtube=pd.read_csv("Youtube_Ko_Raw_05.csv")
file_news=pd.read_csv("news_keyword_05.csv")
file_twitter=pd.read_csv("twitter_cleaning_05.csv")

# %%
body_youtube=list(file_youtube['body'])
body_news=list(file_news['body'])
body_twitter=list(file_twitter['body'])

# %%
from pororo import Pororo
ner=Pororo(task="ner",lang="ko")
review=Pororo(task="review_scoring",lang="ko")

# %%
body_youtube=list(file_youtube['body'].head(10))
body_news=list(file_news['body'].head(10))
body_twitter=list(file_twitter['body'].head(10))

# %%
from tqdm import tqdm_notebook
review_results=[]
for i in tqdm_notebook(body_news):
  result = review(i)
  review_results.append(result)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
review_results
# Out:
# [4.93, 3.81, 4.92, 4.53, 4.0, 4.91, 3.97, 4.83, 4.85, 4.8]

# %%
from tqdm import tqdm_notebook
ner_results=[]
for i in tqdm_notebook(body_news):
  result = ner(i)
  ner_results.append(result)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
ner_results
# Out:
# [[('이수현', 'PERSON'),
#   ('은', 'O'),
#   (' ', 'O'),
#   ('"우리는', 'O'),
#   (' ', 'O'),
#   ('은퇴를', 'O'),
#   (' ', 'O'),
#   ('하면', 'O'),
#   (' ', 'O'),
#   ('했지', 'O'),
#   (' ', 'O'),
#   ('YG', 'ORGANIZATION'),
#   ('를', 'O'),
#   (' ', 'O'),
#   ('떠날', 'O'),
#   (' ', 'O'),
#   ('생각을', 'O'),
#   (' ', 'O'),
#   ('단', 'O'),
#   (' ', 'O'),
#   ('한 번', 'QUANTITY'),
#   ('도', 'O'),
#   (' ', 'O'),
#   ('해', 'O'),
#   (' ', 'O'),
#   ('본', 'O'),
#   (' ', 'O'),
#   ('적', 'O'),
#   (' ', 'O'),
#   ('없다"며', 'O'),
#   (' ', 'O'),
#   ('YG', 'ORGANIZATION'),
#   ('와의', 'O'),
#   (' ', 'O'),
#   ('끈끈한', 'O'),
#   (' ', 'O'),
#   ('의리를', 'O'),
#   (' ', 'O'),
#   ('자랑했다', 'O')],
#  [('저스틴 비버', 'PERSON'),
#   (',', 'O'),
#   (' ', 'O'),
#   ('4개월 만', 'DATE'),
#   ('에', 'O'),
#   (' ', 'O'),
#   ('또', 'O'),
#   (' ', 'O'),
#   ('1위', 'QUANTITY'),
#   (' ', 'O'),
#   ('[', 'O'),
#   ('9월 1주차', 'DATE'),
#   (' ', 'O'),
#   ('멜론차트', 'TERM'),
#   (']', 'O')],
#  [('지난 4일', 'DATE'),
# ...

# %%
review_results=[]
for i in tqdm_notebook(body_youtube):
  result = review(i)
  review_results.append(result)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
review_results
# Out:
# [4.6, 5.02, 5.02, 4.7, 4.63, 3.22, 3.97, 4.93, 4.01, 1.88]

# %%
ner_results=[]
for i in tqdm_notebook(body_youtube):
  result = ner(i)
  ner_results.append(result)
ner_results
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/10 [00:00<?, ?it/s]
# [[('보고싶어', 'O'),
#   (' ', 'O'),
#   ('보고싶어', 'O'),
#   (' ', 'O'),
#   ('보고싶어', 'O'),
#   (' ', 'O'),
#   ('백현아', 'PERSON')],
#  [('따스하고', 'O'),
#   (' ', 'O'),
#   ('다정한', 'O'),
#   (' ', 'O'),
#   ('너의', 'O'),
#   (' ', 'O'),
#   ('목소리는', 'O'),
#   (' ', 'O'),
#   ('12월', 'DATE'),
#   ('의', 'O'),
#   (' ', 'O'),
#   ('기적', 'O'),
#   (' ', 'O'),
#   ('같아♥', 'O'),
#   (' ', 'O'),
#   ('그는', 'O'),
#   (' ', 'O'),
#   ('이제', 'O'),
#   (' ', 'O'),
#   ('내가', 'O'),
#   (' ', 'O'),
#   ('그리워하는', 'O'),
#   (' ', 'O'),
#   ('안도감을', 'O'),
#   (' ', 'O'),
#   ('느끼게', 'O'),
#   (' ', 'O'),
#   ('하는', 'O'),
#   (' ', 'O'),
#   ('모든', 'O'),
#   (' ', 'O'),
#   ('따뜻함으로', 'O'),
#   (' ', 'O'),
#   ('내', 'O'),
#   (' ', 'O'),
#   ('영혼과', 'O'),
#   (' ', 'O'),
# ...

# %%
review_results=[]
for i in tqdm_notebook(body_twitter):
  result = review(i)
  review_results.append(result)
review_results
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/10 [00:00<?, ?it/s]
# [1.79, 1.54, 4.74, 1.38, 3.94, 1.65, 2.03, 4.64, 4.14, 4.52]

# %%
ner_results=[]
for i in tqdm_notebook(body_twitter):
  result = ner(i)
  ner_results.append(result)
ner_results
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/10 [00:00<?, ?it/s]
# [[('아이브', 'PERSON'),
#   (' ', 'O'),
#   ('너무너무키여운거.', 'O'),
#   (' ', 'O'),
#   ('ㅇㅇ즈', 'O'),
#   (' ', 'O'),
#   ('이름이', 'O'),
#   (' ', 'O'),
#   ('다', 'O'),
#   (' ', 'O'),
#   ('커플즈', 'O'),
#   (' ', 'O'),
#   ('공주즈', 'O'),
#   (' ', 'O'),
#   ('우당탕즈', 'O'),
#   (' ', 'O'),
#   ('감성즈', 'O'),
#   (' ', 'O'),
#   ('이런거임', 'O'),
#   (' ', 'O'),
#   ('호감너무심해', 'O'),
#   (' ', 'O'),
#   ('공주', 'CIVILIZATION'),
#   ('님들', 'O'),
#   (' ', 'O'),
#   ('모임이야', 'O'),
#   (' ', 'O'),
#   ('완전', 'O'),
#   (' ', 'O'),
#   ('나는', 'O'),
#   (' ', 'O'),
#   ('그사이에낀', 'O'),
#   (' ', 'O'),
#   ('난쟁이', 'ANIMAL'),
#   ('똥자루', 'ANIMAL'),
#   ('1마리', 'QUANTITY'),
#   ('고', 'O')],
#  [('식물한테', 'O'),
#   (' ', 'O'),
#   ('사랑해', 'O'),
#   (' ', 'O'),
# ...
